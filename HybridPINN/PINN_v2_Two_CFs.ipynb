# %% [markdown]
# ## Version Description
# In this version, we deploy a Hybrid PINN to predict two correction factors, i.e the correction factor for both the MTR ( `MTR-600` ) and its corresponding duct part (`TZ-6_zmix`) is predicted by the neural network.

# %%
from IPython.core.display import display, HTML,display_html
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# Source: https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side
def display_side_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

# %%
# import required libraries
import random
import pandas as pd
import numpy as np

from functools import reduce
import sys

#Set some numpy print options for displaying numpy arrays to fit maximum width of cell
np.set_printoptions(precision=3, edgeitems=30, linewidth=1000,formatter=dict(float=lambda x: "%.3g" % x))

# Disable Warnings for chained assignments Eg:Setting with Copy Warning
pd.options.mode.chained_assignment = None

from bokeh.models import ColumnDataSource
from bokeh.plotting import figure, show, output_file,output_notebook
output_notebook() # Set to output the plot in the notebook
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="83c94bf3-cf66-429d-bdc8-f02a170e05a8">Loading BokehJS ...</span>
#     </div>

# %%
# import LTR and corresponding Restrictor dataframe
Restrictor_data = pd.read_csv('D:/OneDrive/Documents/Airbus/GitHub/ML_A350_Restrictors/TZ6/data/Zone6_RestrictorData_LTR.csv')
LTR_data = pd.read_csv('D:/OneDrive/Documents/Airbus/GitHub/ML_A350_Restrictors/TZ6/data/Zone6_LTRData.csv')
obs_HOVs = pd.read_csv('../data/LTR_dataset.csv', usecols = ['HoV'])[['HoV']]
LTR_data[['AMBP','MIXP']] *= 100 # Convert hPa to Pa
zero_MIXT_hoV_idx = LTR_data.index[LTR_data['MIXT'] == 20].tolist() # Points where originally, MIXT == 0 and substituted with 20° C
LTR_data[['MIXT','AMBT']] += 273.15 # Convert Celcius to Kelvin
print('Total LTR points:',len(LTR_data))

## Calculate Density = (0.5* Pmix + Pamb) / (R * Tmix) where R = 287 is the Gas constant in Ideal Gas Law
idx = LTR_data.columns.get_loc("AMBT")
LTR_data.insert(loc=(idx+1), column='Density(kg/m³)', value=np.round((0.5 * LTR_data['MIXP'] + LTR_data['AMBP'] ) / (LTR_data['MIXT']*287),4))
target_df = reduce(lambda left,right: pd.merge(left,right,left_on='HoV',right_on='HoV'), [LTR_data,Restrictor_data])
target_df['HoV'] = obs_HOVs.values
target_df.head(3)
# Out:
# Total LTR points: 34
#   HoV  CAOLH_C66-C68  CAOLH_C68-C70  CAOLH_C70-C72  CAOLH_C72-C74  \
# 0  A1      36.071000      38.802000      36.796000      36.794000
# 1  A2      36.061000      38.697000      37.156000      36.738000
# 2  A3      37.504234      40.911735      38.412733      37.859887
#
#    CAOLH_C74-C76  CAOLH_C76-C78  CAORH_C66-C68  CAORH_C68-C70  CAORH_C70-C72  \
# 0      39.100000      38.318000      37.055000      39.596000      38.333000
# 1      38.957000      38.326000      36.501000      40.797000      39.284000
# 2      36.585486      38.504564      36.161971      37.068225      37.893405
#
#      ...     R632_HS1  R633_HS1  R634_HS1  R635_HS1  R636_HS1  R637_HS1  \
# 0    ...           41        41        41        41        41        41
# 1    ...           41        41        41        41        41        41
# 2    ...           41        41        41        41        41        41
#
#    R638_HS1  R639_HS1  R640_HS1  R641_HS1
# 0        41        41        41        41
# 1        41        41        41        41
# 2        41        41        41        41
#
# [3 rows x 58 columns]

# %%
target_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 0 to 33
# Data columns (total 58 columns):
# HoV               34 non-null object
# CAOLH_C66-C68     34 non-null float64
# CAOLH_C68-C70     34 non-null float64
# CAOLH_C70-C72     34 non-null float64
# CAOLH_C72-C74     34 non-null float64
# CAOLH_C74-C76     34 non-null float64
# CAOLH_C76-C78     34 non-null float64
# CAORH_C66-C68     34 non-null float64
# CAORH_C68-C70     34 non-null float64
# CAORH_C70-C72     34 non-null float64
# CAORH_C72-C74     34 non-null float64
# CAORH_C74-C76     34 non-null float64
# CAORH_C76-C78     34 non-null float64
# LAOLH_C66-C68     34 non-null float64
# LAOLH_C68-C70     34 non-null float64
# LAOLH_C70-C72     34 non-null float64
# LAOLH_C72-C74     34 non-null float64
# LAOLH_C74-C76     34 non-null float64
# LAOLH_C76-C78     34 non-null float64
# LAORH_C66-C68     34 non-null float64
# LAORH_C68-C70     34 non-null float64
# LAORH_C70-C72     34 non-null float64
# LAORH_C72-C74     34 non-null float64
# LAORH_C74-C76     34 non-null float64
# LAORH_C76-C78     34 non-null float64
# MIXP              34 non-null float64
# MIXT              34 non-null float64
# AMBP              34 non-null float64
# AMBT              34 non-null float64
# Density(kg/m³)    34 non-null float64
# CAOLH_SumFlow     34 non-null float64
# CAORH_SumFlow     34 non-null float64
# LAOLH_SumFlow     34 non-null float64
# LAORH_SumFlow     34 non-null float64
# TZ6_Flow          34 non-null float64
# R600_HD           34 non-null int64
# R610_HS1          34 non-null int64
# R611_HS1          34 non-null int64
# R612_HS1          34 non-null int64
# R613_HS1          34 non-null int64
# R620_HS1          34 non-null int64
# R620_HS2          34 non-null int64
# R620_HS3          34 non-null int64
# R621_HS1          34 non-null int64
# R621_HS2          34 non-null int64
# R621_HS3          34 non-null int64
# R630_HS1          34 non-null int64
# R631_HS1          34 non-null int64
# R632_HS1          34 non-null int64
# R633_HS1          34 non-null int64
# R634_HS1          34 non-null int64
# R635_HS1          34 non-null int64
# R636_HS1          34 non-null int64
# R637_HS1          34 non-null int64
# R638_HS1          34 non-null int64
# R639_HS1          34 non-null int64
# R640_HS1          34 non-null int64
# R641_HS1          34 non-null int64
# dtypes: float64(34), int64(23), object(1)
# memory usage: 15.7+ KB

# %%
MIXP = [1800, 2600, 3400]
# Define Restrictor Labels
MTR = 'R600_HD'
CLRS = ['R610_HS1','R611_HS1','R612_HS1','R613_HS1']
CAORS = ['R620_HS1','R620_HS2','R620_HS3','R621_HS1','R621_HS2','R621_HS3']
MHRS = CLRS + CAORS
LAORS = ['R630_HS1','R631_HS1','R632_HS1','R633_HS1','R634_HS1','R635_HS1','R636_HS1','R637_HS1','R638_HS1','R639_HS1','R640_HS1','R641_HS1']

# %%
# Duct Areas
MTR_DuctArea = 0.03464 # in sq.m
MHR_Duct_Areas = {'R610_HS1':0.01767,'R611_HS1':0.01767,'R612_HS1':0.02461,'R613_HS1':0.02461,
                 'R620_HS1':0.01090,'R620_HS2':0.00470,'R620_HS3':0.01085,'R621_HS1':0.01085,'R621_HS2':0.00470,'R621_HS3':0.01090}

## Define Initial Correction factor values from CFD
# Correction Factor for Duct Part `TZ6_zmix:
TZ6_zmix_cf = 1 # Start with initial c_f =1 

#3D Correction Factor for MTR
MTR_cf = 1.1664876228437


#3D Correction Factors for MultiHole Restrictors
MHR_cf = {'R610_HS1':0.740773983383846,'R611_HS1':0.740205245723713,'R612_HS1':0.83879652680329,'R613_HS1':0.81775586281569,
          'R620_HS1':0.757121843184036,'R620_HS2':0.773919779037984,'R620_HS3':0.789028593182055,
          'R621_HS1':0.714811824527744,'R621_HS2':0.866271631648556,'R621_HS3':0.822447592395462}

# %% [markdown]
# ### Calculate Loss-Coefficient $\zeta$
# **For Single Hole Restrictor:**<br>
#
#     f0_f1 = A_Circular(Hole_Diameter) / Area_Overall
#     l_cross = Thickness / Hole_Diameter
#     Zeta_dash = 0.13 + 0.34 * 10 ^ -(3.4 * l_cross + 88.4 * l_cross ^ 2.3)
#     Zeta_Single_Hole_Thick_Chamfered = ((1 - f0_f1 + (Zeta_dash ^ 0.5) * (1 - f0_f1) ^ 0.375) ^ 2) * f0_f1 ^ -2

# %%
def SHR_Zeta_3D(n_holes,hole_dia,MTR_DuctArea,cf):
    '''
    Computes the Zeta with 3D Correction Factor (cf) for Single Hole Retrictors
    '''
    MTR_New_Area = n_holes * (np.pi/4) * (hole_dia / 1000)**2 # Divide dia by 1000 to convert mm to m
    f0_f1 = MTR_New_Area/MTR_DuctArea
    l_cross = 1/hole_dia
    zeta_dash = 0.13 + 0.34 * 10**(-(3.4 * l_cross + 88.4 * l_cross**2.3))
    zeta_SHR_1D = ((1 - f0_f1 + (zeta_dash**0.5) * (1 - f0_f1)**0.375)**2) * f0_f1**(-2) # 1D Zeta
    zeta_SHR_3D = zeta_SHR_1D * cf # Zeta with 3D Correction Factor    
    return MTR_New_Area,zeta_SHR_3D

# %%
target_df[MTR+'_Area'],target_df[MTR+'_Zeta3D'] = zip(*[SHR_Zeta_3D(1,dia,MTR_DuctArea,MTR_cf) for dia in target_df[MTR]])
target_df[[MTR,'R600_HD_Area','R600_HD_Zeta3D']].head()
# Out:
#    R600_HD  R600_HD_Area  R600_HD_Zeta3D
# 0      148      0.017203        4.949375
# 1      149      0.017437        4.730821
# 2      152      0.018146        4.127180
# 3      154      0.018627        3.764504
# 4      148      0.017203        4.949375

# %% [markdown]
# **For Multi Hole Restrictors:**<br>
#
#     Area_Free = Number_of_Holes * A_Circular(Hole_Diameter)
#     f0_f1 = Area_Free / Area_Overall
#     l_cross = Thickness / Hole_Diameter
#     phi = 0.25 + (0.535 * l_cross ^ 8) / (0.05 + l_cross ^ 7)
#     tau = (2.4 - l_cross) * 10 ^ (-phi)
#     Zeta_Multi_Hole = (0.5 * (1 - f0_f1) ^ 0.75 + tau * (1 - f0_f1) ^ 1.375 + (1 - f0_f1) ^ 2 + 0.02 * l_cross) / f0_f1 ^ 2

# %%
def MHR_Zeta_3D(nr_holes,hole_dia,MHR_DuctArea,cf):
    '''
    Computes the Zeta with 3D Correction Factor (cf) for Multi Hole Restrictors
    '''
    MHR_New_Area = nr_holes * (np.pi/4) * (hole_dia / 1000)**2 # Divide dia by 1000 to convert mm to m
    f0_f1 = MHR_New_Area/MHR_DuctArea
    l_cross = (0.00144*1000)/hole_dia
    phi = 0.25 + (0.535 * l_cross**8) / (0.05 + l_cross**7)
    tau = (2.4 - l_cross) * 10**(-phi)
    zeta_MHR_1D = (0.5 * (1 - f0_f1)**0.75 + tau * (1 - f0_f1)**1.375 + (1 - f0_f1)**2 + 0.02 * l_cross) / f0_f1**2 # 1D Zeta     
    zeta_MHR_3D = zeta_MHR_1D * cf # Zeta with 3D Correction Factor    
    return MHR_New_Area,zeta_MHR_3D

# %%
# Calculate Zeta for Multi-Hole Restrictors
for clr in CLRS:
    if (clr == 'R610_HS1') | (clr == 'R611_HS1'):
        hole_dia = 8
    else:
        hole_dia = 10
    MHR_nr_holes = target_df[clr].values
    target_df[clr+'_Area'], target_df[clr+'_Zeta3D'] = zip(*[MHR_Zeta_3D(ele,hole_dia,MHR_Duct_Areas[clr],MHR_cf[clr]) for ele in MHR_nr_holes])
    
for caor in CAORS:
    CAOR_nr_holes = target_df[caor].values
    target_df[caor+'_Area'],target_df[caor+'_Zeta3D'] = zip(*[MHR_Zeta_3D(ele,8,MHR_Duct_Areas[caor],MHR_cf[caor]) for ele in CAOR_nr_holes])

# %%
# LTR Dataframe col index for Restrictor Zeta and Area values
target_df.iloc[:,58:].head()
# Out:
#    R600_HD_Area  R600_HD_Zeta3D  R610_HS1_Area  R610_HS1_Zeta3D  \
# 0      0.017203        4.949375       0.006585         7.506119
# 1      0.017437        4.730821       0.006585         7.506119
# 2      0.018146        4.127180       0.006585         7.506119
# 3      0.018627        3.764504       0.006585         7.506119
# 4      0.017203        4.949375       0.007288         5.595443
#
#    R611_HS1_Area  R611_HS1_Zeta3D  R612_HS1_Area  R612_HS1_Zeta3D  \
# 0       0.006836         6.741078       0.009425         7.920333
# 1       0.006836         6.741078       0.009425         7.920333
# 2       0.006836         6.741078       0.008954         9.156844
# 3       0.006836         6.741078       0.009425         7.920333
# 4       0.007691         4.756868       0.010210         6.271347
#
#    R613_HS1_Area  R613_HS1_Zeta3D       ...         R620_HS2_Area  \
# 0       0.009425         7.721657       ...               0.00191
# 1       0.009425         7.721657       ...               0.00191
# 2       0.009425         7.721657       ...               0.00191
# 3       0.009425         7.721657       ...               0.00191
# 4       0.010210         6.114035       ...               0.00191
#
#    R620_HS2_Zeta3D  R620_HS3_Area  R620_HS3_Zeta3D  R621_HS1_Area  \
# 0         6.107864        0.00568         2.786638        0.00377
# 1         6.107864        0.00568         2.786638        0.00377
# 2         6.107864        0.00568         2.786638        0.00377
# 3         6.107864        0.00568         2.786638        0.00377
# 4         6.107864        0.00568         2.786638        0.00377
#
#    R621_HS1_Zeta3D  R621_HS2_Area  R621_HS2_Zeta3D  R621_HS3_Area  \
# 0         8.801675        0.00191         6.836716        0.00568
# 1         8.801675        0.00191         6.836716        0.00568
# 2         8.801675        0.00191         6.836716        0.00568
# 3         8.801675        0.00191         6.836716        0.00568
# 4         8.801675        0.00191         6.836716        0.00568
#
#    R621_HS3_Zeta3D
# 0          2.95119
# 1          2.95119
# 2          2.95119
# 3          2.95119
# 4          2.95119
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Run FDDN Solver

# %%
from FDDN_Lib import fddn_zeta_input, FDDN_Solver, FDDN_output_df_gen, name_variables, zeta_values

# %%
print(name_variables)
# Out:
# ['TZ-6_zmix', 'MTR-600', 'riser_LAO_RHS', 'riser_LAO_LHS', 'riser_CAO_RHS', 'riser_CAO_LHS', 'R-610', 'R-611', 'R-612', 'R-613', 'LAOR-630', 'LAOR-632', 'LAOR-634', 'LAOR-636', 'LAOR-638', 'LAOR-640', 'LAOR-631', 'LAOR-633', 'LAOR-635', 'LAOR-637', 'LAOR-639', 'LAOR-641', 'CAO-620_fwd', 'CAO-620_mid', 'CAO-620_aft', 'CAO-621_fwd', 'CAO-621_mid', 'CAO-621_aft', 'LAO-630', 'LAO-632', 'LAO-634', 'LAO-636', 'LAO-638', 'LAO-640', 'LAO-631', 'LAO-633', 'LAO-635', 'LAO-637', 'LAO-639', 'LAO-641', 'CAOR-620_fwd', 'CAOR-620_mid', 'CAOR-620_aft', 'CAOR-621_fwd', 'CAOR-621_mid', 'CAOR-621_aft', 'pp2610pdloss', 'pp2611pdloss', 'pp2612pdloss', 'pp2613pdloss', '26120-R620_F', '26120-R620_M', '26120-R620_A', '26121-R621_F', '26121-R621_M', '26121-R621_A']

# %%
# Use Initial Zeta value from the CFD model for the 'TZ-6_zmix' duct part
idx = target_df.columns.get_loc("R600_HD_Zeta3D")
target_df.insert(loc=(idx-1), column='TZ6_zmix_Zeta3D', value=float(zeta_values[0]))

# %%
# Gather col_names and their corresponding column indices
zeta_col_names = [col for col in target_df.columns if 'Zeta3D' in col]
zeta_col_names_idx = [target_df.columns.get_loc(col) for col in zeta_col_names if col in target_df]
area_col_names = [col for col in target_df.columns if 'Area' in col]
area_col_names_idx = [target_df.columns.get_loc(col) for col in area_col_names if col in target_df]
pt_var_idx = [target_df.columns.get_loc(col) for col in ['MIXP','AMBP','AMBT'] if col in target_df]
req_flow_rates_idx = [target_df.columns.get_loc(col) for col in ['TZ6_Flow'] if col in target_df]
# print(zeta_col_names_idx)
print(zeta_col_names)
# Out:
# ['TZ6_zmix_Zeta3D', 'R600_HD_Zeta3D', 'R610_HS1_Zeta3D', 'R611_HS1_Zeta3D', 'R612_HS1_Zeta3D', 'R613_HS1_Zeta3D', 'R620_HS1_Zeta3D', 'R620_HS2_Zeta3D', 'R620_HS3_Zeta3D', 'R621_HS1_Zeta3D', 'R621_HS2_Zeta3D', 'R621_HS3_Zeta3D']

# %%
LTR_zeta_df_col_idx = sorted([0] + req_flow_rates_idx + pt_var_idx + zeta_col_names_idx)
target_df.iloc[:,LTR_zeta_df_col_idx].to_csv('data_output/LTR_Zeta_df.csv', index=False)

# %%
LTR_zeta_df = target_df[['HoV','MIXP','AMBP','AMBT','TZ6_Flow']+zeta_col_names]
LTR_zeta_df[['HoV','AMBP','AMBT']+zeta_col_names].tail()
# Out:
#    HoV         AMBP        AMBT  TZ6_zmix_Zeta3D  R600_HD_Zeta3D  \
# 29  S3  101105.3000  297.285667         0.712987        4.521189
# 30  S4  102356.1438  294.425869         0.712987        4.521189
# 31  S5  102286.7009  294.434538         0.712987        2.839767
# 32  T1  100112.6000  297.133500         0.712987        4.949375
# 33  T2  101099.0000  296.278833         0.712987        4.949375
#
#     R610_HS1_Zeta3D  R611_HS1_Zeta3D  R612_HS1_Zeta3D  R613_HS1_Zeta3D  \
# 29         7.506119         6.741078         7.920333         7.721657
# 30         7.506119         6.741078         7.920333         6.862828
# 31         7.506119         5.591147         7.920333         6.862828
# 32         7.506119         6.741078         7.920333         7.721657
# 33         7.506119         6.741078         7.920333         7.721657
#
#     R620_HS1_Zeta3D  R620_HS2_Zeta3D  R620_HS3_Zeta3D  R621_HS1_Zeta3D  \
# 29         9.440922         6.107864         2.786638         8.801675
# 30         9.440922         6.107864         2.786638         8.801675
# 31         9.440922         6.107864         2.786638         8.801675
# 32         9.440922         6.107864         2.786638         8.801675
# 33         9.440922         6.107864         2.786638         8.801675
#
#     R621_HS2_Zeta3D  R621_HS3_Zeta3D
# 29         6.836716          2.95119
# 30         6.836716          2.95119
# 31         6.836716          2.95119
# 32         6.836716          2.95119
# 33         6.836716          2.95119

# %%
final_df = target_df[['HoV','MIXP','Density(kg/m³)','R600_HD','TZ6_zmix_Zeta3D','R600_HD_Zeta3D','TZ6_Flow']]
final_df.reset_index(drop=True,inplace = True)
# final_df[['MIXP','Density(kg/m³)','R600_HD','TZ6_zmix_Zeta3D','R600_HD_Zeta3D','TZ6_Flow']].head()

# %% [markdown]
# ### Training data Preparation

# %%
from Hybrid_PINN_v2 import NormbyMax, DeNormbyMax, PINN

# %%
input_features = ['MIXP','Density(kg/m³)','TZ6_zmix_Zeta3D','R600_HD_Zeta3D','TZ6_Flow']
features_max, df_rescaled = NormbyMax(final_df,input_features)
print('Max value of all features:',features_max)

V_max_org = features_max['TZ6_Flow']
print('Maximum TZ6 Flow:',V_max_org)
# Out:
# Max value of all features: {'MIXP': 2632.9689, 'Density(kg/m³)': 1.238, 'TZ6_zmix_Zeta3D': 0.712986788872249, 'R600_HD_Zeta3D': 5.4148802645163, 'TZ6_Flow': 764.0123719999998}
# Maximum TZ6 Flow: 764.0123719999998

# %%
# Display original and Scaled DataFrame Side-by-side
# print( '{:<60s} {:<20s}'.format('Original Input Dataframe:','Rescaled Input Dataframe:') )
# display_side_by_side(final_df[['HoV']+input_features],df_rescaled)

# %%
df_rescaled_inv = DeNormbyMax(df_rescaled,features_max,input_features)

# %%
train_data = df_rescaled
# train_data = df_rescaled.iloc[[7,15]]
print("Number of training samples:", len(train_data))
train_data
# Out:
# Number of training samples: 34
#         MIXP  Density(kg/m³)  TZ6_zmix_Zeta3D  R600_HD_Zeta3D  TZ6_Flow
# 0   0.987478        0.986026              1.0        0.914032  0.966062
# 1   0.987478        0.987722              1.0        0.873670  0.965658
# 2   0.989830        0.976575              1.0        0.762192  0.969853
# 3   0.987440        0.999031              1.0        0.695215  0.958246
# 4   0.987478        1.000000              1.0        0.914032  0.970963
# 5   0.987478        0.985299              1.0        0.914032  0.973195
# 6   0.987478        0.978837              1.0        0.914032  0.968664
# 7   0.988183        0.967367              1.0        0.728011  0.971982
# 8   0.985737        0.960420              1.0        0.762192  0.968232
# 9   0.987478        0.996446              1.0        0.834956  0.968331
# 10  0.987588        0.981179              1.0        0.762192  0.951742
# 11  0.986882        0.974556              1.0        0.695215  0.986556
# 12  0.987478        0.989984              1.0        0.797819  0.987052
# 13  0.987478        0.989095              1.0        0.914032  0.965635
# 14  0.987478        0.985299              1.0        0.914032  0.962727
# 15  0.991731        0.977141              1.0        0.914032  0.877929
# 16  0.987478        0.998546              1.0        1.000000  0.944254
# 17  0.987478        0.985299              1.0        1.000000  0.944254
# 18  0.987478        0.998223              1.0        0.914032  0.971268
# 19  0.987478        0.991599              1.0        0.914032  0.964416
# 20  0.987999        0.968417              1.0        0.762192  0.951578
# 21  0.986652        0.976090              1.0        0.914032  0.926337
# 22  0.983197        0.973425              1.0        0.695215  0.989218
# 23  1.000000        0.959289              1.0        0.695215  1.000000
# 24  0.989386        0.973910              1.0        0.695215  0.984918
# 25  0.987478        0.986187              1.0        0.914032  0.948973
# 26  0.987478        0.973667              1.0        0.914032  0.978063
# 27  0.987709        0.976494              1.0        0.663745  0.971287
# 28  0.987478        0.974637              1.0        0.914032  0.974581
# 29  0.987478        0.983199              1.0        0.834956  0.986001
# 30  0.986584        0.986914              1.0        0.834956  0.961329
# 31  0.988390        0.989095              1.0        0.524438  0.992039
# 32  0.987478        0.973667              1.0        0.914032  0.945777
# 33  0.987478        0.983118              1.0        0.914032  0.970179

# %%
# Store indices and values of train data
train_data_idx = train_data.index.values.tolist()
train_R600HD_series = final_df['R600_HD'].iloc[train_data_idx]
X_train = train_data.values

# %% [markdown]
# ### Predict $c_f$ with Physics Informed Neural Network

# %%
# A random seed is used to reproduce the weight initialization values and training performance everytime this notebook is run.
np.random.seed(13)
# Define custom MSE function
MSE = lambda y_hat,y_true: np.mean((y_hat-y_true)**2)

# %% [markdown]
# **Train the Neural Network**:

# %%
### Set the hyperparameters here ###
iterations = 100
learning_rate = 0.01 ### Important Parameter
hidden_nodes = 3 ### Important Parameter
output_nodes = 2
MTR_epsi = MTR_cf * 0.01
TZ6_zmix_epsi = TZ6_zmix_cf * 0.01

# %%
N_i = X_train.shape[1]
network = PINN(N_i, hidden_nodes, output_nodes, learning_rate)

train_loss_hist = []
losses_hist = {'HoV':[],'train_loss':[]}
c_f_hist = {'HoV':[],'MTR_cf_hat':[],'TZ6zmix_cf_hat':[]}

for idx in train_data_idx:    
    ## Stochastic Gradient Descent with mini-batch training
    print('Old_Zeta:',target_df[MTR+'_Zeta3D'].loc[idx])
    for ii in range(iterations):    
        # Go through one record at a time from the training data set
        X_train = train_data[input_features].loc[[idx]].values
        dia_train = np.atleast_1d(train_R600HD_series.loc[idx])    
        HoV,V_hat_FDDN,V_true_LTR,break_flag,MTR_new_cf,TZ6_zmix_new_cf = network.train(X_train,dia_train,[idx],(MTR_epsi,TZ6_zmix_epsi),
                                                                                        MTR_DuctArea,target_df,zeta_col_names,V_max_org)
        
        # Printing out the training progress
        train_loss = MSE(V_hat_FDDN,V_true_LTR) # MSE between FDDN predicted flow rate and true flow rate on UN-scaled original values    
        sys.stdout.write("\rProgress: {:2.1f}".format(100 * ii/float(iterations))+ "% ... Training loss: " + str(round(train_loss,4))[:5])
        print('... Training Iteration:',ii)    
        sys.stdout.flush()
        train_loss_hist.append(train_loss)
        if (break_flag == 1) or (ii == iterations-1): # Early stopping based on custom break flag during training
            print('EARLY STOPPING ACTIVATED - Terminating Neural Network Training')
            print('Train Loss History for {}:'.format(HoV[0]),train_loss_hist)
            losses_hist['HoV'].append(HoV[0])
            losses_hist['train_loss'].append(train_loss_hist)
            c_f_hist['HoV'].append(HoV[0])
            c_f_hist['MTR_cf_hat'].append(MTR_new_cf)
            c_f_hist['TZ6zmix_cf_hat'].append(TZ6_zmix_new_cf)
            train_loss_hist = []
            break
# Out:
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.14 -0.0976]]
# MTR-Cf: 1.1409931844143717 , TZ6-zmix-Cf: -0.09761142606542361
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.14 0.0976]]
# MTR-Cf: 1.1409931844143717
# |TZ6_zmix-Cf|: 0.09761142606542361
# New_Zeta for MTR-600: [4.84]
# New_Zeta for TZ6_zmix: [0.0696]
# FDDN Solver Output: [[76.2 36.4 115 75.1 39.7 122 12 26 25.9 26 25.4 25.1 11.7 25.6 25.8 25.3 25 25]]
# New_Zeta_epsi for MTR-600: [4.89]
# New_Zeta_epsi for TZ6_zmix: [-0.00749]
# FDDN Solver Output: [[76.3 36.4 115 75.2 39.7 123 12 26 25.9 26 25.4 25.1 11.7 25.6 25.8 25.4 25.1 25.1]]
# Row ID: [0]
# HoV: ['A1']
# FlowRate Difference (LTR - FDDN): [-5.51] l/s
# % Diff between flowrates [0.743]
# Progress: 0.0% ... Training loss: 30.31... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for A1: [30.317672124050258]
# Old_Zeta: 4.7308206417914045
#
# NN output (C_f): [[1.12 -0.152]]
# MTR-Cf: 1.1228167334473969 , TZ6-zmix-Cf: -0.15196483001581343
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.12 0.152]]
# MTR-Cf: 1.1228167334473969
# |TZ6_zmix-Cf|: 0.15196483001581343
# New_Zeta for MTR-600: [4.55]
# New_Zeta for TZ6_zmix: [-0.00114]
# FDDN Solver Output: [[77.5 37 117 76.4 40.4 124 12.2 26.4 26.3 26.4 25.8 25.5 11.9 26 26.2 25.8 25.4 25.5]]
# New_Zeta_epsi for MTR-600: [4.6]
# New_Zeta_epsi for TZ6_zmix: [0.000184]
# FDDN Solver Output: [[77.3 36.9 116 76.2 40.3 124 12.2 26.3 26.3 26.3 25.8 25.4 11.9 25.9 26.1 25.7 25.4 25.4]]
# Row ID: [1]
# HoV: ['A2']
# FlowRate Difference (LTR - FDDN): [-18] l/s
# Progress: 0.0% ... Training loss: 324.8... Training Iteration: 0
#
# NN output (C_f): [[1.55 0.0648]]
# MTR-Cf: 1.5491474188933827 , TZ6-zmix-Cf: 0.06480867626510335
# New_Zeta for MTR-600: [6.28]
# New_Zeta for TZ6_zmix: [1.19e-05]
# FDDN Solver Output: [[71.1 33.9 107 70.2 37.1 114 11.2 24.2 24.2 24.2 23.7 23.4 11 23.9 24.1 23.7 23.4 23.4]]
# New_Zeta_epsi for MTR-600: [6.33]
# New_Zeta_epsi for TZ6_zmix: [8.94e-07]
# FDDN Solver Output: [[71 33.9 107 70 37 114 11.2 24.2 24.1 24.2 23.7 23.4 10.9 23.8 24 23.6 23.3 23.3]]
# Row ID: [1]
# HoV: ['A2']
# FlowRate Difference (LTR - FDDN): [43.6] l/s
# Progress: 1.0% ... Training loss: 1901.... Training Iteration: 1
#
# NN output (C_f): [[0.731 -0.412]]
# MTR-Cf: 0.7311149784656289 , TZ6-zmix-Cf: -0.4120084736893952
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[0.731 0.412]]
# MTR-Cf: 0.7311149784656289
# |TZ6_zmix-Cf|: 0.4120084736893952
# New_Zeta for MTR-600: [2.97]
# New_Zeta for TZ6_zmix: [3.68e-07]
# FDDN Solver Output: [[85.1 40.6 128 83.9 44.3 137 13.4 29 28.9 29 28.4 28 13.1 28.5 28.7 28.3 27.9 27.9]]
# New_Zeta_epsi for MTR-600: [3.01]
# New_Zeta_epsi for TZ6_zmix: [-1.55e-07]
# FDDN Solver Output: [[84.8 40.5 128 83.6 44.2 136 13.4 28.9 28.8 28.9 28.3 27.9 13.1 28.4 28.7 28.2 27.8 27.9]]
# Row ID: [1]
# HoV: ['A2']
# FlowRate Difference (LTR - FDDN): [-92.1] l/s
# Progress: 2.0% ... Training loss: 8489.... Training Iteration: 2
#
# NN output (C_f): [[3.36 1.1]]
# MTR-Cf: 3.364661760275414 , TZ6-zmix-Cf: 1.096956654583763
# New_Zeta for MTR-600: [13.6]
# New_Zeta for TZ6_zmix: [-1.7e-07]
# FDDN Solver Output: [[55.1 26.3 83 54.3 28.7 88.5 8.71 18.8 18.7 18.8 18.4 18.1 8.49 18.5 18.6 18.3 18.1 18.1]]
# New_Zeta_epsi for MTR-600: [13.7]
# New_Zeta_epsi for TZ6_zmix: [-1.89e-07]
# FDDN Solver Output: [[55 26.2 82.9 54.3 28.7 88.4 8.7 18.8 18.7 18.8 18.4 18.1 8.49 18.5 18.6 18.3 18.1 18.1]]
# Row ID: [1]
# HoV: ['A2']
# FlowRate Difference (LTR - FDDN): [200] l/s
# Progress: 3.0% ... Training loss: 40006... Training Iteration: 3
#
# NN output (C_f): [[1.38 -0.034]]
# MTR-Cf: 1.3839696554467438 , TZ6-zmix-Cf: -0.033998688444023796
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.38 0.034]]
# MTR-Cf: 1.3839696554467438
# |TZ6_zmix-Cf|: 0.033998688444023796
# New_Zeta for MTR-600: [5.61]
# New_Zeta for TZ6_zmix: [-6.42e-09]
# FDDN Solver Output: [[73.4 35 111 72.4 38.2 118 11.6 25 25 25 24.5 24.1 11.3 24.6 24.8 24.4 24.1 24.1]]
# New_Zeta_epsi for MTR-600: [5.66]
# New_Zeta_epsi for TZ6_zmix: [2.82e-10]
# FDDN Solver Output: [[73.2 34.9 110 72.2 38.2 118 11.6 24.9 24.9 25 24.4 24.1 11.3 24.6 24.8 24.4 24.1 24.1]]
# Row ID: [1]
# HoV: ['A2']
# FlowRate Difference (LTR - FDDN): [21.5] l/s
# Progress: 4.0% ... Training loss: 464.2... Training Iteration: 4
#
# NN output (C_f): [[1.15 -0.138]]
# MTR-Cf: 1.1519161211185787 , TZ6-zmix-Cf: -0.13760170800314078
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.15 0.138]]
# MTR-Cf: 1.1519161211185787
# |TZ6_zmix-Cf|: 0.13760170800314078
# New_Zeta for MTR-600: [4.67]
# New_Zeta for TZ6_zmix: [3.88e-11]
# FDDN Solver Output: [[77 36.7 116 75.9 40.1 124 12.1 26.2 26.2 26.2 25.7 25.3 11.9 25.8 26 25.6 25.3 25.3]]
# New_Zeta_epsi for MTR-600: [4.72]
# New_Zeta_epsi for TZ6_zmix: [-5.73e-12]
# FDDN Solver Output: [[76.8 36.6 116 75.7 40 123 12.1 26.2 26.1 26.2 25.6 25.3 11.8 25.8 26 25.5 25.2 25.2]]
# Row ID: [1]
# HoV: ['A2']
# FlowRate Difference (LTR - FDDN): [-13.3] l/s
# Progress: 5.0% ... Training loss: 177.3... Training Iteration: 5
#
# NN output (C_f): [[1.33 -0.106]]
# MTR-Cf: 1.3264188013147655 , TZ6-zmix-Cf: -0.1055065693961898
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.33 0.106]]
# MTR-Cf: 1.3264188013147655
# |TZ6_zmix-Cf|: 0.1055065693961898
# New_Zeta for MTR-600: [5.38]
# New_Zeta for TZ6_zmix: [-6.05e-13]
# FDDN Solver Output: [[74.2 35.4 112 73.2 38.7 119 11.7 25.3 25.2 25.3 24.8 24.4 11.4 24.9 25.1 24.7 24.4 24.4]]
# New_Zeta_epsi for MTR-600: [5.43]
# New_Zeta_epsi for TZ6_zmix: [6.99e-14]
# FDDN Solver Output: [[74.1 35.3 112 73 38.6 119 11.7 25.2 25.2 25.2 24.7 24.4 11.4 24.8 25 24.6 24.3 24.4]]
# Row ID: [1]
# HoV: ['A2']
# FlowRate Difference (LTR - FDDN): [13.4] l/s
# Progress: 6.0% ... Training loss: 178.5... Training Iteration: 6
#
# NN output (C_f): [[1.2 -0.173]]
# MTR-Cf: 1.195331206280644 , TZ6-zmix-Cf: -0.173212876299768
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.2 0.173]]
# MTR-Cf: 1.195331206280644
# |TZ6_zmix-Cf|: 0.173212876299768
# New_Zeta for MTR-600: [4.85]
# New_Zeta for TZ6_zmix: [1.21e-14]
# FDDN Solver Output: [[76.3 36.4 115 75.2 39.7 123 12 26 25.9 26 25.4 25.1 11.7 25.6 25.8 25.4 25.1 25.1]]
# New_Zeta_epsi for MTR-600: [4.9]
# New_Zeta_epsi for TZ6_zmix: [-2.22e-15]
# FDDN Solver Output: [[76.1 36.3 115 75 39.6 122 12 25.9 25.9 25.9 25.4 25 11.7 25.5 25.7 25.3 25 25]]
# Row ID: [1]
# HoV: ['A2']
# FlowRate Difference (LTR - FDDN): [-6.42] l/s
# Progress: 7.0% ... Training loss: 41.16... Training Iteration: 7
#
# NN output (C_f): [[1.29 -0.168]]
# MTR-Cf: 1.2879843556938273 , TZ6-zmix-Cf: -0.16842460666080034
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.29 0.168]]
# MTR-Cf: 1.2879843556938273
# |TZ6_zmix-Cf|: 0.16842460666080034
# New_Zeta for MTR-600: [5.22]
# New_Zeta for TZ6_zmix: [-3.73e-16]
# FDDN Solver Output: [[74.8 35.7 113 73.8 39 120 11.8 25.5 25.4 25.5 24.9 24.6 11.5 25.1 25.3 24.9 24.6 24.6]]
# New_Zeta_epsi for MTR-600: [5.27]
# New_Zeta_epsi for TZ6_zmix: [6.66e-17]
# FDDN Solver Output: [[74.6 35.6 113 73.6 38.9 120 11.8 25.4 25.4 25.4 24.9 24.6 11.5 25 25.2 24.8 24.5 24.5]]
# Row ID: [1]
# HoV: ['A2']
# FlowRate Difference (LTR - FDDN): [7.73] l/s
# Progress: 8.0% ... Training loss: 59.80... Training Iteration: 8
#
# NN output (C_f): [[1.22 -0.214]]
# MTR-Cf: 1.2233667927481888 , TZ6-zmix-Cf: -0.21395450552102563
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.22 0.214]]
# MTR-Cf: 1.2233667927481888
# |TZ6_zmix-Cf|: 0.21395450552102563
# New_Zeta for MTR-600: [4.96]
# New_Zeta for TZ6_zmix: [1.43e-17]
# FDDN Solver Output: [[75.8 36.2 114 74.8 39.5 122 12 25.8 25.8 25.8 25.3 24.9 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi for MTR-600: [5.01]
# New_Zeta_epsi for TZ6_zmix: [-3.19e-18]
# FDDN Solver Output: [[75.6 36.1 114 74.6 39.4 122 11.9 25.8 25.7 25.8 25.2 24.9 11.7 25.4 25.6 25.2 24.8 24.9]]
# Row ID: [1]
# HoV: ['A2']
# FlowRate Difference (LTR - FDDN): [-2.04] l/s
# % Diff between flowrates [0.276]
# Progress: 9.0% ... Training loss: 4.171... Training Iteration: 9
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for A2: [324.84598536345806, 1901.183011550614, 8489.898505349549, 40006.977514425314, 464.2176053913696, 177.35468223087597, 178.5239507830599, 41.16547657503946, 59.80604636769132, 4.171170884105412]
# Old_Zeta: 4.127180457922134
#
# NN output (C_f): [[1.32 -0.254]]
# MTR-Cf: 1.3178343779165875 , TZ6-zmix-Cf: -0.25358923406159223
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.32 0.254]]
# MTR-Cf: 1.3178343779165875
# |TZ6_zmix-Cf|: 0.25358923406159223
# New_Zeta for MTR-600: [4.66]
# New_Zeta for TZ6_zmix: [-8.1e-19]
# FDDN Solver Output: [[77 36.8 116 74 39.1 121 12.2 26.2 26.2 26.2 25.7 25.3 11.9 25.8 26 25.6 25.3 25.3]]
# New_Zeta_epsi for MTR-600: [4.7]
# New_Zeta_epsi for TZ6_zmix: [2.13e-19]
# FDDN Solver Output: [[76.9 36.7 116 73.9 39 120 12.1 26.2 26.1 26.2 25.6 25.3 11.8 25.8 26 25.6 25.3 25.3]]
# Row ID: [2]
# HoV: ['A3']
# FlowRate Difference (LTR - FDDN): [-4.56] l/s
# % Diff between flowrates [0.613]
# Progress: 0.0% ... Training loss: 20.74... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for A3: [20.74903276879855]
# Old_Zeta: 3.7645035449506787
#
# NN output (C_f): [[1.44 -0.276]]
# MTR-Cf: 1.441739665193178 , TZ6-zmix-Cf: -0.275702478011363
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.44 0.276]]
# MTR-Cf: 1.441739665193178
# |TZ6_zmix-Cf|: 0.275702478011363
# New_Zeta for MTR-600: [4.65]
# New_Zeta for TZ6_zmix: [5.88e-20]
# FDDN Solver Output: [[76 36.3 115 75 39.6 122 12 25.9 25.8 25.9 25.3 25 11.7 25.5 25.7 25.3 25 25]]
# New_Zeta_epsi for MTR-600: [4.69]
# New_Zeta_epsi for TZ6_zmix: [-1.68e-20]
# FDDN Solver Output: [[75.9 36.2 114 74.8 39.5 122 12 25.8 25.8 25.9 25.3 25 11.7 25.4 25.6 25.2 24.9 24.9]]
# Row ID: [3]
# HoV: ['A4']
# FlowRate Difference (LTR - FDDN): [-9.52] l/s
# Progress: 0.0% ... Training loss: 90.70... Training Iteration: 0
#
# NN output (C_f): [[1.57 -0.262]]
# MTR-Cf: 1.5730597503587243 , TZ6-zmix-Cf: -0.26154512219586384
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.57 0.262]]
# MTR-Cf: 1.5730597503587243
# |TZ6_zmix-Cf|: 0.26154512219586384
# New_Zeta for MTR-600: [5.08]
# New_Zeta for TZ6_zmix: [-4.4e-21]
# FDDN Solver Output: [[74.4 35.5 112 73.3 38.7 119 11.7 25.3 25.3 25.3 24.8 24.5 11.5 24.9 25.1 24.7 24.4 24.4]]
# New_Zeta_epsi for MTR-600: [5.11]
# New_Zeta_epsi for TZ6_zmix: [1.19e-21]
# FDDN Solver Output: [[74.2 35.4 112 73.2 38.7 119 11.7 25.3 25.2 25.3 24.7 24.4 11.4 24.9 25.1 24.7 24.4 24.4]]
# Row ID: [3]
# HoV: ['A4']
# FlowRate Difference (LTR - FDDN): [6.62] l/s
# Progress: 1.0% ... Training loss: 43.88... Training Iteration: 1
#
# NN output (C_f): [[1.55 -0.311]]
# MTR-Cf: 1.5520470290872153 , TZ6-zmix-Cf: -0.3112917725145872
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.55 0.311]]
# MTR-Cf: 1.5520470290872153
# |TZ6_zmix-Cf|: 0.3112917725145872
# New_Zeta for MTR-600: [5.01]
# New_Zeta for TZ6_zmix: [3.72e-22]
# FDDN Solver Output: [[74.6 35.6 112 73.6 38.9 120 11.8 25.4 25.4 25.4 24.9 24.5 11.5 25 25.2 24.8 24.5 24.5]]
# New_Zeta_epsi for MTR-600: [5.05]
# New_Zeta_epsi for TZ6_zmix: [-1.19e-22]
# FDDN Solver Output: [[74.5 35.5 112 73.4 38.8 120 11.8 25.4 25.3 25.4 24.8 24.5 11.5 25 25.2 24.8 24.5 24.5]]
# Row ID: [3]
# HoV: ['A4']
# FlowRate Difference (LTR - FDDN): [4.09] l/s
# % Diff between flowrates [0.56]
# Progress: 2.0% ... Training loss: 16.72... Training Iteration: 2
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for A4: [90.70903197994205, 43.889834280374416, 16.727100788574276]
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.44 -0.292]]
# MTR-Cf: 1.4447258674604275 , TZ6-zmix-Cf: -0.291684573849935
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.44 0.292]]
# MTR-Cf: 1.4447258674604275
# |TZ6_zmix-Cf|: 0.291684573849935
# New_Zeta for MTR-600: [6.13]
# New_Zeta for TZ6_zmix: [-3.48e-23]
# FDDN Solver Output: [[71.7 34.2 108 71 37.5 116 11.3 24.4 24.3 24.4 23.9 23.5 11 23.9 24.1 23.8 23.5 23.5]]
# New_Zeta_epsi for MTR-600: [6.18]
# New_Zeta_epsi for TZ6_zmix: [1.05e-23]
# FDDN Solver Output: [[71.6 34.1 108 70.9 37.4 115 11.3 24.3 24.3 24.3 23.8 23.5 11 23.9 24.1 23.7 23.4 23.4]]
# Row ID: [4]
# HoV: ['A5']
# FlowRate Difference (LTR - FDDN): [41.9] l/s
# Progress: 0.0% ... Training loss: 1758.... Training Iteration: 0
#
# NN output (C_f): [[1.03 -0.431]]
# MTR-Cf: 1.0320227203854788 , TZ6-zmix-Cf: -0.43062178803039625
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.03 0.431]]
# MTR-Cf: 1.0320227203854788
# |TZ6_zmix-Cf|: 0.43062178803039625
# New_Zeta for MTR-600: [4.38]
# New_Zeta for TZ6_zmix: [4.52e-24]
# FDDN Solver Output: [[78.5 37.5 118 77.7 41.1 127 12.4 26.7 26.6 26.7 26.1 25.8 12 26.2 26.4 26 25.7 25.7]]
# New_Zeta_epsi for MTR-600: [4.43]
# New_Zeta_epsi for TZ6_zmix: [-1.99e-24]
# FDDN Solver Output: [[78.3 37.4 118 77.5 41 126 12.3 26.6 26.5 26.6 26 25.7 12 26.1 26.3 25.9 25.6 25.6]]
# Row ID: [4]
# HoV: ['A5']
# FlowRate Difference (LTR - FDDN): [-24.2] l/s
# Progress: 1.0% ... Training loss: 586.0... Training Iteration: 1
#
# NN output (C_f): [[1.29 -0.367]]
# MTR-Cf: 1.2873322418602269 , TZ6-zmix-Cf: -0.36745550269585914
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.29 0.367]]
# MTR-Cf: 1.2873322418602269
# |TZ6_zmix-Cf|: 0.36745550269585914
# New_Zeta for MTR-600: [5.46]
# New_Zeta for TZ6_zmix: [-7.33e-25]
# FDDN Solver Output: [[74.1 35.4 112 73.4 38.8 120 11.7 25.2 25.1 25.2 24.6 24.3 11.4 24.7 24.9 24.5 24.2 24.2]]
# New_Zeta_epsi for MTR-600: [5.51]
# New_Zeta_epsi for TZ6_zmix: [2.76e-25]
# FDDN Solver Output: [[73.9 35.3 111 73.2 38.7 119 11.6 25.1 25.1 25.1 24.6 24.3 11.3 24.7 24.9 24.5 24.2 24.2]]
# Row ID: [4]
# HoV: ['A5']
# FlowRate Difference (LTR - FDDN): [18.8] l/s
# Progress: 2.0% ... Training loss: 352.2... Training Iteration: 2
#
# NN output (C_f): [[1.12 -0.438]]
# MTR-Cf: 1.1167624279129684 , TZ6-zmix-Cf: -0.4378108781249824
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.12 0.438]]
# MTR-Cf: 1.1167624279129684
# |TZ6_zmix-Cf|: 0.4378108781249824
# New_Zeta for MTR-600: [4.74]
# New_Zeta for TZ6_zmix: [1.21e-25]
# FDDN Solver Output: [[77 36.7 116 76.2 40.3 124 12.1 26.1 26.1 26.2 25.6 25.2 11.8 25.7 25.9 25.5 25.2 25.2]]
# New_Zeta_epsi for MTR-600: [4.79]
# New_Zeta_epsi for TZ6_zmix: [-5.42e-26]
# FDDN Solver Output: [[76.8 36.6 116 76 40.1 124 12.1 26.1 26 26.1 25.5 25.2 11.8 25.6 25.8 25.4 25.1 25.1]]
# Row ID: [4]
# HoV: ['A5']
# FlowRate Difference (LTR - FDDN): [-9.11] l/s
# Progress: 3.0% ... Training loss: 82.94... Training Iteration: 3
#
# NN output (C_f): [[1.22 -0.426]]
# MTR-Cf: 1.223512031510413 , TZ6-zmix-Cf: -0.42603177921029045
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.22 0.426]]
# MTR-Cf: 1.223512031510413
# |TZ6_zmix-Cf|: 0.42603177921029045
# New_Zeta for MTR-600: [5.19]
# New_Zeta for TZ6_zmix: [-2.31e-26]
# FDDN Solver Output: [[75.1 35.9 113 74.4 39.3 121 11.8 25.5 25.5 25.5 25 24.7 11.5 25.1 25.3 24.9 24.6 24.6]]
# New_Zeta_epsi for MTR-600: [5.24]
# New_Zeta_epsi for TZ6_zmix: [1.01e-26]
# FDDN Solver Output: [[75 35.8 113 74.2 39.2 121 11.8 25.5 25.4 25.5 24.9 24.6 11.5 25 25.2 24.8 24.5 24.5]]
# Row ID: [4]
# HoV: ['A5']
# FlowRate Difference (LTR - FDDN): [8.72] l/s
# Progress: 4.0% ... Training loss: 76.02... Training Iteration: 4
#
# NN output (C_f): [[1.16 -0.468]]
# MTR-Cf: 1.1591980528957275 , TZ6-zmix-Cf: -0.4676483656157342
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.16 0.468]]
# MTR-Cf: 1.1591980528957275
# |TZ6_zmix-Cf|: 0.4676483656157342
# New_Zeta for MTR-600: [4.92]
# New_Zeta for TZ6_zmix: [4.71e-27]
# FDDN Solver Output: [[76.2 36.4 115 75.5 39.9 123 12 25.9 25.8 25.9 25.3 25 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi for MTR-600: [4.97]
# New_Zeta_epsi for TZ6_zmix: [-2.25e-27]
# FDDN Solver Output: [[76 36.3 115 75.3 39.8 123 12 25.8 25.8 25.8 25.3 24.9 11.7 25.4 25.6 25.2 24.9 24.9]]
# Row ID: [4]
# HoV: ['A5']
# FlowRate Difference (LTR - FDDN): [-1.86] l/s
# % Diff between flowrates [0.25]
# Progress: 5.0% ... Training loss: 3.443... Training Iteration: 5
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for A5: [1758.0261617771366, 586.0115068813595, 352.22505389092765, 82.94066738998846, 76.02553944263923, 3.4429650159392633]
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.19 -0.475]]
# MTR-Cf: 1.1854525200406856 , TZ6-zmix-Cf: -0.47481187560229454
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.19 0.475]]
# MTR-Cf: 1.1854525200406856
# |TZ6_zmix-Cf|: 0.47481187560229454
# New_Zeta for MTR-600: [5.03]
# New_Zeta for TZ6_zmix: [-1.07e-27]
# FDDN Solver Output: [[75 35.8 113 73.9 39.1 120 11.8 25.5 25.5 25.5 25 24.7 11.6 25.1 25.4 24.9 24.6 24.6]]
# New_Zeta_epsi for MTR-600: [5.08]
# New_Zeta_epsi for TZ6_zmix: [5.18e-28]
# FDDN Solver Output: [[74.8 35.7 113 73.8 39 120 11.8 25.5 25.4 25.5 24.9 24.6 11.5 25.1 25.3 24.9 24.6 24.6]]
# Row ID: [5]
# HoV: ['A6']
# FlowRate Difference (LTR - FDDN): [12] l/s
# Progress: 0.0% ... Training loss: 143.0... Training Iteration: 0
# NN output (C_f): [[1.1 -0.523]]
# MTR-Cf: 1.0959365204593758 , TZ6-zmix-Cf: -0.5227279793138901
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.1 0.523]]
# MTR-Cf: 1.0959365204593758
# |TZ6_zmix-Cf|: 0.5227279793138901
# New_Zeta for MTR-600: [4.65]
# New_Zeta for TZ6_zmix: [2.71e-28]
# FDDN Solver Output: [[76.5 36.5 115 75.4 39.8 123 12.1 26 26 26.1 25.5 25.2 11.8 25.6 25.9 25.4 25.1 25.1]]
# New_Zeta_epsi for MTR-600: [4.7]
# New_Zeta_epsi for TZ6_zmix: [-1.44e-28]
# FDDN Solver Output: [[76.3 36.4 115 75.2 39.7 123 12 26 25.9 26 25.4 25.1 11.7 25.6 25.8 25.4 25.1 25.1]]
# Row ID: [5]
# HoV: ['A6']
# FlowRate Difference (LTR - FDDN): [-2.67] l/s
# % Diff between flowrates [0.358]
# Progress: 1.0% ... Training loss: 7.125... Training Iteration: 1
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for A6: [143.00648071254003, 7.125908620682836]
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.13 -0.527]]
# MTR-Cf: 1.1287434333449018 , TZ6-zmix-Cf: -0.5267296806223144
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.13 0.527]]
# MTR-Cf: 1.1287434333449018
# |TZ6_zmix-Cf|: 0.5267296806223144
# New_Zeta for MTR-600: [4.79]
# New_Zeta for TZ6_zmix: [-7.59e-29]
# FDDN Solver Output: [[76.3 36.4 115 75.2 39.7 123 12 26 25.9 26 25.4 25.1 11.8 25.6 25.8 25.4 25.1 25.1]]
# New_Zeta_epsi for MTR-600: [4.84]
# New_Zeta_epsi for TZ6_zmix: [4.08e-29]
# FDDN Solver Output: [[76.1 36.3 115 75 39.6 122 12 25.9 25.9 25.9 25.4 25 11.7 25.5 25.7 25.3 25 25]]
# Row ID: [6]
# HoV: ['C1']
# FlowRate Difference (LTR - FDDN): [-4.44] l/s
# % Diff between flowrates [0.598]
# Progress: 0.0% ... Training loss: 19.70... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for C1: [19.704986447094946]
# Old_Zeta: 3.9420929651694854
#
# NN output (C_f): [[1.27 -0.593]]
# MTR-Cf: 1.2726639665929038 , TZ6-zmix-Cf: -0.5931033599736303
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.27 0.593]]
# MTR-Cf: 1.2726639665929038
# |TZ6_zmix-Cf|: 0.5931033599736303
# New_Zeta for MTR-600: [4.3]
# New_Zeta for TZ6_zmix: [2.42e-29]
# FDDN Solver Output: [[79.7 38.1 120 77.3 40.8 126 12.5 26.9 26.9 26.9 26.3 26 12.1 26.3 26.5 26.1 25.7 25.8]]
# New_Zeta_epsi for MTR-600: [4.34]
# New_Zeta_epsi for TZ6_zmix: [-1.46e-29]
# FDDN Solver Output: [[79.6 38 120 77.1 40.8 126 12.4 26.9 26.8 26.9 26.3 25.9 12.1 26.2 26.4 26 25.7 25.7]]
# Row ID: [7]
# HoV: ['C2']
# FlowRate Difference (LTR - FDDN): [-27.5] l/s
# Progress: 0.0% ... Training loss: 754.9... Training Iteration: 0
#
# NN output (C_f): [[1.53 -0.51]]
# MTR-Cf: 1.528730279965629 , TZ6-zmix-Cf: -0.5100711420714248
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.53 0.51]]
# MTR-Cf: 1.528730279965629
# |TZ6_zmix-Cf|: 0.5100711420714248
# New_Zeta for MTR-600: [5.17]
# New_Zeta for TZ6_zmix: [-7.44e-30]
# FDDN Solver Output: [[76.2 36.3 115 73.8 39 120 11.9 25.7 25.7 25.7 25.2 24.8 11.5 25.1 25.3 24.9 24.6 24.6]]
# New_Zeta_epsi for MTR-600: [5.21]
# New_Zeta_epsi for TZ6_zmix: [3.87e-30]
# FDDN Solver Output: [[76 36.3 115 73.7 38.9 120 11.9 25.7 25.6 25.7 25.1 24.8 11.5 25.1 25.3 24.9 24.5 24.6]]
# Row ID: [7]
# HoV: ['C2']
# FlowRate Difference (LTR - FDDN): [7.06] l/s
# Progress: 1.0% ... Training loss: 49.85... Training Iteration: 1
#
# NN output (C_f): [[1.51 -0.556]]
# MTR-Cf: 1.5091688848310603 , TZ6-zmix-Cf: -0.5557266725194471
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.51 0.556]]
# MTR-Cf: 1.5091688848310603
# |TZ6_zmix-Cf|: 0.5557266725194471
# New_Zeta for MTR-600: [5.1]
# New_Zeta for TZ6_zmix: [2.15e-30]
# FDDN Solver Output: [[76.4 36.5 115 74.1 39.1 121 11.9 25.8 25.7 25.8 25.2 24.9 11.6 25.2 25.4 25 24.7 24.7]]
# New_Zeta_epsi for MTR-600: [5.14]
# New_Zeta_epsi for TZ6_zmix: [-1.22e-30]
# FDDN Solver Output: [[76.3 36.4 115 73.9 39.1 120 11.9 25.7 25.7 25.8 25.2 24.9 11.6 25.1 25.4 24.9 24.6 24.6]]
# Row ID: [7]
# HoV: ['C2']
# FlowRate Difference (LTR - FDDN): [4.58] l/s
# % Diff between flowrates [0.619]
# Progress: 2.0% ... Training loss: 21.01... Training Iteration: 2
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for C2: [754.9265445195392, 49.85055502343078, 21.019370186483393]
# Old_Zeta: 4.127180457922134
#
# NN output (C_f): [[1.49 -0.579]]
# MTR-Cf: 1.4867379300870995 , TZ6-zmix-Cf: -0.5786979819928993
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.49 0.579]]
# MTR-Cf: 1.4867379300870995
# |TZ6_zmix-Cf|: 0.5786979819928993
# New_Zeta for MTR-600: [5.26]
# New_Zeta for TZ6_zmix: [-7.04e-31]
# FDDN Solver Output: [[76.1 36.3 115 73.8 39 120 11.8 25.5 25.4 25.5 24.9 24.6 11.5 25.1 25.3 24.9 24.6 24.6]]
# New_Zeta_epsi for MTR-600: [5.3]
# New_Zeta_epsi for TZ6_zmix: [4.14e-31]
# FDDN Solver Output: [[75.9 36.2 114 73.6 38.9 120 11.8 25.4 25.4 25.4 24.9 24.6 11.5 25 25.2 24.8 24.5 24.5]]
# Row ID: [8]
# HoV: ['C3']
# FlowRate Difference (LTR - FDDN): [6.02] l/s
# Progress: 0.0% ... Training loss: 36.21... Training Iteration: 0
#
# NN output (C_f): [[1.47 -0.62]]
# MTR-Cf: 1.4739941014372944 , TZ6-zmix-Cf: -0.6200015810886726
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.47 0.62]]
# MTR-Cf: 1.4739941014372944
# |TZ6_zmix-Cf|: 0.6200015810886726
# New_Zeta for MTR-600: [5.22]
# New_Zeta for TZ6_zmix: [2.57e-31]
# FDDN Solver Output: [[76.3 36.4 115 73.9 39 120 11.8 25.5 25.5 25.6 25 24.7 11.5 25.1 25.3 24.9 24.6 24.6]]
# New_Zeta_epsi for MTR-600: [5.26]
# New_Zeta_epsi for TZ6_zmix: [-1.62e-31]
# FDDN Solver Output: [[76.1 36.3 115 73.8 39 120 11.8 25.5 25.4 25.5 24.9 24.6 11.5 25.1 25.3 24.9 24.6 24.6]]
# Row ID: [8]
# HoV: ['C3']
# FlowRate Difference (LTR - FDDN): [4.37] l/s
# % Diff between flowrates [0.593]
# Progress: 1.0% ... Training loss: 19.12... Training Iteration: 1
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for C3: [36.21883683284398, 19.12619440584831]
# Old_Zeta: 4.521188627716888
#
# NN output (C_f): [[1.47 -0.64]]
# MTR-Cf: 1.4662539706121753 , TZ6-zmix-Cf: -0.6396766054972272
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.47 0.64]]
# MTR-Cf: 1.4662539706121753
# |TZ6_zmix-Cf|: 0.6396766054972272
# New_Zeta for MTR-600: [5.68]
# New_Zeta for TZ6_zmix: [-1.04e-31]
# FDDN Solver Output: [[72.5 34.6 109 71.5 37.7 116 11.4 24.7 24.6 24.7 24.2 23.8 11.2 24.3 24.5 24.1 23.8 23.8]]
# New_Zeta_epsi for MTR-600: [5.73]
# New_Zeta_epsi for TZ6_zmix: [6.73e-32]
# FDDN Solver Output: [[72.3 34.5 109 71.3 37.7 116 11.4 24.6 24.6 24.6 24.1 23.8 11.1 24.3 24.5 24.1 23.8 23.8]]
# Row ID: [9]
# HoV: ['C4']
# FlowRate Difference (LTR - FDDN): [32.7] l/s
# Progress: 0.0% ... Training loss: 1069.... Training Iteration: 0
#
# NN output (C_f): [[1.24 -0.759]]
# MTR-Cf: 1.2377403015232045 , TZ6-zmix-Cf: -0.7585069054684815
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.24 0.759]]
# MTR-Cf: 1.2377403015232045
# |TZ6_zmix-Cf|: 0.7585069054684815
# New_Zeta for MTR-600: [4.8]
# New_Zeta for TZ6_zmix: [5.1e-32]
# FDDN Solver Output: [[75.7 36.1 114 74.7 39.5 122 12 25.8 25.8 25.8 25.3 24.9 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi for MTR-600: [4.84]
# New_Zeta_epsi for TZ6_zmix: [-3.92e-32]
# FDDN Solver Output: [[75.6 36.1 114 74.5 39.4 121 11.9 25.7 25.7 25.8 25.2 24.9 11.6 25.3 25.6 25.1 24.8 24.8]]
# Row ID: [9]
# HoV: ['C4']
# FlowRate Difference (LTR - FDDN): [0.654] l/s
# % Diff between flowrates [0.0884]
# Progress: 1.0% ... Training loss: 0.427... Training Iteration: 1
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for C4: [1069.4739708736997, 0.4276309885016141]
# Old_Zeta: 4.127180457922134
#
# NN output (C_f): [[1.28 -0.797]]
# MTR-Cf: 1.2776474438735268 , TZ6-zmix-Cf: -0.7970324551368041
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.28 0.797]]
# MTR-Cf: 1.2776474438735268
# |TZ6_zmix-Cf|: 0.7970324551368041
# New_Zeta for MTR-600: [4.52]
# New_Zeta for TZ6_zmix: [-3.12e-32]
# FDDN Solver Output: [[77.1 36.8 116 76 40.1 124 12.3 26.6 26.5 26.6 26 25.6 11.9 25.8 26.1 25.6 25.3 25.3]]
# New_Zeta_epsi for MTR-600: [4.56]
# New_Zeta_epsi for TZ6_zmix: [2.52e-32]
# FDDN Solver Output: [[76.9 36.7 116 75.8 40.1 124 12.3 26.5 26.4 26.5 25.9 25.6 11.8 25.8 26 25.6 25.3 25.3]]
# Row ID: [10]
# HoV: ['C5']
# FlowRate Difference (LTR - FDDN): [-26.5] l/s
# Progress: 0.0% ... Training loss: 700.5... Training Iteration: 0
# NN output (C_f): [[1.49 -0.702]]
# MTR-Cf: 1.4930418721715184 , TZ6-zmix-Cf: -0.7017709375738066
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.49 0.702]]
# MTR-Cf: 1.4930418721715184
# |TZ6_zmix-Cf|: 0.7017709375738066
# New_Zeta for MTR-600: [5.28]
# New_Zeta for TZ6_zmix: [1.77e-32]
# FDDN Solver Output: [[74.1 35.3 112 73 38.6 119 11.8 25.5 25.5 25.5 25 24.7 11.4 24.8 25.1 24.6 24.3 24.3]]
# New_Zeta_epsi for MTR-600: [5.32]
# New_Zeta_epsi for TZ6_zmix: [-1.26e-32]
# FDDN Solver Output: [[73.9 35.3 111 72.9 38.5 119 11.8 25.5 25.4 25.5 24.9 24.6 11.4 24.8 25 24.6 24.3 24.3]]
# Row ID: [10]
# HoV: ['C5']
# FlowRate Difference (LTR - FDDN): [2.73] l/s
# % Diff between flowrates [0.376]
# Progress: 1.0% ... Training loss: 7.466... Training Iteration: 1
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for C5: [700.5032084821667, 7.466294175162057]
# Old_Zeta: 3.7645035449506787
#
# NN output (C_f): [[1.54 -0.76]]
# MTR-Cf: 1.5443316922850387 , TZ6-zmix-Cf: -0.7596873508135
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.54 0.76]]
# MTR-Cf: 1.5443316922850387
# |TZ6_zmix-Cf|: 0.7596873508135
# New_Zeta for MTR-600: [4.98]
# New_Zeta for TZ6_zmix: [-9.57e-33]
# FDDN Solver Output: [[76.4 36.5 115 74.1 39.1 121 12.1 26 26 26 25.5 25.1 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi for MTR-600: [5.02]
# New_Zeta_epsi for TZ6_zmix: [7.36e-33]
# FDDN Solver Output: [[76.2 36.4 115 73.9 39 120 12 26 25.9 26 25.4 25.1 11.6 25.4 25.6 25.1 24.8 24.9]]
# Row ID: [11]
# HoV: ['C6']
# FlowRate Difference (LTR - FDDN): [13.5] l/s
# Progress: 0.0% ... Training loss: 181.5... Training Iteration: 0
#
# NN output (C_f): [[1.48 -0.828]]
# MTR-Cf: 1.4814335599752086 , TZ6-zmix-Cf: -0.8283086152858807
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.48 0.828]]
# MTR-Cf: 1.4814335599752086
# |TZ6_zmix-Cf|: 0.8283086152858807
# New_Zeta for MTR-600: [4.78]
# New_Zeta for TZ6_zmix: [6.1e-33]
# FDDN Solver Output: [[77.2 36.8 116 74.9 39.5 122 12.2 26.3 26.2 26.3 25.7 25.4 11.8 25.7 25.9 25.5 25.2 25.2]]
# New_Zeta_epsi for MTR-600: [4.82]
# New_Zeta_epsi for TZ6_zmix: [-5.11e-33]
# FDDN Solver Output: [[77.1 36.8 116 74.7 39.5 122 12.2 26.2 26.2 26.3 25.7 25.3 11.8 25.6 25.8 25.4 25.1 25.1]]
# Row ID: [11]
# HoV: ['C6']
# FlowRate Difference (LTR - FDDN): [5.54] l/s
# % Diff between flowrates [0.738]
# Progress: 1.0% ... Training loss: 30.71... Training Iteration: 1
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for C6: [181.5689837069156, 30.713407748181822]
# Old_Zeta: 4.32009667071488
#
# NN output (C_f): [[1.44 -0.83]]
# MTR-Cf: 1.4361179767718524 , TZ6-zmix-Cf: -0.8302225584951208
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.44 0.83]]
# MTR-Cf: 1.4361179767718524
# |TZ6_zmix-Cf|: 0.8302225584951208
# New_Zeta for MTR-600: [5.32]
# New_Zeta for TZ6_zmix: [-4.25e-33]
# FDDN Solver Output: [[74.5 35.6 112 73.5 38.8 120 11.8 25.4 25.3 25.4 24.9 24.5 11.5 25 25.2 24.8 24.5 24.5]]
# New_Zeta_epsi for MTR-600: [5.36]
# New_Zeta_epsi for TZ6_zmix: [3.57e-33]
# FDDN Solver Output: [[74.4 35.5 112 73.3 38.7 120 11.7 25.3 25.3 25.3 24.8 24.5 11.5 24.9 25.2 24.7 24.4 24.4]]
# Row ID: [12]
# HoV: ['D1']
# FlowRate Difference (LTR - FDDN): [26.8] l/s
# Progress: 0.0% ... Training loss: 719.9... Training Iteration: 0
#
# NN output (C_f): [[1.27 -0.947]]
# MTR-Cf: 1.2700431456997012 , TZ6-zmix-Cf: -0.9465120289084349
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.27 0.947]]
# MTR-Cf: 1.2700431456997012
# |TZ6_zmix-Cf|: 0.9465120289084349
# New_Zeta for MTR-600: [4.7]
# New_Zeta for TZ6_zmix: [3.38e-33]
# FDDN Solver Output: [[76.9 36.7 116 75.9 40.1 124 12.1 26.2 26.2 26.2 25.6 25.3 11.9 25.8 26 25.6 25.3 25.3]]
# New_Zeta_epsi for MTR-600: [4.75]
# New_Zeta_epsi for TZ6_zmix: [-3.23e-33]
# FDDN Solver Output: [[76.7 36.6 116 75.7 40 123 12.1 26.1 26.1 26.2 25.6 25.2 11.8 25.7 26 25.5 25.2 25.2]]
# Row ID: [12]
# HoV: ['D1']
# FlowRate Difference (LTR - FDDN): [3.57] l/s
# % Diff between flowrates [0.475]
# Progress: 1.0% ... Training loss: 12.75... Training Iteration: 1
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for D1: [719.9009628785799, 12.755779858266996]
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.21 -0.912]]
# MTR-Cf: 1.2076052466522935 , TZ6-zmix-Cf: -0.9122530029737851
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.21 0.912]]
# MTR-Cf: 1.2076052466522935
# |TZ6_zmix-Cf|: 0.9122530029737851
# New_Zeta for MTR-600: [5.12]
# New_Zeta for TZ6_zmix: [-2.95e-33]
# FDDN Solver Output: [[77.2 36.3 111 76.9 39.5 118 11.7 25.2 25.2 25.2 24.7 24.3 11.4 24.8 25 24.6 24.3 24.3]]
# New_Zeta_epsi for MTR-600: [5.17]
# New_Zeta_epsi for TZ6_zmix: [2.72e-33]
# FDDN Solver Output: [[77 36.2 111 76.7 39.4 118 11.7 25.1 25.1 25.2 24.6 24.3 11.4 24.7 24.9 24.5 24.2 24.2]]
# Row ID: [13]
# HoV: ['D2']
# FlowRate Difference (LTR - FDDN): [7.43] l/s
# Progress: 0.0% ... Training loss: 55.25... Training Iteration: 0
#
# NN output (C_f): [[1.17 -0.955]]
# MTR-Cf: 1.1734819520667261 , TZ6-zmix-Cf: -0.955405131198522
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.17 0.955]]
# MTR-Cf: 1.1734819520667261
# |TZ6_zmix-Cf|: 0.955405131198522
# New_Zeta for MTR-600: [4.98]
# New_Zeta for TZ6_zmix: [2.6e-33]
# FDDN Solver Output: [[77.7 36.6 112 77.5 39.8 119 11.8 25.4 25.3 25.4 24.9 24.5 11.5 25 25.2 24.8 24.5 24.5]]
# New_Zeta_epsi for MTR-600: [5.03]
# New_Zeta_epsi for TZ6_zmix: [-2.51e-33]
# FDDN Solver Output: [[77.5 36.5 112 77.3 39.7 119 11.7 25.3 25.3 25.3 24.8 24.5 11.4 24.9 25.1 24.7 24.4 24.4]]
# Row ID: [13]
# HoV: ['D2']
# FlowRate Difference (LTR - FDDN): [2.04] l/s
# % Diff between flowrates [0.277]
# Progress: 1.0% ... Training loss: 4.155... Training Iteration: 1
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for D2: [55.25209686927325, 4.155844355095047]
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.17 -0.97]]
# MTR-Cf: 1.1694417445088265 , TZ6-zmix-Cf: -0.9697869166483278
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.17 0.97]]
# MTR-Cf: 1.1694417445088265
# |TZ6_zmix-Cf|: 0.9697869166483278
# New_Zeta for MTR-600: [4.96]
# New_Zeta for TZ6_zmix: [-2.43e-33]
# FDDN Solver Output: [[75.7 36.1 114 74.6 39.4 122 11.9 25.8 25.7 25.8 25.2 24.9 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi for MTR-600: [5.01]
# New_Zeta_epsi for TZ6_zmix: [2.38e-33]
# FDDN Solver Output: [[75.5 36 114 74.4 39.3 121 11.9 25.7 25.7 25.7 25.2 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# Row ID: [14]
# HoV: ['E1']
# FlowRate Difference (LTR - FDDN): [-2.68] l/s
# % Diff between flowrates [0.363]
# Progress: 0.0% ... Training loss: 7.158... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for E1: [7.158864901546498]
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.19 -0.941]]
# MTR-Cf: 1.1888713221780391 , TZ6-zmix-Cf: -0.9408257491735627
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.19 0.941]]
# MTR-Cf: 1.1888713221780391
# |TZ6_zmix-Cf|: 0.9408257491735627
# New_Zeta for MTR-600: [5.04]
# New_Zeta for TZ6_zmix: [2.24e-33]
# FDDN Solver Output: [[75.3 35.9 114 74.2 39.2 121 11.9 25.6 25.6 25.7 25.1 24.8 11.6 25.2 25.5 25 24.7 24.7]]
# New_Zeta_epsi for MTR-600: [5.09]
# New_Zeta_epsi for TZ6_zmix: [-2.13e-33]
# FDDN Solver Output: [[75.1 35.8 113 74.1 39.1 121 11.8 25.6 25.5 25.6 25 24.7 11.6 25.2 25.4 25 24.7 24.7]]
# Row ID: [15]
# HoV: ['E2']
# FlowRate Difference (LTR - FDDN): [-64] l/s
# Progress: 0.0% ... Training loss: 4090.... Training Iteration: 0
#
# NN output (C_f): [[1.61 -0.625]]
# MTR-Cf: 1.611601026105729 , TZ6-zmix-Cf: -0.6253403957543392
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.61 0.625]]
# MTR-Cf: 1.611601026105729
# |TZ6_zmix-Cf|: 0.6253403957543392
# New_Zeta for MTR-600: [6.84]
# New_Zeta for TZ6_zmix: [-1.33e-33]
# FDDN Solver Output: [[69.2 33 104 68.3 36.1 111 10.9 23.6 23.5 23.6 23.1 22.8 10.7 23.2 23.4 23 22.7 22.8]]
# New_Zeta_epsi for MTR-600: [6.89]
# New_Zeta_epsi for TZ6_zmix: [8.46e-34]
# FDDN Solver Output: [[69.1 33 104 68.1 36 111 10.9 23.5 23.5 23.5 23 22.7 10.6 23.2 23.4 23 22.7 22.7]]
# Row ID: [15]
# HoV: ['E2']
# FlowRate Difference (LTR - FDDN): [-4.77] l/s
# % Diff between flowrates [0.709]
# Progress: 1.0% ... Training loss: 22.75... Training Iteration: 1
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for E2: [4090.527527680384, 22.75900897872221]
# Old_Zeta: 5.4148802645163
#
# NN output (C_f): [[1.69 -0.623]]
# MTR-Cf: 1.6891924788614008 , TZ6-zmix-Cf: -0.6227103044333142
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.69 0.623]]
# MTR-Cf: 1.6891924788614008
# |TZ6_zmix-Cf|: 0.6227103044333142
# New_Zeta for MTR-600: [7.84]
# New_Zeta for TZ6_zmix: [5.27e-34]
# FDDN Solver Output: [[66.2 31.6 99.8 65.3 34.5 106 10.5 22.6 22.5 22.6 22.1 21.8 10.2 22.2 22.4 22 21.8 21.8]]
# New_Zeta_epsi for MTR-600: [7.9]
# New_Zeta_epsi for TZ6_zmix: [-3.33e-34]
# FDDN Solver Output: [[66.1 31.5 99.6 65.1 34.4 106 10.4 22.5 22.5 22.5 22 21.7 10.2 22.2 22.4 22 21.7 21.7]]
# Row ID: [16]
# HoV: ['F1']
# FlowRate Difference (LTR - FDDN): [75.3] l/s
# Progress: 0.0% ... Training loss: 5665.... Training Iteration: 0
#
# NN output (C_f): [[1.12 -0.796]]
# MTR-Cf: 1.1181370026660207 , TZ6-zmix-Cf: -0.7961769182438221
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.12 0.796]]
# MTR-Cf: 1.1181370026660207
# |TZ6_zmix-Cf|: 0.7961769182438221
# New_Zeta for MTR-600: [5.19]
# New_Zeta for TZ6_zmix: [-2.65e-34]
# FDDN Solver Output: [[74.5 35.6 112 73.5 38.8 120 11.8 25.4 25.3 25.4 24.9 24.5 11.5 25 25.2 24.8 24.5 24.5]]
# New_Zeta_epsi for MTR-600: [5.24]
# New_Zeta_epsi for TZ6_zmix: [2.14e-34]
# FDDN Solver Output: [[74.3 35.5 112 73.3 38.7 119 11.7 25.3 25.3 25.3 24.8 24.4 11.5 24.9 25.1 24.7 24.4 24.4]]
# Row ID: [16]
# HoV: ['F1']
# FlowRate Difference (LTR - FDDN): [-5.68] l/s
# Progress: 1.0% ... Training loss: 32.29... Training Iteration: 1
#
# NN output (C_f): [[1.17 -0.788]]
# MTR-Cf: 1.1659029619800645 , TZ6-zmix-Cf: -0.7882815674927617
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.17 0.788]]
# MTR-Cf: 1.1659029619800645
# |TZ6_zmix-Cf|: 0.7882815674927617
# New_Zeta for MTR-600: [5.41]
# New_Zeta for TZ6_zmix: [1.69e-34]
# FDDN Solver Output: [[73.7 35.2 111 72.7 38.4 118 11.6 25.1 25.1 25.1 24.6 24.2 11.4 24.7 24.9 24.5 24.2 24.2]]
# New_Zeta_epsi for MTR-600: [5.47]
# New_Zeta_epsi for TZ6_zmix: [-1.35e-34]
# FDDN Solver Output: [[73.5 35.1 111 72.5 38.3 118 11.6 25 25 25.1 24.5 24.2 11.3 24.6 24.9 24.5 24.2 24.2]]
# Row ID: [16]
# HoV: ['F1']
# FlowRate Difference (LTR - FDDN): [2.27] l/s
# % Diff between flowrates [0.315]
# Progress: 2.0% ... Training loss: 5.143... Training Iteration: 2
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for F1: [5665.397289967064, 32.29947958987008, 5.143636754106003]
# Old_Zeta: 5.4148802645163
#
# NN output (C_f): [[1.16 -0.802]]
# MTR-Cf: 1.1588581820805335 , TZ6-zmix-Cf: -0.8020905546105531
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.16 0.802]]
# MTR-Cf: 1.1588581820805335
# |TZ6_zmix-Cf|: 0.8020905546105531
# New_Zeta for MTR-600: [5.38]
# New_Zeta for TZ6_zmix: [-1.08e-34]
# FDDN Solver Output: [[73.7 35.2 111 72.6 38.4 118 11.6 25.1 25 25.1 24.6 24.2 11.4 24.7 24.9 24.5 24.2 24.2]]
# New_Zeta_epsi for MTR-600: [5.43]
# New_Zeta_epsi for TZ6_zmix: [8.77e-35]
# FDDN Solver Output: [[73.5 35.1 111 72.4 38.3 118 11.6 25 25 25 24.5 24.2 11.3 24.6 24.8 24.4 24.1 24.1]]
# Row ID: [17]
# HoV: ['F2']
# FlowRate Difference (LTR - FDDN): [2.57] l/s
# % Diff between flowrates [0.356]
# Progress: 0.0% ... Training loss: 6.581... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for F2: [6.581554915046528]
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.21 -0.874]]
# MTR-Cf: 1.2143249153357547 , TZ6-zmix-Cf: -0.8738303364307326
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.21 0.874]]
# MTR-Cf: 1.2143249153357547
# |TZ6_zmix-Cf|: 0.8738303364307326
# New_Zeta for MTR-600: [5.15]
# New_Zeta for TZ6_zmix: [7.67e-35]
# FDDN Solver Output: [[75.7 36.1 114 74.1 39.1 121 12 25.9 25.8 25.9 25.3 25 11.6 25.2 25.4 25 24.7 24.7]]
# New_Zeta_epsi for MTR-600: [5.2]
# New_Zeta_epsi for TZ6_zmix: [-6.78e-35]
# FDDN Solver Output: [[75.5 36 114 73.9 39 120 11.9 25.8 25.7 25.8 25.3 24.9 11.5 25.1 25.3 24.9 24.6 24.6]]
# Row ID: [18]
# HoV: ['F3']
# FlowRate Difference (LTR - FDDN): [6.01] l/s
# Progress: 0.0% ... Training loss: 36.14... Training Iteration: 0
#
# NN output (C_f): [[1.19 -0.907]]
# MTR-Cf: 1.1938313571001473 , TZ6-zmix-Cf: -0.9071413951355808
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.19 0.907]]
# MTR-Cf: 1.1938313571001473
# |TZ6_zmix-Cf|: 0.9071413951355808
# New_Zeta for MTR-600: [5.07]
# New_Zeta for TZ6_zmix: [-6.15e-35]
# FDDN Solver Output: [[76 36.3 115 74.4 39.3 121 12 26 25.9 26 25.4 25.1 11.6 25.3 25.5 25.1 24.8 24.8]]
# New_Zeta_epsi for MTR-600: [5.11]
# New_Zeta_epsi for TZ6_zmix: [5.64e-35]
# FDDN Solver Output: [[75.8 36.2 114 74.2 39.2 121 12 25.9 25.9 25.9 25.4 25 11.6 25.2 25.4 25 24.7 24.7]]
# Row ID: [18]
# HoV: ['F3']
# FlowRate Difference (LTR - FDDN): [2.67] l/s
# % Diff between flowrates [0.36]
# Progress: 1.0% ... Training loss: 7.104... Training Iteration: 1
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for F3: [36.143766148635294, 7.104361331458886]
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.19 -0.923]]
# MTR-Cf: 1.187422993206321 , TZ6-zmix-Cf: -0.923121367916607
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.19 0.923]]
# MTR-Cf: 1.187422993206321
# |TZ6_zmix-Cf|: 0.923121367916607
# New_Zeta for MTR-600: [5.04]
# New_Zeta for TZ6_zmix: [5.2e-35]
# FDDN Solver Output: [[75.9 36.2 114 75.2 39.7 123 12 25.8 25.8 25.8 25.3 24.9 11.7 25.4 25.6 25.1 24.8 24.8]]
# New_Zeta_epsi for MTR-600: [5.09]
# New_Zeta_epsi for TZ6_zmix: [-4.86e-35]
# FDDN Solver Output: [[75.8 36.1 114 75 39.6 122 11.9 25.7 25.7 25.7 25.2 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# Row ID: [19]
# HoV: ['H1']
# FlowRate Difference (LTR - FDDN): [-4.15] l/s
# % Diff between flowrates [0.562]
# Progress: 0.0% ... Training loss: 17.23... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for H1: [17.239837886233747]
# Old_Zeta: 4.127180457922134
#
# NN output (C_f): [[1.29 -0.976]]
# MTR-Cf: 1.2876828952895645 , TZ6-zmix-Cf: -0.975682524440431
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.29 0.976]]
# MTR-Cf: 1.2876828952895645
# |TZ6_zmix-Cf|: 0.975682524440431
# New_Zeta for MTR-600: [4.56]
# New_Zeta for TZ6_zmix: [-4.74e-35]
# FDDN Solver Output: [[77.3 36.9 117 76.2 40.3 124 12.3 26.5 26.5 26.5 26 25.6 12.2 26.6 26.9 26.4 26.1 26.1]]
# New_Zeta_epsi for MTR-600: [4.6]
# New_Zeta_epsi for TZ6_zmix: [4.67e-35]
# FDDN Solver Output: [[77.1 36.8 116 76.1 40.2 124 12.3 26.5 26.4 26.5 25.9 25.6 12.2 26.6 26.8 26.4 26 26.1]]
# Row ID: [20]
# HoV: ['I1']
# FlowRate Difference (LTR - FDDN): [-32.3] l/s
# Progress: 0.0% ... Training loss: 1045.... Training Iteration: 0
#
# NN output (C_f): [[1.5 -0.847]]
# MTR-Cf: 1.497418904859093 , TZ6-zmix-Cf: -0.8470455148955549
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.5 0.847]]
# MTR-Cf: 1.497418904859093
# |TZ6_zmix-Cf|: 0.8470455148955549
# New_Zeta for MTR-600: [5.3]
# New_Zeta for TZ6_zmix: [3.96e-35]
# FDDN Solver Output: [[74.4 35.5 112 73.3 38.7 120 11.8 25.5 25.5 25.5 25 24.7 11.8 25.6 25.9 25.4 25.1 25.1]]
# New_Zeta_epsi for MTR-600: [5.34]
# New_Zeta_epsi for TZ6_zmix: [-3.39e-35]
# FDDN Solver Output: [[74.2 35.4 112 73.2 38.7 119 11.8 25.5 25.4 25.5 25 24.6 11.8 25.6 25.8 25.4 25.1 25.1]]
# Row ID: [20]
# HoV: ['I1']
# FlowRate Difference (LTR - FDDN): [-3.61] l/s
# % Diff between flowrates [0.495]
# Progress: 1.0% ... Training loss: 13.01... Training Iteration: 1
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for I1: [1045.2714359817157, 13.01041254686322]
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.48 -0.79]]
# MTR-Cf: 1.4785179049122945 , TZ6-zmix-Cf: -0.7904433152526466
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.48 0.79]]
# MTR-Cf: 1.4785179049122945
# |TZ6_zmix-Cf|: 0.7904433152526466
# New_Zeta for MTR-600: [6.27]
# New_Zeta for TZ6_zmix: [-2.68e-35]
# FDDN Solver Output: [[70.9 33.9 107 70 37 114 11.2 24.2 24.1 24.2 23.7 23.3 10.9 23.8 24 23.6 23.3 23.3]]
# New_Zeta_epsi for MTR-600: [6.32]
# New_Zeta_epsi for TZ6_zmix: [2.14e-35]
# FDDN Solver Output: [[70.8 33.8 107 69.8 36.9 114 11.2 24.1 24.1 24.1 23.6 23.3 10.9 23.7 23.9 23.6 23.3 23.3]]
# Row ID: [21]
# HoV: ['J1']
# FlowRate Difference (LTR - FDDN): [15.4] l/s
# Progress: 0.0% ... Training loss: 237.9... Training Iteration: 0
# NN output (C_f): [[1.41 -0.851]]
# MTR-Cf: 1.4077069899739516 , TZ6-zmix-Cf: -0.8508330548183908
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.41 0.851]]
# MTR-Cf: 1.4077069899739516
# |TZ6_zmix-Cf|: 0.8508330548183908
# New_Zeta for MTR-600: [5.97]
# New_Zeta for TZ6_zmix: [1.82e-35]
# FDDN Solver Output: [[71.9 34.3 108 70.9 37.5 116 11.4 24.5 24.5 24.5 24 23.7 11.1 24.1 24.3 23.9 23.6 23.6]]
# New_Zeta_epsi for MTR-600: [6.02]
# New_Zeta_epsi for TZ6_zmix: [-1.57e-35]
# FDDN Solver Output: [[71.8 34.2 108 70.8 37.4 115 11.3 24.4 24.4 24.5 23.9 23.6 11.1 24.1 24.3 23.9 23.6 23.6]]
# Row ID: [21]
# HoV: ['J1']
# FlowRate Difference (LTR - FDDN): [5.79] l/s
# Progress: 1.0% ... Training loss: 33.56... Training Iteration: 1
#
# NN output (C_f): [[1.4 -0.885]]
# MTR-Cf: 1.4014361325652442 , TZ6-zmix-Cf: -0.8851810465326901
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.4 0.885]]
# MTR-Cf: 1.4014361325652442
# |TZ6_zmix-Cf|: 0.8851810465326901
# New_Zeta for MTR-600: [5.95]
# New_Zeta for TZ6_zmix: [-1.39e-35]
# FDDN Solver Output: [[72 34.4 109 71 37.5 116 11.4 24.5 24.5 24.5 24 23.7 11.1 24.2 24.4 24 23.7 23.7]]
# New_Zeta_epsi for MTR-600: [6]
# New_Zeta_epsi for TZ6_zmix: [1.24e-35]
# FDDN Solver Output: [[71.9 34.3 108 70.9 37.4 115 11.3 24.5 24.4 24.5 24 23.6 11.1 24.1 24.3 23.9 23.6 23.6]]
# Row ID: [21]
# HoV: ['J1']
# FlowRate Difference (LTR - FDDN): [4.93] l/s
# % Diff between flowrates [0.699]
# Progress: 2.0% ... Training loss: 24.29... Training Iteration: 2
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for J1: [237.94651725858276, 33.56304398495674, 24.296977305467127]
# Old_Zeta: 3.7645035449506787
#
# NN output (C_f): [[1.52 -1.03]]
# MTR-Cf: 1.5224286687640718 , TZ6-zmix-Cf: -1.026225677762162
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.52 1.03]]
# MTR-Cf: 1.5224286687640718
# |TZ6_zmix-Cf|: 1.026225677762162
# New_Zeta for MTR-600: [4.91]
# New_Zeta for TZ6_zmix: [1.28e-35]
# FDDN Solver Output: [[75.6 36.1 114 74.5 39.4 121 11.9 25.7 25.7 25.8 25.2 24.9 11.6 25.3 25.6 25.1 24.8 24.8]]
# New_Zeta_epsi for MTR-600: [4.95]
# New_Zeta_epsi for TZ6_zmix: [-1.32e-35]
# FDDN Solver Output: [[75.4 36 114 74.4 39.3 121 11.9 25.7 25.6 25.7 25.2 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# Row ID: [22]
# HoV: ['M1']
# FlowRate Difference (LTR - FDDN): [18.4] l/s
# Progress: 0.0% ... Training loss: 338.4... Training Iteration: 0
#
# NN output (C_f): [[1.44 -1.11]]
# MTR-Cf: 1.4440859840337352 , TZ6-zmix-Cf: -1.1096439946509864
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.44 1.11]]
# MTR-Cf: 1.4440859840337352
# |TZ6_zmix-Cf|: 1.1096439946509864
# New_Zeta for MTR-600: [4.66]
# New_Zeta for TZ6_zmix: [-1.47e-35]
# FDDN Solver Output: [[76.6 36.5 115 75.5 39.9 123 12.1 26.1 26 26.1 25.5 25.2 11.8 25.7 25.9 25.5 25.2 25.2]]
# New_Zeta_epsi for MTR-600: [4.7]
# New_Zeta_epsi for TZ6_zmix: [1.64e-35]
# FDDN Solver Output: [[76.4 36.5 115 75.4 39.8 123 12.1 26 26 26 25.5 25.1 11.8 25.6 25.8 25.4 25.1 25.1]]
# Row ID: [22]
# HoV: ['M1']
# FlowRate Difference (LTR - FDDN): [8.56] l/s
# Progress: 1.0% ... Training loss: 73.31... Training Iteration: 1
#
# NN output (C_f): [[1.42 -1.16]]
# MTR-Cf: 1.4215991176916685 , TZ6-zmix-Cf: -1.1553155915038675
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.42 1.16]]
# MTR-Cf: 1.4215991176916685
# |TZ6_zmix-Cf|: 1.1553155915038675
# New_Zeta for MTR-600: [4.59]
# New_Zeta for TZ6_zmix: [1.9e-35]
# FDDN Solver Output: [[76.9 36.7 116 75.8 40 124 12.1 26.2 26.1 26.2 25.6 25.3 11.8 25.8 26 25.6 25.2 25.3]]
# New_Zeta_epsi for MTR-600: [4.63]
# New_Zeta_epsi for TZ6_zmix: [-2.21e-35]
# FDDN Solver Output: [[76.7 36.6 116 75.7 40 123 12.1 26.1 26.1 26.1 25.6 25.2 11.8 25.7 25.9 25.5 25.2 25.2]]
# Row ID: [22]
# HoV: ['M1']
# FlowRate Difference (LTR - FDDN): [5.68] l/s
# Progress: 2.0% ... Training loss: 32.25... Training Iteration: 2
#
# NN output (C_f): [[1.41 -1.19]]
# MTR-Cf: 1.4138957276019533 , TZ6-zmix-Cf: -1.18687728403375
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.41 1.19]]
# MTR-Cf: 1.4138957276019533
# |TZ6_zmix-Cf|: 1.18687728403375
# New_Zeta for MTR-600: [4.56]
# New_Zeta for TZ6_zmix: [-2.63e-35]
# FDDN Solver Output: [[77 36.7 116 75.9 40.1 124 12.1 26.2 26.2 26.2 25.7 25.3 11.9 25.8 26 25.6 25.3 25.3]]
# New_Zeta_epsi for MTR-600: [4.6]
# New_Zeta_epsi for TZ6_zmix: [3.15e-35]
# FDDN Solver Output: [[76.8 36.7 116 75.8 40 123 12.1 26.2 26.1 26.2 25.6 25.3 11.8 25.8 26 25.5 25.2 25.2]]
# Row ID: [22]
# HoV: ['M1']
# FlowRate Difference (LTR - FDDN): [4.68] l/s
# % Diff between flowrates [0.621]
# Progress: 3.0% ... Training loss: 21.87... Training Iteration: 3
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for M1: [338.49507523777135, 73.31318859776104, 32.25381691921776, 21.872656906627387]
# Old_Zeta: 3.7645035449506787
#
# NN output (C_f): [[1.41 -1.21]]
# MTR-Cf: 1.4066126273563488 , TZ6-zmix-Cf: -1.211138724170026
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.41 1.21]]
# MTR-Cf: 1.4066126273563488
# |TZ6_zmix-Cf|: 1.211138724170026
# New_Zeta for MTR-600: [4.54]
# New_Zeta for TZ6_zmix: [3.81e-35]
# FDDN Solver Output: [[79.4 37.9 120 76.9 40.6 125 12.5 27 27 27 26.5 26.1 12.1 26.4 26.6 26.2 25.9 25.9]]
# New_Zeta_epsi for MTR-600: [4.58]
# New_Zeta_epsi for TZ6_zmix: [-4.65e-35]
# FDDN Solver Output: [[79.2 37.8 119 76.8 40.6 125 12.5 27 26.9 27 26.4 26 12.1 26.3 26.6 26.1 25.8 25.8]]
# Row ID: [23]
# HoV: ['M2']
# FlowRate Difference (LTR - FDDN): [-4.97] l/s
# % Diff between flowrates [0.648]
# Progress: 0.0% ... Training loss: 24.66... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for M2: [24.66878167179089]
# Old_Zeta: 3.7645035449506787
#
# NN output (C_f): [[1.46 -1.19]]
# MTR-Cf: 1.4594352737481782 , TZ6-zmix-Cf: -1.1892721363646863
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.46 1.19]]
# MTR-Cf: 1.4594352737481782
# |TZ6_zmix-Cf|: 1.1892721363646863
# New_Zeta for MTR-600: [4.71]
# New_Zeta for TZ6_zmix: [-5.53e-35]
# FDDN Solver Output: [[76.7 36.6 116 75.7 40 123 12.1 26.1 26.1 26.2 25.6 25.2 11.8 25.7 26 25.5 25.2 25.2]]
# New_Zeta_epsi for MTR-600: [4.75]
# New_Zeta_epsi for TZ6_zmix: [6.64e-35]
# ...
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.18 1.3]]
# MTR-Cf: 1.1789712439850055
# |TZ6_zmix-Cf|: 1.3002411593252754
# New_Zeta for MTR-600: [5]
# New_Zeta for TZ6_zmix: [-2.61e-34]
# FDDN Solver Output: [[76.1 36.3 115 75 39.6 122 12 25.9 25.9 25.9 25.4 25 11.7 25.5 25.7 25.3 25 25]]
# New_Zeta_epsi for MTR-600: [5.05]
# New_Zeta_epsi for TZ6_zmix: [3.42e-34]
# FDDN Solver Output: [[75.9 36.2 114 74.8 39.5 122 12 25.8 25.8 25.9 25.3 25 11.7 25.4 25.7 25.2 24.9 24.9]]
# Row ID: [26]
# HoV: ['Q2']
# FlowRate Difference (LTR - FDDN): [5.06] l/s
# % Diff between flowrates [0.68]
# Progress: 0.0% ... Training loss: 25.61... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for Q2: [25.618027405140325]
# Old_Zeta: 3.5940970676669863
#
# NN output (C_f): [[1.27 -1.47]]
# MTR-Cf: 1.269949885435959 , TZ6-zmix-Cf: -1.4742910745901296
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.27 1.47]]
# MTR-Cf: 1.269949885435959
# |TZ6_zmix-Cf|: 1.4742910745901296
# New_Zeta for MTR-600: [3.91]
# New_Zeta for TZ6_zmix: [5.04e-34]
# FDDN Solver Output: [[80.3 38.3 121 77.1 40.7 126 12.7 27.3 27.3 27.3 26.8 26.4 12.4 26.9 27.1 26.7 26.4 26.4]]
# New_Zeta_epsi for MTR-600: [3.95]
# New_Zeta_epsi for TZ6_zmix: [-7.48e-34]
# FDDN Solver Output: [[80.1 38.2 121 77 40.7 125 12.6 27.3 27.2 27.3 26.7 26.3 12.3 26.9 27.1 26.6 26.3 26.3]]
# Row ID: [27]
# HoV: ['S1']
# FlowRate Difference (LTR - FDDN): [-34.6] l/s
# Progress: 0.0% ... Training loss: 1200.... Training Iteration: 0
#
# NN output (C_f): [[1.42 -1.21]]
# MTR-Cf: 1.4154562545516944 , TZ6-zmix-Cf: -1.20654140581533
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.42 1.21]]
# MTR-Cf: 1.4154562545516944
# |TZ6_zmix-Cf|: 1.20654140581533
# New_Zeta for MTR-600: [4.36]
# New_Zeta for TZ6_zmix: [-9.02e-34]
# FDDN Solver Output: [[78.3 37.3 118 75.2 39.7 123 12.4 26.7 26.6 26.7 26.1 25.7 12.1 26.2 26.5 26 25.7 25.7]]
# New_Zeta_epsi for MTR-600: [4.4]
# New_Zeta_epsi for TZ6_zmix: [1.1e-33]
# FDDN Solver Output: [[78.1 37.3 118 75.1 39.7 122 12.3 26.6 26.6 26.6 26.1 25.7 12 26.2 26.4 26 25.7 25.7]]
# Row ID: [27]
# HoV: ['S1']
# FlowRate Difference (LTR - FDDN): [-15.5] l/s
# Progress: 1.0% ... Training loss: 239.5... Training Iteration: 1
#
# NN output (C_f): [[1.51 -1.13]]
# MTR-Cf: 1.5142885818746674 , TZ6-zmix-Cf: -1.1345652150619112
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.51 1.13]]
# MTR-Cf: 1.5142885818746674
# |TZ6_zmix-Cf|: 1.1345652150619112
# New_Zeta for MTR-600: [4.67]
# New_Zeta for TZ6_zmix: [1.25e-33]
# FDDN Solver Output: [[77 36.7 116 74 39.1 121 12.1 26.2 26.2 26.2 25.7 25.3 11.9 25.8 26 25.6 25.3 25.3]]
# New_Zeta_epsi for MTR-600: [4.7]
# New_Zeta_epsi for TZ6_zmix: [-1.43e-33]
# FDDN Solver Output: [[76.9 36.7 116 73.9 39 120 12.1 26.2 26.1 26.2 25.6 25.3 11.8 25.8 26 25.6 25.2 25.3]]
# Row ID: [27]
# HoV: ['S1']
# FlowRate Difference (LTR - FDDN): [-3.25] l/s
# % Diff between flowrates [0.437]
# Progress: 2.0% ... Training loss: 10.54... Training Iteration: 2
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for S1: [1200.1835492306172, 239.5720265814422, 10.543236311183826]
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.43 -1.01]]
# MTR-Cf: 1.4250589105666254 , TZ6-zmix-Cf: -1.0114230449543946
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.43 1.01]]
# MTR-Cf: 1.4250589105666254
# |TZ6_zmix-Cf|: 1.0114230449543946
# New_Zeta for MTR-600: [6.05]
# New_Zeta for TZ6_zmix: [-1.44e-33]
# FDDN Solver Output: [[72.2 34.5 109 71.2 37.6 116 11.4 24.6 24.6 24.6 24.1 23.8 11.1 24.2 24.4 24 23.7 23.7]]
# New_Zeta_epsi for MTR-600: [6.1]
# New_Zeta_epsi for TZ6_zmix: [1.47e-33]
# FDDN Solver Output: [[72 34.4 109 71 37.5 116 11.4 24.5 24.5 24.6 24 23.7 11.1 24.2 24.4 24 23.7 23.7]]
# Row ID: [28]
# HoV: ['S2']
# FlowRate Difference (LTR - FDDN): [40] l/s
# Progress: 0.0% ... Training loss: 1600.... Training Iteration: 0
#
# NN output (C_f): [[1.22 -1.16]]
# MTR-Cf: 1.2213988081171858 , TZ6-zmix-Cf: -1.162911143557115
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.22 1.16]]
# MTR-Cf: 1.2213988081171858
# |TZ6_zmix-Cf|: 1.162911143557115
# New_Zeta for MTR-600: [5.18]
# New_Zeta for TZ6_zmix: [1.71e-33]
# FDDN Solver Output: [[75.3 35.9 113 74.2 39.2 121 11.9 25.6 25.6 25.6 25.1 24.8 11.6 25.2 25.5 25 24.7 24.7]]
# New_Zeta_epsi for MTR-600: [5.23]
# New_Zeta_epsi for TZ6_zmix: [-2.01e-33]
# FDDN Solver Output: [[75.1 35.8 113 74 39.1 121 11.9 25.6 25.5 25.6 25 24.7 11.6 25.2 25.4 25 24.7 24.7]]
# Row ID: [28]
# HoV: ['S2']
# FlowRate Difference (LTR - FDDN): [10] l/s
# Progress: 1.0% ... Training loss: 100.4... Training Iteration: 1
#
# NN output (C_f): [[1.18 -1.22]]
# MTR-Cf: 1.1840717698495244 , TZ6-zmix-Cf: -1.2185830719769892
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.18 1.22]]
# MTR-Cf: 1.1840717698495244
# |TZ6_zmix-Cf|: 1.2185830719769892
# New_Zeta for MTR-600: [5.02]
# New_Zeta for TZ6_zmix: [-2.45e-33]
# FDDN Solver Output: [[75.9 36.2 114 74.8 39.5 122 12 25.8 25.8 25.9 25.3 25 11.7 25.4 25.7 25.2 24.9 24.9]]
# New_Zeta_epsi for MTR-600: [5.07]
# New_Zeta_epsi for TZ6_zmix: [3.01e-33]
# FDDN Solver Output: [[75.7 36.1 114 74.6 39.4 122 11.9 25.8 25.7 25.8 25.2 24.9 11.7 25.4 25.6 25.2 24.9 24.9]]
# Row ID: [28]
# HoV: ['S2']
# FlowRate Difference (LTR - FDDN): [4.12] l/s
# % Diff between flowrates [0.555]
# Progress: 2.0% ... Training loss: 17.01... Training Iteration: 2
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for S2: [1600.9959332344706, 100.46877807310894, 17.01255611116649]
# Old_Zeta: 4.521188627716888
#
# NN output (C_f): [[1.22 -1.29]]
# MTR-Cf: 1.2151454662535714 , TZ6-zmix-Cf: -1.291891844630807
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.22 1.29]]
# MTR-Cf: 1.2151454662535714
# |TZ6_zmix-Cf|: 1.291891844630807
# New_Zeta for MTR-600: [4.71]
# New_Zeta for TZ6_zmix: [3.89e-33]
# FDDN Solver Output: [[76.9 36.7 116 75.8 40 123 12.1 26.2 26.1 26.2 25.6 25.3 11.8 25.8 26 25.6 25.2 25.3]]
# New_Zeta_epsi for MTR-600: [4.75]
# New_Zeta_epsi for TZ6_zmix: [-5.06e-33]
# FDDN Solver Output: [[76.7 36.6 116 75.6 39.9 123 12.1 26.1 26.1 26.1 25.6 25.2 11.8 25.7 25.9 25.5 25.2 25.2]]
# Row ID: [29]
# HoV: ['S3']
# FlowRate Difference (LTR - FDDN): [3.43] l/s
# % Diff between flowrates [0.457]
# Progress: 0.0% ... Training loss: 11.79... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for S3: [11.790416282760289]
# Old_Zeta: 4.521188627716888
#
# NN output (C_f): [[1.2 -1.3]]
# MTR-Cf: 1.2042440565391157 , TZ6-zmix-Cf: -1.3018989192688208
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.2 1.3]]
# MTR-Cf: 1.2042440565391157
# |TZ6_zmix-Cf|: 1.3018989192688208
# New_Zeta for MTR-600: [4.67]
# New_Zeta for TZ6_zmix: [-6.58e-33]
# FDDN Solver Output: [[77.3 36.9 116 74.9 39.6 122 12 25.9 25.8 25.9 25.3 25 11.7 25.5 25.7 25.3 24.9 25]]
# New_Zeta_epsi for MTR-600: [4.71]
# New_Zeta_epsi for TZ6_zmix: [8.64e-33]
# FDDN Solver Output: [[77.1 36.8 116 74.7 39.5 122 12 25.8 25.8 25.8 25.3 24.9 11.7 25.4 25.6 25.2 24.9 24.9]]
# Row ID: [30]
# HoV: ['S4']
# FlowRate Difference (LTR - FDDN): [-10.5] l/s
# Progress: 0.0% ... Training loss: 109.9... Training Iteration: 0
#
# NN output (C_f): [[1.25 -1.22]]
# MTR-Cf: 1.2475220514360894 , TZ6-zmix-Cf: -1.2218962882834294
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.25 1.22]]
# MTR-Cf: 1.2475220514360894
# |TZ6_zmix-Cf|: 1.2218962882834294
# New_Zeta for MTR-600: [4.84]
# New_Zeta for TZ6_zmix: [1.06e-32]
# FDDN Solver Output: [[76.6 36.5 115 74.2 39.2 121 11.9 25.6 25.6 25.7 25.1 24.8 11.6 25.2 25.5 25 24.7 24.7]]
# New_Zeta_epsi for MTR-600: [4.88]
# New_Zeta_epsi for TZ6_zmix: [-1.3e-32]
# FDDN Solver Output: [[76.4 36.5 115 74.1 39.1 121 11.9 25.6 25.5 25.6 25 24.7 11.6 25.2 25.4 25 24.7 24.7]]
# Row ID: [30]
# HoV: ['S4']
# FlowRate Difference (LTR - FDDN): [-3.92] l/s
# % Diff between flowrates [0.533]
# Progress: 1.0% ... Training loss: 15.38... Training Iteration: 1
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for S4: [109.90347840875435, 15.386263222167731]
# Old_Zeta: 2.8397674398682766
#
# NN output (C_f): [[1.44 -1.37]]
# MTR-Cf: 1.4357057550509809 , TZ6-zmix-Cf: -1.3722432353371528
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.44 1.37]]
# MTR-Cf: 1.4357057550509809
# |TZ6_zmix-Cf|: 1.3722432353371528
# New_Zeta for MTR-600: [3.5]
# New_Zeta for TZ6_zmix: [-1.78e-32]
# FDDN Solver Output: [[82.6 39.4 125 80.1 42.3 130 13 28.1 28.1 28.1 27.5 27.2 12.5 27.2 27.4 27 26.7 26.7]]
# New_Zeta_epsi for MTR-600: [3.52]
# New_Zeta_epsi for TZ6_zmix: [2.47e-32]
# FDDN Solver Output: [[82.5 39.3 124 79.9 42.2 130 13 28.1 28 28.1 27.5 27.1 12.5 27.2 27.4 27 26.6 26.6]]
# Row ID: [31]
# HoV: ['S5']
# FlowRate Difference (LTR - FDDN): [-40.9] l/s
# Progress: 0.0% ... Training loss: 1674.... Training Iteration: 0
#
# NN output (C_f): [[1.64 -1.14]]
# MTR-Cf: 1.6420936903042977 , TZ6-zmix-Cf: -1.1398217858285717
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.64 1.14]]
# MTR-Cf: 1.6420936903042977
# |TZ6_zmix-Cf|: 1.1398217858285717
# New_Zeta for MTR-600: [4]
# New_Zeta for TZ6_zmix: [2.81e-32]
# FDDN Solver Output: [[80.2 38.2 121 77.7 41.1 127 12.6 27.3 27.2 27.3 26.7 26.4 12.1 26.4 26.6 26.2 25.9 25.9]]
# New_Zeta_epsi for MTR-600: [4.03]
# New_Zeta_epsi for TZ6_zmix: [-3.23e-32]
# FDDN Solver Output: [[80 38.2 121 77.6 41 126 12.6 27.2 27.2 27.3 26.7 26.3 12.1 26.4 26.6 26.2 25.8 25.9]]
# Row ID: [31]
# HoV: ['S5']
# FlowRate Difference (LTR - FDDN): [-17.4] l/s
# Progress: 1.0% ... Training loss: 304.4... Training Iteration: 1
#
# NN output (C_f): [[1.79 -1.08]]
# MTR-Cf: 1.7866803387882417 , TZ6-zmix-Cf: -1.0829217686124075
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.79 1.08]]
# MTR-Cf: 1.7866803387882417
# |TZ6_zmix-Cf|: 1.0829217686124075
# New_Zeta for MTR-600: [4.35]
# New_Zeta for TZ6_zmix: [-3.5e-32]
# FDDN Solver Output: [[78.6 37.5 118 76.2 40.2 124 12.4 26.8 26.7 26.8 26.2 25.8 11.9 25.9 26.1 25.7 25.4 25.4]]
# New_Zeta_epsi for MTR-600: [4.38]
# New_Zeta_epsi for TZ6_zmix: [3.83e-32]
# FDDN Solver Output: [[78.5 37.4 118 76 40.2 124 12.4 26.7 26.7 26.7 26.2 25.8 11.9 25.9 26.1 25.7 25.3 25.3]]
# Row ID: [31]
# HoV: ['S5']
# FlowRate Difference (LTR - FDDN): [-2.19] l/s
# % Diff between flowrates [0.288]
# Progress: 2.0% ... Training loss: 4.789... Training Iteration: 2
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for S5: [1674.8682529033488, 304.49850073998005, 4.789053960217451]
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.6 -0.919]]
# MTR-Cf: 1.597922113393893 , TZ6-zmix-Cf: -0.9192446464023684
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.6 0.919]]
# MTR-Cf: 1.597922113393893
# |TZ6_zmix-Cf|: 0.9192446464023684
# New_Zeta for MTR-600: [6.78]
# New_Zeta for TZ6_zmix: [3.52e-32]
# FDDN Solver Output: [[69.9 33.4 105 69 36.4 112 11 23.8 23.8 23.8 23.3 23 10.8 23.5 23.7 23.3 23 23]]
# New_Zeta_epsi for MTR-600: [6.83]
# New_Zeta_epsi for TZ6_zmix: [-3.27e-32]
# FDDN Solver Output: [[69.8 33.3 105 68.8 36.4 112 11 23.8 23.7 23.8 23.3 23 10.8 23.4 23.6 23.2 22.9 22.9]]
# Row ID: [32]
# HoV: ['T1']
# FlowRate Difference (LTR - FDDN): [40.1] l/s
# Progress: 0.0% ... Training loss: 1604.... Training Iteration: 0
#
# NN output (C_f): [[1.37 -1.04]]
# MTR-Cf: 1.3728801848843766 , TZ6-zmix-Cf: -1.0372175445908052
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.37 1.04]]
# MTR-Cf: 1.3728801848843766
# |TZ6_zmix-Cf|: 1.0372175445908052
# New_Zeta for MTR-600: [5.83]
# New_Zeta for TZ6_zmix: [-3.39e-32]
# FDDN Solver Output: [[73 34.8 110 72 38 117 11.5 24.9 24.8 24.9 24.4 24 11.3 24.5 24.7 24.3 24 24]]
# New_Zeta_epsi for MTR-600: [5.87]
# New_Zeta_epsi for TZ6_zmix: [3.55e-32]
# FDDN Solver Output: [[72.9 34.8 110 71.8 38 117 11.5 24.8 24.8 24.8 24.3 24 11.2 24.4 24.6 24.2 23.9 23.9]]
# Row ID: [32]
# HoV: ['T1']
# FlowRate Difference (LTR - FDDN): [9.97] l/s
# Progress: 1.0% ... Training loss: 99.35... Training Iteration: 1
#
# NN output (C_f): [[1.34 -1.08]]
# MTR-Cf: 1.3441412860987854 , TZ6-zmix-Cf: -1.0835768926794525
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.34 1.08]]
# MTR-Cf: 1.3441412860987854
# |TZ6_zmix-Cf|: 1.0835768926794525
# New_Zeta for MTR-600: [5.7]
# New_Zeta for TZ6_zmix: [3.85e-32]
# FDDN Solver Output: [[73.5 35 111 72.4 38.3 118 11.6 25 25 25 24.5 24.2 11.3 24.6 24.8 24.4 24.1 24.1]]
# New_Zeta_epsi for MTR-600: [5.75]
# New_Zeta_epsi for TZ6_zmix: [-4.21e-32]
# FDDN Solver Output: [[73.3 35 110 72.3 38.2 118 11.6 25 24.9 25 24.4 24.1 11.3 24.6 24.8 24.4 24.1 24.1]]
# Row ID: [32]
# HoV: ['T1']
# FlowRate Difference (LTR - FDDN): [5.82] l/s
# Progress: 2.0% ... Training loss: 33.92... Training Iteration: 2
#
# NN output (C_f): [[1.34 -1.11]]
# MTR-Cf: 1.3352381575309133 , TZ6-zmix-Cf: -1.114859952850011
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.34 1.11]]
# MTR-Cf: 1.3352381575309133
# |TZ6_zmix-Cf|: 1.114859952850011
# New_Zeta for MTR-600: [5.67]
# New_Zeta for TZ6_zmix: [-4.69e-32]
# FDDN Solver Output: [[73.6 35.1 111 72.6 38.3 118 11.6 25.1 25 25.1 24.5 24.2 11.3 24.7 24.9 24.5 24.2 24.2]]
# New_Zeta_epsi for MTR-600: [5.71]
# New_Zeta_epsi for TZ6_zmix: [5.28e-32]
# FDDN Solver Output: [[73.4 35 111 72.4 38.2 118 11.6 25 25 25 24.5 24.2 11.3 24.6 24.8 24.4 24.1 24.1]]
# Row ID: [32]
# HoV: ['T1']
# FlowRate Difference (LTR - FDDN): [4.53] l/s
# % Diff between flowrates [0.628]
# Progress: 3.0% ... Training loss: 20.48... Training Iteration: 3
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for T1: [1604.1001030692125, 99.352752169824, 33.92931082624998, 20.481424024947703]
# Old_Zeta: 4.949375283472444
#
# NN output (C_f): [[1.34 -1.15]]
# MTR-Cf: 1.341415150461607 , TZ6-zmix-Cf: -1.1503494680617488
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.34 1.15]]
# MTR-Cf: 1.341415150461607
# |TZ6_zmix-Cf|: 1.1503494680617488
# New_Zeta for MTR-600: [5.69]
# New_Zeta for TZ6_zmix: [6.07e-32]
# FDDN Solver Output: [[73 34.8 110 72 38 117 11.5 24.9 24.8 24.9 24.4 24 11.3 24.5 24.7 24.3 24 24]]
# New_Zeta_epsi for MTR-600: [5.74]
# New_Zeta_epsi for TZ6_zmix: [-7.04e-32]
# FDDN Solver Output: [[72.8 34.8 110 71.8 38 117 11.5 24.8 24.8 24.8 24.3 24 11.2 24.4 24.6 24.2 23.9 23.9]]
# Row ID: [33]
# HoV: ['T2']
# FlowRate Difference (LTR - FDDN): [28.6] l/s
# Progress: 0.0% ... Training loss: 818.6... Training Iteration: 0
#
# NN output (C_f): [[1.22 -1.29]]
# MTR-Cf: 1.2224397934499096 , TZ6-zmix-Cf: -1.2860973195796157
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.22 1.29]]
# MTR-Cf: 1.2224397934499096
# |TZ6_zmix-Cf|: 1.2860973195796157
# New_Zeta for MTR-600: [5.19]
# New_Zeta for TZ6_zmix: [-9.06e-32]
# FDDN Solver Output: [[74.9 35.7 113 73.8 39 120 11.8 25.5 25.5 25.5 25 24.6 11.5 25.1 25.3 24.9 24.6 24.6]]
# New_Zeta_epsi for MTR-600: [5.24]
# New_Zeta_epsi for TZ6_zmix: [1.17e-31]
# FDDN Solver Output: [[74.7 35.6 113 73.6 38.9 120 11.8 25.4 25.4 25.4 24.9 24.6 11.5 25 25.2 24.8 24.5 24.5]]
# Row ID: [33]
# HoV: ['T2']
# FlowRate Difference (LTR - FDDN): [10.8] l/s
# Progress: 1.0% ... Training loss: 115.8... Training Iteration: 1
#
# NN output (C_f): [[1.18 -1.35]]
# MTR-Cf: 1.1848614438378766 , TZ6-zmix-Cf: -1.3483985482721352
#
# NN output is -ve. Taking |(c_f)| values for both MTR and TZ6_zmix: [[1.18 1.35]]
# MTR-Cf: 1.1848614438378766
# |TZ6_zmix-Cf|: 1.3483985482721352
# New_Zeta for MTR-600: [5.03]
# New_Zeta for TZ6_zmix: [1.58e-31]
# FDDN Solver Output: [[75.5 36 114 74.4 39.3 121 11.9 25.7 25.7 25.7 25.2 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# New_Zeta_epsi for MTR-600: [5.08]
# New_Zeta_epsi for TZ6_zmix: [-2.15e-31]
# FDDN Solver Output: [[75.3 35.9 113 74.2 39.2 121 11.9 25.6 25.6 25.7 25.1 24.8 11.6 25.2 25.5 25 24.7 24.7]]
# Row ID: [33]
# HoV: ['T2']
# FlowRate Difference (LTR - FDDN): [4.84] l/s
# % Diff between flowrates [0.656]
# Progress: 2.0% ... Training loss: 23.46... Training Iteration: 2
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# Train Loss History for T2: [818.6902450323936, 115.85493920227923, 23.4601946304504]

# %%
cf_df = pd.DataFrame(data=c_f_hist)
losses = pd.DataFrame(data=losses_hist)

# %%
cf_df['MaxEpochs'] = None # Initialize Empty Column for storing epochs trained

for i in range(len(losses['HoV'])):
    nr_epochs_trained = len(losses['train_loss'][i])
    cf_df['MaxEpochs'].loc[i] = nr_epochs_trained

cf_df
# Out:
#    HoV  MTR_cf_hat  TZ6zmix_cf_hat  MaxEpochs
# 0   A1    1.140993        0.097611          1
# 1   A2    1.223367        0.213955         10
# 2   A3    1.317834        0.253589          1
# 3   A4    1.552047        0.311292          3
# 4   A5    1.159198        0.467648          6
# 5   A6    1.095937        0.522728          2
# 6   C1    1.128743        0.526730          1
# 7   C2    1.509169        0.555727          3
# 8   C3    1.473994        0.620002          2
# 9   C4    1.237740        0.758507          2
# 10  C5    1.493042        0.701771          2
# 11  C6    1.481434        0.828309          2
# 12  D1    1.270043        0.946512          2
# 13  D2    1.173482        0.955405          2
# 14  E1    1.169442        0.969787          1
# 15  E2    1.611601        0.625340          2
# 16  F1    1.165903        0.788282          3
# 17  F2    1.158858        0.802091          1
# 18  F3    1.193831        0.907141          2
# 19  H1    1.187423        0.923121          1
# 20  I1    1.497419        0.847046          2
# 21  J1    1.401436        0.885181          3
# 22  M1    1.413896        1.186877          4
# 23  M2    1.406613        1.211139          1
# 24  P1    1.459435        1.189272          1
# 25  Q1    1.201677        1.278871          3
# 26  Q2    1.178971        1.300241          1
# 27  S1    1.514289        1.134565          3
# 28  S2    1.184072        1.218583          3
# 29  S3    1.215145        1.291892          1
# 30  S4    1.247522        1.221896          2
# 31  S5    1.786680        1.082922          3
# 32  T1    1.335238        1.114860          4
# 33  T2    1.184861        1.348399          3

# %%
print('Max no. of epochs for:',cf_df['HoV'].iloc[[cf_df.MaxEpochs.idxmax()]].values)
cf_df.to_csv('data_output/NN_2CF_Output.csv',index=False)
cf_df.iloc[[cf_df.MaxEpochs.idxmax()]]
# Out:
# Max no. of epochs for: ['A2']
#   HoV  MTR_cf_hat  TZ6zmix_cf_hat  MaxEpochs
# 1  A2    1.223367        0.213955         10

# %% [markdown]
# **Plot Training Loss**

# %%
from bokeh.palettes import Category20,Colorblind,Spectral,Set2,YlGnBu,RdPu
temp_list = []
bokeh_palettes = [Colorblind,YlGnBu,RdPu,Set2]
for palette in bokeh_palettes:
    for key in palette.keys():
        temp_list.append(palette[key])
    
color_palette = [y for x in temp_list for y in x]

# %%
num_lines = len(losses.HoV) # no. of lines to draw
colors = color_palette[0:num_lines]
labels = losses.HoV.values.tolist()

p = figure(width=1100)
for i in range(num_lines):
    x = list(range(1,len(losses['train_loss'][i])+1))
    y = losses['train_loss'][i]
    p.line(x, y, line_width=2, color=colors[i], alpha=0.8, legend='Train Loss for {}'.format(labels[i]))
p.yaxis.axis_label = "Train Loss"
p.xaxis.axis_label = "Epochs"
p.legend.click_policy="hide"
show(p)
# Out:
#   <div class="bk-root" id="9837423e-3e42-4219-b64f-85cc0dc4efaa"></div>

# %% [markdown]
# ### Observations:
# In general the performance of the Hybrid PINN architecture seems to be satisfactory and the final `c_f`s predicted are physically consistent. Some drawbacks that were observed are:
# * The early stopping criteria is specified in the `Hybrid_PINN_v2.py` script which uses a percentage difference (set to 0.75%) between the LTR and FDDN Flowrate. This % diff value is higher than the value used in the `Hybrid_PINN_v1.py` because in this version we are predicting two correction factors.
