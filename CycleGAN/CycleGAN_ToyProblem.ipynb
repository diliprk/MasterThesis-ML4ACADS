# %% [markdown]
# <a href="https://colab.research.google.com/github/diliprk/MasterThesis-ML4ACADS/blob/master/CycleGAN_ToyProblem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Version Description:
# In this version we experiment with a toy problem to understand the application of CycleGANs for our requirement.<br> The CycleGAN generates the following columns (i.e all major features):
# * `D` - (Restrictor Diameter)
# * `z` - (Loss Co-efficient)
# * `c` - (Correction Factor)
# * `V` - (Volume Flow Rate)
# <br>Derived features like `A` (Area) and `zc` (z * c) are ommitted to avoid redundant feature selection and improve model performance.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import random
import pandas as pd
import numpy as np
from math import pi
from numpy.random import rand, randn, randint
from functools import reduce

#Set some numpy print options for displaying numpy arrays to fit maximum width of cell
np.set_printoptions(precision=3, edgeitems=30, linewidth=1000, formatter=dict(float=lambda x: "%.3g" % x))

# Disable Warnings for chained assignments Eg:Setting with Copy Warning
pd.options.mode.chained_assignment = None 

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
plt.style.use('seaborn-whitegrid')

# %%
# Set seed for reproducability
np.random.seed(seed=41)

# %% [markdown]
# ### Generate Data points for Toy Dataset:

# %%
## Constant parameters from a lab test bench
D1 = 120
dp = 26
D_duct = 180
A_duct = pi/4*(D_duct/1000)**2
increment = 1.02

# %%
def gen_new_points(dia,cf_error=[],cf_flag = 1):
    '''Custom function to generate data points of different distributions to construct toy dataset.
    Setting the c_f flag to various values generates points for data distributions in the toy dataset.
    c_f flag = 1 generates points for the LTR dataset,
    c_f flag = 0 generates simulation points with systematic error
    c_f flag = -1 generates erroneous points for the LTR dataset which requires erroenous values in cf_error list
    '''
    A_d = pi/4*(dia/1000)**2 
    z = (1 - (A_d / A_duct))**2 
    x2 = ((dia - D1) / 2) + 1
    if cf_flag == 1:
        # C_f for LTR points
        cf = 1 * (increment**(x2 - 1))
    elif cf_flag == 0:
        # C_f for Sim points
        cf = 1
    elif cf_flag == -1:
        # C_f for manually generating erroneous points 
        cf = cf_error
    zc = z * cf
    V = ((dp/zc) * (A_duct)**2)**0.5
    return A_d,z,cf,zc,V

# %%
# Create a toy dataset of 'real world points' using the lab test parameters
dia_array = range(120,162,1)
area, zeta, cf, zeta_cf, V_flowrate = gen_new_points(np.array(dia_array))
toy_df = pd.DataFrame({'D':dia_array,'A':area,'Z':zeta,'c':cf,'Zc':zeta_cf,'V':V_flowrate})
# toy_df.to_csv('data/Toy_DataSet.csv', index = False)
toy_df
# Out:
#       D         A         Z         c        Zc         V
# 0   120  0.011310  0.308642  1.000000  0.308642  0.233558
# 1   121  0.011499  0.300433  1.009950  0.303422  0.235558
# 2   122  0.011690  0.292267  1.020000  0.298112  0.237647
# 3   123  0.011882  0.284148  1.030150  0.292715  0.239827
# 4   124  0.012076  0.276079  1.040400  0.287232  0.242106
# 5   125  0.012272  0.268062  1.050752  0.281667  0.244486
# 6   126  0.012469  0.260100  1.061208  0.276020  0.246974
# 7   127  0.012668  0.252196  1.071768  0.270296  0.249576
# 8   128  0.012868  0.244353  1.082432  0.264496  0.252297
# 9   129  0.013070  0.236574  1.093203  0.258624  0.255145
# 10  130  0.013273  0.228862  1.104081  0.252682  0.258128
# 11  131  0.013478  0.221219  1.115067  0.246674  0.261252
# 12  132  0.013685  0.213649  1.126162  0.240604  0.264527
# 13  133  0.013893  0.206155  1.137368  0.234474  0.267962
# 14  134  0.014103  0.198740  1.148686  0.228290  0.271568
# 15  135  0.014314  0.191406  1.160116  0.222053  0.275355
# 16  136  0.014527  0.184158  1.171659  0.215770  0.279335
# 17  137  0.014741  0.176997  1.183318  0.209443  0.283523
# 18  138  0.014957  0.169927  1.195093  0.203079  0.287932
# 19  139  0.015175  0.162952  1.206984  0.196680  0.292578
# 20  140  0.015394  0.156074  1.218994  0.190253  0.297479
# 21  141  0.015615  0.149296  1.231124  0.183802  0.302654
# 22  142  0.015837  0.142623  1.243374  0.177334  0.308124
# 23  143  0.016061  0.136056  1.255746  0.170852  0.313914
# 24  144  0.016286  0.129600  1.268242  0.164364  0.320050
# 25  145  0.016513  0.123257  1.280861  0.157876  0.326561
# 26  146  0.016742  0.117032  1.293607  0.151393  0.333479
# 27  147  0.016972  0.110926  1.306479  0.144922  0.340842
# 28  148  0.017203  0.104944  1.319479  0.138471  0.348692
# 29  149  0.017437  0.099089  1.332608  0.132047  0.357074
# 30  150  0.017671  0.093364  1.345868  0.125656  0.366041
# 31  151  0.017908  0.087773  1.359260  0.119307  0.375655
# 32  152  0.018146  0.082319  1.372786  0.113007  0.385984
# 33  153  0.018385  0.077006  1.386446  0.106765  0.397107
# 34  154  0.018627  0.071837  1.400241  0.100589  0.409115
# 35  155  0.018869  0.066816  1.414175  0.094489  0.422114
# 36  156  0.019113  0.061946  1.428246  0.088474  0.436229
# 37  157  0.019359  0.057230  1.442458  0.082552  0.451603
# 38  158  0.019607  0.052673  1.456811  0.076735  0.468409
# 39  159  0.019856  0.048278  1.471307  0.071032  0.486851
# 40  160  0.020106  0.044048  1.485947  0.065453  0.507173
# 41  161  0.020358  0.039988  1.500733  0.060011  0.529672

# %% [markdown]
# **LTR Dataset**:

# %%
# Select some points from the toy_df (from reality) to represent the lab test data points 
dia_LTR = [120,126,132,138,142]
# dia_LTR = [120,122,126,128,132,134,138,142]
dataset_LTR = toy_df[['D','Z','c','V']].loc[toy_df['D'].isin(dia_LTR)]
dataset_LTR.reset_index(drop = True, inplace = True)
dataset_LTR
# Out:
#      D         Z         c         V
# 0  120  0.308642  1.000000  0.233558
# 1  126  0.260100  1.061208  0.246974
# 2  132  0.213649  1.126162  0.264527
# 3  138  0.169927  1.195093  0.287932
# 4  142  0.142623  1.243374  0.308124

# %%
# Introduce some error (non-linearities) by using wrong c_f in LTR datapoints to create outliers
dia_ep = [132] #[132,146,155]
cf_err = [0.9] #[0.9, 0.78, 0.92]

area_ep, zeta_ep, cf_ep, zeta_cf_ep, V_flowrate_ep = gen_new_points(np.array(dia_ep),cf_error = cf_err, cf_flag = -1)
df_ep = pd.DataFrame({'D':dia_ep,'A':area_ep,'Z':zeta_ep,'c':cf_ep,'Zc':zeta_cf_ep,'V':V_flowrate_ep})
df_ep['Zc_delta'] = df_ep['Zc'].values - toy_df['Zc'].loc[toy_df['D'].isin(dia_ep)].values
df_ep['V_delta'] = df_ep['V'].values - toy_df['V'].loc[toy_df['D'].isin(dia_ep)].values
df_ep['%Error'] = 100 * df_ep['V_delta'].values/toy_df['V'].loc[toy_df['D'].isin(dia_ep)].values
df_ep = df_ep[['D','A','Z','c','Zc','Zc_delta','V','V_delta','%Error']]
print('Synthesised Erroneous Points:')
df_ep
# Out:
# Synthesised Erroneous Points:
#      D         A         Z    c        Zc  Zc_delta         V   V_delta  \
# 0  132  0.013685  0.213649  0.9  0.192284 -0.048319  0.295903  0.031376
#
#       %Error
# 0  11.861145

# %%
# Replace corresponding data point in dataset_LTR with outlier point
idx_2drop = dataset_LTR.loc[dataset_LTR['D'].isin(dia_ep)].index.tolist()
print('Indices to Replace in LTR_Dataset:',idx_2drop, 'with Dia values:',dia_ep) #,'Data Type:',type(idx_2drop)
dataset_LTR.drop(idx_2drop,inplace = True)
dataset_LTR = dataset_LTR.append(df_ep[['D','Z','c','V']])
dataset_LTR.sort_values(by=['D'], ascending=[1], inplace = True)
dataset_LTR.reset_index(drop = True,inplace = True)
dataset_LTR
# Out:
# Indices to Replace in LTR_Dataset: [2] with Dia values: [132]
#      D         Z         c         V
# 0  120  0.308642  1.000000  0.233558
# 1  126  0.260100  1.061208  0.246974
# 2  132  0.213649  0.900000  0.295903
# 3  138  0.169927  1.195093  0.287932
# 4  142  0.142623  1.243374  0.308124

# %% [markdown]
# **Simulation Dataset**:

# %%
# Create low-fidelity simulated points for the same diamter values in the toy_df
# To introduce some systematic error into the simulation points we set the c_f == 1 which deviates it from the real world points
dia_sim = range(120,144,2) 
area_sim, zeta_sim, cf_sim, Zeta_cf_sim, V_flowrate_sim = gen_new_points(np.array(dia_sim), cf_flag = 0)
dataset_sim = pd.DataFrame({'D':dia_sim,'A':area_sim,'Z':zeta_sim,'c':cf_sim,'Zc':Zeta_cf_sim,'V':V_flowrate_sim})
dataset_sim['Zc_delta'] = dataset_sim['Zc'] - toy_df['Zc']
dataset_sim['V_delta'] = dataset_sim['V'] - toy_df['V']
dataset_sim['%Error'] = 100 * dataset_sim['V_delta']/toy_df['V']
dataset_sim = dataset_sim[['D','A','Z','c','Zc','Zc_delta','V','V_delta','%Error']]
# toy_df_simulation.to_csv('data/Toy_DataSet_Simulation.csv', index = False)
dataset_sim
# Out:
#       D         A         Z  c        Zc  Zc_delta         V   V_delta  \
# 0   120  0.011310  0.308642  1  0.308642  0.000000  0.233558  0.000000
# 1   122  0.011690  0.292267  1  0.292267 -0.011155  0.240011  0.004453
# 2   124  0.012076  0.276079  1  0.276079 -0.022033  0.246948  0.009301
# 3   126  0.012469  0.260100  1  0.260100 -0.032615  0.254420  0.014593
# 4   128  0.012868  0.244353  1  0.244353 -0.042879  0.262490  0.020384
# 5   130  0.013273  0.228862  1  0.228862 -0.052805  0.271228  0.026742
# 6   132  0.013685  0.213649  1  0.213649 -0.062371  0.280718  0.033744
# 7   134  0.014103  0.198740  1  0.198740 -0.071556  0.291058  0.041482
# 8   136  0.014527  0.184158  1  0.184158 -0.080338  0.302362  0.050065
# 9   138  0.014957  0.169927  1  0.169927 -0.088696  0.314768  0.059622
# 10  140  0.015394  0.156074  1  0.156074 -0.096608  0.328440  0.070313
# 11  142  0.015837  0.142623  1  0.142623 -0.104051  0.343579  0.082327
#
#        %Error
# 0    0.000000
# 1    1.890481
# 2    3.913844
# 3    6.084620
# 4    8.419580
# 5   10.938182
# 6   13.663130
# 7   16.621082
# 8   19.843544
# 9   23.368031
# 10  27.239560
# 11  31.512633

# %%
dataset_sim = dataset_sim[['D','Z','c','V']] # Omit columns not needed for the ML

# %% [markdown]
# ### Rescale and Normalize Data:

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler() # Common MinMaxScaler for all features.

# %%
# Create copies of the two datasets for scaling purpose
Sim_df = dataset_sim.copy()
LTR_df = dataset_LTR.copy()
LTR_df
# Out:
#      D         Z         c         V
# 0  120  0.308642  1.000000  0.233558
# 1  126  0.260100  1.061208  0.246974
# 2  132  0.213649  0.900000  0.295903
# 3  138  0.169927  1.195093  0.287932
# 4  142  0.142623  1.243374  0.308124

# %%
Sim_df.sort_values(by=['D'], ascending=[True], inplace = True)
Sim_df
# Out:
#       D         Z  c         V
# 0   120  0.308642  1  0.233558
# 1   122  0.292267  1  0.240011
# 2   124  0.276079  1  0.246948
# 3   126  0.260100  1  0.254420
# 4   128  0.244353  1  0.262490
# 5   130  0.228862  1  0.271228
# 6   132  0.213649  1  0.280718
# 7   134  0.198740  1  0.291058
# 8   136  0.184158  1  0.302362
# 9   138  0.169927  1  0.314768
# 10  140  0.156074  1  0.328440
# 11  142  0.142623  1  0.343579

# %%
# Rescale Data
colnames_all = list(LTR_df)
LTR_df[colnames_all] = scaler.fit_transform(LTR_df[colnames_all])
Sim_df[colnames_all] = scaler.fit_transform(Sim_df[colnames_all])

# %%
print('No. of columns in LTR dataframe :',LTR_df.shape[1])
print('No. of columns in FDDN dataframe:',Sim_df.shape[1])
# Out:
# No. of columns in LTR dataframe : 4
# No. of columns in FDDN dataframe: 4

# %%
from keras.optimizers import Adam
from keras.models import Model, Sequential, Input
from keras.layers import Dense, LeakyReLU, Activation
from keras.initializers import RandomNormal
from keras.utils.vis_utils import plot_model
# Out:
# Using TensorFlow backend.

# %%
# Select a batch of random samples, returns features and target
def generate_real_samples(dataset, n_samples):
    # choose random instances of indices
    ix = randint(0, dataset.shape[0], n_samples)
    # retrieve samples from indices
    X = dataset.iloc[ix].values
    # generate 'real' class labels (1)
    y = np.ones((n_samples,1))
    return X, y

# %%
# generate a batch of fake examples with class labels
def generate_fake_samples(gen_model, dataset):
    # generate fake instance
    X = gen_model.predict(dataset)
    # create 'fake' class labels (0)
    y = np.zeros((len(X),1))
    return X, y

# %% [markdown]
# ### Define Architecture of Generator and Discriminator
# Since the dataset is very simple, a simple neural network (eg: MLP) is expected to be sufficient for both the discriminator and generator.
#
# The `define_discriminator()` function below defines and returns the discriminator model. The function parameterizes the number of inputs to expect.<br>
# * **Inputs**: No. of input features (4)
# * **Outputs**: single float value to assess likelihood of Real or Fake output from Generator.
# <br>The discriminator model will have one hidden layer with 32 nodes and we will use the `ReLU` activation function and a `random normal` weight initialization. The discriminator model is compiled using a least squares loss (L2) which is implemented using "_mean squared error_" between the target values of class=1 for real data and class=0 for fake data.

# %% [markdown]
# The `define_generator()` function below defines and returns the generator model.<br>
# * **Inputs**: No. of input features (4).
# * **Outputs**: Four-element vector representing a generated sample point.
# <br>The generator model is also small like the discriminator model and has a single hidden layer with 32 nodes. It also uses the `ReLU` activation function and the random normal weight initialization.The output layer will have 4 nodes for the four elements in a generated vector and will use a linear activation function. A linear activation function is used because we want the generator to output a vector of real values. The generator model is not compiled, as it is not fitted directly.

# %%
# define the discriminator model
def define_discriminator(nr_features):
    init = RandomNormal(stddev=0.02)
    model = Sequential()
    model.add(Dense(nr_features, activation='relu',kernel_initializer=init, input_shape=(nr_features,)))
    model.add(Dense(32, activation='relu',kernel_initializer=init))
    model.add(Dense(1, activation='linear'))
    # COMPILE Model
    model.compile(loss='mse', optimizer=Adam(lr=0.0002, beta_1=0.5), loss_weights=[0.5])
#     model.compile(loss='binary_crossentropy', optimizer='adam')
#     model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
    return model
 
 # define the standalone generator model
def define_generator(nr_features):
    init = RandomNormal(stddev=0.02)
    model = Sequential()
    model.add(Dense(nr_features, activation='relu',kernel_initializer=init, input_shape=(nr_features,)))
    model.add(Dense(32, activation='relu',kernel_initializer=init))  
    model.add(Dense(nr_features, activation='linear'))
    return model

# %% [markdown]
# ### Composite Model:
# The generator models are not updated directly. Instead, the generator models are updated via composite models.
# An update to each generator model involves changes to the model weights based on four concerns:
# * Adversarial loss (L2 or mean squared error).
# * Identity loss (L1 or mean absolute error).
# * Forward cycle loss (L1 or mean absolute error).
# * Backward cycle loss (L1 or mean absolute error).
# <br><font color='red'>For more details please see item **[1]** in the **Resources** below.</font>

# %%
# Define a composite model for updating generators by adversarial and cycle loss
def define_composite_model(g_model_1, d_model, g_model_2, nr_features):
    # ensure the model we're updating is trainable
    g_model_1.trainable = True
    # mark discriminator as not trainable
    d_model.trainable = False
    # mark other generator model as not trainable
    g_model_2.trainable = False
    # discriminator element
    input_gen = Input(shape=(nr_features,))
    gen1_out = g_model_1(input_gen)
    output_d = d_model(gen1_out)
    # identity element
    input_id = Input(shape=(nr_features,))
    output_id = g_model_1(input_id)
    # forward cycle
    output_f = g_model_2(gen1_out)
    # backward cycle
    gen2_out = g_model_2(input_id)
    output_b = g_model_1(gen2_out)
    # define model graph
    model = Model([input_gen, input_id], [output_d, output_id, output_f, output_b])
    # define optimization algorithm configuration
    opt = Adam(lr=0.0002, beta_1=0.5)
    # compile model with weighting of least squares loss and L1 loss
    model.compile(loss=['mse', 'mse', 'mse', 'mse'], loss_weights=[1, 5, 10, 10], optimizer=opt)
    return model

nr_features = LTR_df.shape[1]
# generator: A -> B
g_model_AtoB = define_generator(nr_features)
# discriminator: A -> [real/fake]
d_model_A = define_discriminator(nr_features)
# generator: B -> A
g_model_BtoA = define_generator(nr_features)
# discriminator: B -> [real/fake]
d_model_B = define_discriminator(nr_features)
# composite: A -> B -> [real/fake, A]
c_model_AtoB = define_composite_model(g_model_AtoB, d_model_B, g_model_BtoA, nr_features)
# composite: B -> A -> [real/fake, B]
c_model_BtoA = define_composite_model(g_model_BtoA, d_model_A, g_model_AtoB, nr_features)

# %%
g_model_AtoB.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                160
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 312
# Trainable params: 0
# Non-trainable params: 312
# _________________________________________________________________

# %%
d_model_A.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                160
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 426
# Trainable params: 213
# Non-trainable params: 213
# _________________________________________________________________

# %%
# Generate samples and save as a plot and save the model
def summarize_performance(epoch_step, g_model, trainX, name):
    # select a sample of input images
    X_in, _ = generate_real_samples(trainX, n_samples = 32)
    # generate translated images
    X_out, _ = generate_fake_samples(g_model_BtoA, X_in)
    # Inverse scale to real value
    X_in = scaler.inverse_transform(X_in)
    X_out = scaler.inverse_transform(X_out)
    # Scatter plot of real and fake data points
    plt.scatter(X_in[:, 0], X_in[:, -1], color='red',label = 'Real Data')
    plt.scatter(X_out[:, 0], X_out[:, -1], color='blue', label = 'Synthesized Data')
    plt.ylabel("R600_HD")
    plt.xlabel("TZ6_Flow")
    plt.legend(loc="upper left")
    plt.show()
  # save plot every set epoch_steps to file
#   filename1 = '%s_generated_plot_%06d.png' % (name, (epoch_step+1))
#   plt.savefig(filename1)

# %% [markdown]
# The original paper describes using a pool of previously generated synthetic data points from which examples are randomly selected and used to update the discriminator model. This can be implemented using a list for each domain and a using a function to populate the pool, then randomly replace elements from the pool once it is at capacity. Here the pool size is set to 2 points because of the small size of our datasets. The `update_sim_pool()` function below implements this, based on the official Torch implementation in image_pool.lua.
# <br><font color='red'>For more details please see item **[1]** in the **Resources** below.</font>

# %%
# Update simulation pool for fake datapoints
def update_sim_pool(pool, data_points, max_size=5):
    selected = list()
    for data in data_points:
        if len(pool) < max_size:
            # stock the pool
            pool.append(data)
            selected.append(data)
        elif random.random() < 0.5:
            # use data point, but don't add it to the pool
            selected.append(data)
        else:
            # replace an existing data point and use replaced data point
            ix = randint(0, len(pool))
            selected.append(pool[ix])
            pool[ix] = data
    return np.asarray(selected)

# %%
# Train cyclegan models
def train(d_model_A, d_model_B, g_model_AtoB, g_model_BtoA, c_model_AtoB, c_model_BtoA, dataset):
    # define properties of the training run
    n_epochs, n_batch = 10000, 2
    # unpack dataset
    trainA, trainB = dataset
    # prepare image pool for fakes
    poolA, poolB = list(), list()
    # prepare lists for storing training loss history stats 
    discA_loss_realA_hist, discA_loss_fakeA_hist = list(), list()
    discB_loss_realB_hist, discB_loss_fakeB_hist = list(), list()
    gen_loss_A2B_hist, gen_loss_B2A_hist = list(), list()
    # calculate the number of batches per training epoch
    bat_per_epo = int(len(trainA) / n_batch)
    # calculate the number of training iterations
    n_steps = bat_per_epo * n_epochs
    # manually enumerate epochs
    for i in range(n_steps):
        # select a batch of real samples
        X_realA, y_realA = generate_real_samples(trainA, n_samples = 1)
        X_realB, y_realB = generate_real_samples(trainB, n_samples = 1)
        # generate a batch of fake samples
        X_fakeA, y_fakeA = generate_fake_samples(g_model_BtoA, X_realB)
        X_fakeB, y_fakeB = generate_fake_samples(g_model_AtoB, X_realA)
        # update fakes from pool
        X_fakeA = update_sim_pool(poolA, X_fakeA)
        X_fakeB = update_sim_pool(poolB, X_fakeB)
        # update generator B->A via adversarial and cycle loss
        g_loss2, _, _, _, _  = c_model_BtoA.train_on_batch([X_realB, X_realA], [y_realA, X_realA, X_realB, X_realA])        
        # update discriminator for A -> [real/fake]
        dA_loss1 = d_model_A.train_on_batch(X_realA, y_realA)
        dA_loss2 = d_model_A.train_on_batch(X_fakeA, y_fakeA)
        # update generator A->B via adversarial and cycle loss
        g_loss1, _, _, _, _ = c_model_AtoB.train_on_batch([X_realA, X_realB], [y_realB, X_realB, X_realA, X_realB])
        # update discriminator for B -> [real/fake]
        dB_loss1 = d_model_B.train_on_batch(X_realB, y_realB)
        dB_loss2 = d_model_B.train_on_batch(X_fakeB, y_fakeB)
        discA_loss_realA_hist.append(dA_loss1)
        discA_loss_fakeA_hist.append(dA_loss2)
        discB_loss_realB_hist.append(dB_loss1)
        discB_loss_fakeB_hist.append(dB_loss2)
        gen_loss_A2B_hist.append(g_loss1)
        gen_loss_B2A_hist.append(g_loss2)
        # summarize performance and Print training statistics every 100 Epochs 
        if (i+1) % 100 == 0:
            print('Epoch:',i+1,'; discA_realA:',round(dA_loss1,3),'; discA_fakeA:',round(dA_loss2,3),'; discB_realB:',round(dB_loss1,3),
                '; discB_fakeB:',round(dB_loss2,3),'; gen_loss_A2B:',round(g_loss1,3),';gen_loss_B2A:',round(g_loss2,3))
             # Plot samples every 100 epochs
#             summarize_performance(i, g_model_AtoB, trainA, 'AtoB')
#             summarize_performance(i, g_model_BtoA, trainB, 'BtoA')
#             print('Epoch:',i+1,'; discA_realA:',np.array(dA_loss1),'; discA_fakeA:', np.array(dA_loss2),
#                 '; discB_realB:', np.array(dB_loss1),'; discB_fakeB:', np.array(dB_loss2),
#                 '; gen_loss_A2B:', np.array(g_loss1),'; gen_loss_B2A:',np.array(g_loss2))
    return discA_loss_realA_hist,discA_loss_fakeA_hist,discB_loss_realB_hist,discB_loss_fakeB_hist,gen_loss_A2B_hist,gen_loss_B2A_hist

# %%
# load a dataset as a list of two numpy arrays
dataset = [LTR_df,Sim_df]
# train models
discA_loss_realA_hist, discA_loss_fakeA_hist, discB_loss_realB_hist, discB_loss_fakeB_hist, gen_loss_A2B_hist, gen_loss_B2A_hist = train(d_model_A, d_model_B, g_model_AtoB, g_model_BtoA, c_model_AtoB, c_model_BtoA, dataset)
# Out:
# Epoch: 100 ; discA_realA: 0.372 ; discA_fakeA: 0.007 ; discB_realB: 0.363 ; discB_fakeB: 0.008 ; gen_loss_A2B: 5.06 ;gen_loss_B2A: 5.01
# Epoch: 200 ; discA_realA: 0.219 ; discA_fakeA: 0.042 ; discB_realB: 0.203 ; discB_fakeB: 0.043 ; gen_loss_A2B: 3.481 ;gen_loss_B2A: 4.053
# Epoch: 300 ; discA_realA: 0.124 ; discA_fakeA: 0.1 ; discB_realB: 0.121 ; discB_fakeB: 0.1 ; gen_loss_A2B: 1.996 ;gen_loss_B2A: 2.327
# Epoch: 400 ; discA_realA: 0.114 ; discA_fakeA: 0.123 ; discB_realB: 0.125 ; discB_fakeB: 0.128 ; gen_loss_A2B: 1.604 ;gen_loss_B2A: 1.887
# Epoch: 500 ; discA_realA: 0.148 ; discA_fakeA: 0.125 ; discB_realB: 0.097 ; discB_fakeB: 0.118 ; gen_loss_A2B: 4.229 ;gen_loss_B2A: 4.401
# Epoch: 600 ; discA_realA: 0.138 ; discA_fakeA: 0.128 ; discB_realB: 0.123 ; discB_fakeB: 0.119 ; gen_loss_A2B: 1.076 ;gen_loss_B2A: 1.25
# Epoch: 700 ; discA_realA: 0.102 ; discA_fakeA: 0.115 ; discB_realB: 0.149 ; discB_fakeB: 0.14 ; gen_loss_A2B: 2.536 ;gen_loss_B2A: 2.353
# Epoch: 800 ; discA_realA: 0.141 ; discA_fakeA: 0.109 ; discB_realB: 0.144 ; discB_fakeB: 0.12 ; gen_loss_A2B: 1.488 ;gen_loss_B2A: 1.666
# Epoch: 900 ; discA_realA: 0.093 ; discA_fakeA: 0.105 ; discB_realB: 0.11 ; discB_fakeB: 0.12 ; gen_loss_A2B: 4.731 ;gen_loss_B2A: 4.549
# Epoch: 1000 ; discA_realA: 0.135 ; discA_fakeA: 0.111 ; discB_realB: 0.143 ; discB_fakeB: 0.157 ; gen_loss_A2B: 1.486 ;gen_loss_B2A: 1.615
# Epoch: 1100 ; discA_realA: 0.134 ; discA_fakeA: 0.126 ; discB_realB: 0.148 ; discB_fakeB: 0.12 ; gen_loss_A2B: 2.937 ;gen_loss_B2A: 2.906
# Epoch: 1200 ; discA_realA: 0.131 ; discA_fakeA: 0.099 ; discB_realB: 0.135 ; discB_fakeB: 0.112 ; gen_loss_A2B: 1.194 ;gen_loss_B2A: 1.667
# Epoch: 1300 ; discA_realA: 0.109 ; discA_fakeA: 0.117 ; discB_realB: 0.141 ; discB_fakeB: 0.108 ; gen_loss_A2B: 0.795 ;gen_loss_B2A: 1.029
# Epoch: 1400 ; discA_realA: 0.135 ; discA_fakeA: 0.12 ; discB_realB: 0.146 ; discB_fakeB: 0.095 ; gen_loss_A2B: 4.92 ;gen_loss_B2A: 5.068
# Epoch: 1500 ; discA_realA: 0.107 ; discA_fakeA: 0.163 ; discB_realB: 0.124 ; discB_fakeB: 0.142 ; gen_loss_A2B: 3.031 ;gen_loss_B2A: 2.397
# Epoch: 1600 ; discA_realA: 0.126 ; discA_fakeA: 0.138 ; discB_realB: 0.136 ; discB_fakeB: 0.106 ; gen_loss_A2B: 1.335 ;gen_loss_B2A: 1.464
# Epoch: 1700 ; discA_realA: 0.129 ; discA_fakeA: 0.167 ; discB_realB: 0.129 ; discB_fakeB: 0.094 ; gen_loss_A2B: 4.449 ;gen_loss_B2A: 4.548
# Epoch: 1800 ; discA_realA: 0.127 ; discA_fakeA: 0.1 ; discB_realB: 0.139 ; discB_fakeB: 0.119 ; gen_loss_A2B: 2.298 ;gen_loss_B2A: 2.416
# Epoch: 1900 ; discA_realA: 0.097 ; discA_fakeA: 0.095 ; discB_realB: 0.137 ; discB_fakeB: 0.156 ; gen_loss_A2B: 2.462 ;gen_loss_B2A: 2.656
# Epoch: 2000 ; discA_realA: 0.12 ; discA_fakeA: 0.119 ; discB_realB: 0.137 ; discB_fakeB: 0.094 ; gen_loss_A2B: 2.09 ;gen_loss_B2A: 2.901
# Epoch: 2100 ; discA_realA: 0.119 ; discA_fakeA: 0.078 ; discB_realB: 0.133 ; discB_fakeB: 0.107 ; gen_loss_A2B: 3.51 ;gen_loss_B2A: 3.025
# Epoch: 2200 ; discA_realA: 0.114 ; discA_fakeA: 0.123 ; discB_realB: 0.137 ; discB_fakeB: 0.107 ; gen_loss_A2B: 0.878 ;gen_loss_B2A: 1.126
# Epoch: 2300 ; discA_realA: 0.11 ; discA_fakeA: 0.116 ; discB_realB: 0.141 ; discB_fakeB: 0.149 ; gen_loss_A2B: 3.047 ;gen_loss_B2A: 3.313
# Epoch: 2400 ; discA_realA: 0.127 ; discA_fakeA: 0.177 ; discB_realB: 0.134 ; discB_fakeB: 0.109 ; gen_loss_A2B: 1.214 ;gen_loss_B2A: 1.662
# Epoch: 2500 ; discA_realA: 0.114 ; discA_fakeA: 0.151 ; discB_realB: 0.128 ; discB_fakeB: 0.141 ; gen_loss_A2B: 1.078 ;gen_loss_B2A: 1.225
# Epoch: 2600 ; discA_realA: 0.122 ; discA_fakeA: 0.138 ; discB_realB: 0.145 ; discB_fakeB: 0.118 ; gen_loss_A2B: 2.464 ;gen_loss_B2A: 2.37
# Epoch: 2700 ; discA_realA: 0.105 ; discA_fakeA: 0.075 ; discB_realB: 0.133 ; discB_fakeB: 0.102 ; gen_loss_A2B: 1.718 ;gen_loss_B2A: 2.32
# Epoch: 2800 ; discA_realA: 0.107 ; discA_fakeA: 0.174 ; discB_realB: 0.114 ; discB_fakeB: 0.112 ; gen_loss_A2B: 2.897 ;gen_loss_B2A: 2.532
# Epoch: 2900 ; discA_realA: 0.103 ; discA_fakeA: 0.143 ; discB_realB: 0.141 ; discB_fakeB: 0.114 ; gen_loss_A2B: 1.546 ;gen_loss_B2A: 1.968
# Epoch: 3000 ; discA_realA: 0.088 ; discA_fakeA: 0.118 ; discB_realB: 0.132 ; discB_fakeB: 0.131 ; gen_loss_A2B: 0.539 ;gen_loss_B2A: 0.684
# Epoch: 3100 ; discA_realA: 0.103 ; discA_fakeA: 0.088 ; discB_realB: 0.122 ; discB_fakeB: 0.114 ; gen_loss_A2B: 1.507 ;gen_loss_B2A: 1.92
# Epoch: 3200 ; discA_realA: 0.098 ; discA_fakeA: 0.092 ; discB_realB: 0.114 ; discB_fakeB: 0.121 ; gen_loss_A2B: 0.899 ;gen_loss_B2A: 0.86
# Epoch: 3300 ; discA_realA: 0.112 ; discA_fakeA: 0.097 ; discB_realB: 0.118 ; discB_fakeB: 0.123 ; gen_loss_A2B: 0.781 ;gen_loss_B2A: 0.894
# Epoch: 3400 ; discA_realA: 0.127 ; discA_fakeA: 0.084 ; discB_realB: 0.099 ; discB_fakeB: 0.121 ; gen_loss_A2B: 2.16 ;gen_loss_B2A: 2.313
# Epoch: 3500 ; discA_realA: 0.115 ; discA_fakeA: 0.139 ; discB_realB: 0.096 ; discB_fakeB: 0.119 ; gen_loss_A2B: 1.524 ;gen_loss_B2A: 1.403
# Epoch: 3600 ; discA_realA: 0.115 ; discA_fakeA: 0.165 ; discB_realB: 0.094 ; discB_fakeB: 0.124 ; gen_loss_A2B: 1.437 ;gen_loss_B2A: 1.324
# Epoch: 3700 ; discA_realA: 0.088 ; discA_fakeA: 0.08 ; discB_realB: 0.111 ; discB_fakeB: 0.107 ; gen_loss_A2B: 0.554 ;gen_loss_B2A: 0.527
# Epoch: 3800 ; discA_realA: 0.083 ; discA_fakeA: 0.084 ; discB_realB: 0.126 ; discB_fakeB: 0.12 ; gen_loss_A2B: 0.387 ;gen_loss_B2A: 0.359
# Epoch: 3900 ; discA_realA: 0.098 ; discA_fakeA: 0.115 ; discB_realB: 0.115 ; discB_fakeB: 0.105 ; gen_loss_A2B: 0.408 ;gen_loss_B2A: 0.393
# Epoch: 4000 ; discA_realA: 0.141 ; discA_fakeA: 0.145 ; discB_realB: 0.146 ; discB_fakeB: 0.12 ; gen_loss_A2B: 1.212 ;gen_loss_B2A: 1.614
# Epoch: 4100 ; discA_realA: 0.149 ; discA_fakeA: 0.14 ; discB_realB: 0.145 ; discB_fakeB: 0.12 ; gen_loss_A2B: 1.226 ;gen_loss_B2A: 1.654
# Epoch: 4200 ; discA_realA: 0.142 ; discA_fakeA: 0.106 ; discB_realB: 0.1 ; discB_fakeB: 0.15 ; gen_loss_A2B: 0.572 ;gen_loss_B2A: 0.736
# Epoch: 4300 ; discA_realA: 0.083 ; discA_fakeA: 0.17 ; discB_realB: 0.08 ; discB_fakeB: 0.082 ; gen_loss_A2B: 0.687 ;gen_loss_B2A: 0.572
# Epoch: 4400 ; discA_realA: 0.083 ; discA_fakeA: 0.161 ; discB_realB: 0.172 ; discB_fakeB: 0.078 ; gen_loss_A2B: 0.529 ;gen_loss_B2A: 0.32
# Epoch: 4500 ; discA_realA: 0.094 ; discA_fakeA: 0.094 ; discB_realB: 0.078 ; discB_fakeB: 0.117 ; gen_loss_A2B: 0.624 ;gen_loss_B2A: 0.583
# Epoch: 4600 ; discA_realA: 0.086 ; discA_fakeA: 0.172 ; discB_realB: 0.186 ; discB_fakeB: 0.083 ; gen_loss_A2B: 0.557 ;gen_loss_B2A: 0.363
# Epoch: 4700 ; discA_realA: 0.15 ; discA_fakeA: 0.133 ; discB_realB: 0.133 ; discB_fakeB: 0.121 ; gen_loss_A2B: 1.159 ;gen_loss_B2A: 1.589
# Epoch: 4800 ; discA_realA: 0.154 ; discA_fakeA: 0.124 ; discB_realB: 0.121 ; discB_fakeB: 0.117 ; gen_loss_A2B: 1.228 ;gen_loss_B2A: 1.707
# Epoch: 4900 ; discA_realA: 0.091 ; discA_fakeA: 0.094 ; discB_realB: 0.076 ; discB_fakeB: 0.119 ; gen_loss_A2B: 0.478 ;gen_loss_B2A: 0.459
# Epoch: 5000 ; discA_realA: 0.155 ; discA_fakeA: 0.082 ; discB_realB: 0.046 ; discB_fakeB: 0.162 ; gen_loss_A2B: 1.571 ;gen_loss_B2A: 2.009
# Epoch: 5100 ; discA_realA: 0.152 ; discA_fakeA: 0.113 ; discB_realB: 0.067 ; discB_fakeB: 0.116 ; gen_loss_A2B: 1.148 ;gen_loss_B2A: 1.647
# Epoch: 5200 ; discA_realA: 0.091 ; discA_fakeA: 0.164 ; discB_realB: 0.187 ; discB_fakeB: 0.118 ; gen_loss_A2B: 0.502 ;gen_loss_B2A: 0.352
# Epoch: 5300 ; discA_realA: 0.09 ; discA_fakeA: 0.12 ; discB_realB: 0.049 ; discB_fakeB: 0.079 ; gen_loss_A2B: 0.721 ;gen_loss_B2A: 0.664
# Epoch: 5400 ; discA_realA: 0.196 ; discA_fakeA: 0.143 ; discB_realB: 0.172 ; discB_fakeB: 0.195 ; gen_loss_A2B: 0.257 ;gen_loss_B2A: 0.343
# Epoch: 5500 ; discA_realA: 0.06 ; discA_fakeA: 0.155 ; discB_realB: 0.173 ; discB_fakeB: 0.058 ; gen_loss_A2B: 0.468 ;gen_loss_B2A: 0.223
# Epoch: 5600 ; discA_realA: 0.09 ; discA_fakeA: 0.083 ; discB_realB: 0.124 ; discB_fakeB: 0.113 ; gen_loss_A2B: 0.438 ;gen_loss_B2A: 0.356
# Epoch: 5700 ; discA_realA: 0.154 ; discA_fakeA: 0.123 ; discB_realB: 0.142 ; discB_fakeB: 0.157 ; gen_loss_A2B: 1.276 ;gen_loss_B2A: 1.756
# Epoch: 5800 ; discA_realA: 0.165 ; discA_fakeA: 0.09 ; discB_realB: 0.079 ; discB_fakeB: 0.157 ; gen_loss_A2B: 0.281 ;gen_loss_B2A: 0.454
# Epoch: 5900 ; discA_realA: 0.091 ; discA_fakeA: 0.115 ; discB_realB: 0.129 ; discB_fakeB: 0.078 ; gen_loss_A2B: 0.437 ;gen_loss_B2A: 0.354
# Epoch: 6000 ; discA_realA: 0.159 ; discA_fakeA: 0.115 ; discB_realB: 0.17 ; discB_fakeB: 0.156 ; gen_loss_A2B: 0.297 ;gen_loss_B2A: 0.333
# Epoch: 6100 ; discA_realA: 0.193 ; discA_fakeA: 0.163 ; discB_realB: 0.181 ; discB_fakeB: 0.083 ; gen_loss_A2B: 0.211 ;gen_loss_B2A: 0.275
# Epoch: 6200 ; discA_realA: 0.185 ; discA_fakeA: 0.089 ; discB_realB: 0.067 ; discB_fakeB: 0.19 ; gen_loss_A2B: 0.242 ;gen_loss_B2A: 0.437
# Epoch: 6300 ; discA_realA: 0.184 ; discA_fakeA: 0.136 ; discB_realB: 0.118 ; discB_fakeB: 0.183 ; gen_loss_A2B: 0.195 ;gen_loss_B2A: 0.33
# Epoch: 6400 ; discA_realA: 0.099 ; discA_fakeA: 0.106 ; discB_realB: 0.163 ; discB_fakeB: 0.085 ; gen_loss_A2B: 0.424 ;gen_loss_B2A: 0.325
# Epoch: 6500 ; discA_realA: 0.178 ; discA_fakeA: 0.142 ; discB_realB: 0.118 ; discB_fakeB: 0.18 ; gen_loss_A2B: 0.194 ;gen_loss_B2A: 0.325
# Epoch: 6600 ; discA_realA: 0.155 ; discA_fakeA: 0.117 ; discB_realB: 0.125 ; discB_fakeB: 0.114 ; gen_loss_A2B: 0.293 ;gen_loss_B2A: 0.387
# Epoch: 6700 ; discA_realA: 0.177 ; discA_fakeA: 0.095 ; discB_realB: 0.079 ; discB_fakeB: 0.09 ; gen_loss_A2B: 0.188 ;gen_loss_B2A: 0.365
# Epoch: 6800 ; discA_realA: 0.094 ; discA_fakeA: 0.18 ; discB_realB: 0.088 ; discB_fakeB: 0.091 ; gen_loss_A2B: 0.409 ;gen_loss_B2A: 0.42
# Epoch: 6900 ; discA_realA: 0.152 ; discA_fakeA: 0.181 ; discB_realB: 0.182 ; discB_fakeB: 0.115 ; gen_loss_A2B: 1.178 ;gen_loss_B2A: 1.527
# Epoch: 7000 ; discA_realA: 0.095 ; discA_fakeA: 0.134 ; discB_realB: 0.08 ; discB_fakeB: 0.151 ; gen_loss_A2B: 0.385 ;gen_loss_B2A: 0.402
# Epoch: 7100 ; discA_realA: 0.159 ; discA_fakeA: 0.135 ; discB_realB: 0.135 ; discB_fakeB: 0.15 ; gen_loss_A2B: 0.274 ;gen_loss_B2A: 0.348
# Epoch: 7200 ; discA_realA: 0.096 ; discA_fakeA: 0.092 ; discB_realB: 0.148 ; discB_fakeB: 0.177 ; gen_loss_A2B: 0.412 ;gen_loss_B2A: 0.34
# Epoch: 7300 ; discA_realA: 0.151 ; discA_fakeA: 0.116 ; discB_realB: 0.108 ; discB_fakeB: 0.116 ; gen_loss_A2B: 1.105 ;gen_loss_B2A: 1.586
# Epoch: 7400 ; discA_realA: 0.153 ; discA_fakeA: 0.114 ; discB_realB: 0.117 ; discB_fakeB: 0.182 ; gen_loss_A2B: 0.276 ;gen_loss_B2A: 0.364
# Epoch: 7500 ; discA_realA: 0.156 ; discA_fakeA: 0.17 ; discB_realB: 0.076 ; discB_fakeB: 0.148 ; gen_loss_A2B: 0.273 ;gen_loss_B2A: 0.422
# Epoch: 7600 ; discA_realA: 0.148 ; discA_fakeA: 0.092 ; discB_realB: 0.097 ; discB_fakeB: 0.076 ; gen_loss_A2B: 1.093 ;gen_loss_B2A: 1.599
# Epoch: 7700 ; discA_realA: 0.163 ; discA_fakeA: 0.136 ; discB_realB: 0.181 ; discB_fakeB: 0.091 ; gen_loss_A2B: 0.299 ;gen_loss_B2A: 0.262
# Epoch: 7800 ; discA_realA: 0.192 ; discA_fakeA: 0.188 ; discB_realB: 0.182 ; discB_fakeB: 0.191 ; gen_loss_A2B: 0.192 ;gen_loss_B2A: 0.192
# Epoch: 7900 ; discA_realA: 0.187 ; discA_fakeA: 0.187 ; discB_realB: 0.182 ; discB_fakeB: 0.114 ; gen_loss_A2B: 0.202 ;gen_loss_B2A: 0.189
# Epoch: 8000 ; discA_realA: 0.186 ; discA_fakeA: 0.136 ; discB_realB: 0.18 ; discB_fakeB: 0.183 ; gen_loss_A2B: 0.198 ;gen_loss_B2A: 0.19
# Epoch: 8100 ; discA_realA: 0.145 ; discA_fakeA: 0.151 ; discB_realB: 0.156 ; discB_fakeB: 0.115 ; gen_loss_A2B: 1.009 ;gen_loss_B2A: 1.347
# Epoch: 8200 ; discA_realA: 0.141 ; discA_fakeA: 0.169 ; discB_realB: 0.167 ; discB_fakeB: 0.115 ; gen_loss_A2B: 0.931 ;gen_loss_B2A: 1.197
# Epoch: 8300 ; discA_realA: 0.181 ; discA_fakeA: 0.105 ; discB_realB: 0.155 ; discB_fakeB: 0.175 ; gen_loss_A2B: 0.186 ;gen_loss_B2A: 0.229
# Epoch: 8400 ; discA_realA: 0.137 ; discA_fakeA: 0.093 ; discB_realB: 0.09 ; discB_fakeB: 0.178 ; gen_loss_A2B: 0.955 ;gen_loss_B2A: 1.378
# Epoch: 8500 ; discA_realA: 0.142 ; discA_fakeA: 0.15 ; discB_realB: 0.153 ; discB_fakeB: 0.08 ; gen_loss_A2B: 0.916 ;gen_loss_B2A: 1.213
# Epoch: 8600 ; discA_realA: 0.14 ; discA_fakeA: 0.137 ; discB_realB: 0.144 ; discB_fakeB: 0.115 ; gen_loss_A2B: 0.924 ;gen_loss_B2A: 1.24
# Epoch: 8700 ; discA_realA: 0.062 ; discA_fakeA: 0.128 ; discB_realB: 0.081 ; discB_fakeB: 0.09 ; gen_loss_A2B: 0.405 ;gen_loss_B2A: 0.371
# Epoch: 8800 ; discA_realA: 0.186 ; discA_fakeA: 0.087 ; discB_realB: 0.081 ; discB_fakeB: 0.182 ; gen_loss_A2B: 0.178 ;gen_loss_B2A: 0.367
# Epoch: 8900 ; discA_realA: 0.141 ; discA_fakeA: 0.17 ; discB_realB: 0.135 ; discB_fakeB: 0.181 ; gen_loss_A2B: 0.899 ;gen_loss_B2A: 1.244
# Epoch: 9000 ; discA_realA: 0.066 ; discA_fakeA: 0.089 ; discB_realB: 0.132 ; discB_fakeB: 0.119 ; gen_loss_A2B: 0.436 ;gen_loss_B2A: 0.338
# Epoch: 9100 ; discA_realA: 0.186 ; discA_fakeA: 0.088 ; discB_realB: 0.09 ; discB_fakeB: 0.177 ; gen_loss_A2B: 0.19 ;gen_loss_B2A: 0.359
# Epoch: 9200 ; discA_realA: 0.14 ; discA_fakeA: 0.092 ; discB_realB: 0.141 ; discB_fakeB: 0.119 ; gen_loss_A2B: 0.879 ;gen_loss_B2A: 1.189
# Epoch: 9300 ; discA_realA: 0.091 ; discA_fakeA: 0.154 ; discB_realB: 0.152 ; discB_fakeB: 0.094 ; gen_loss_A2B: 0.414 ;gen_loss_B2A: 0.306
# Epoch: 9400 ; discA_realA: 0.16 ; discA_fakeA: 0.186 ; discB_realB: 0.173 ; discB_fakeB: 0.119 ; gen_loss_A2B: 0.309 ;gen_loss_B2A: 0.265
# Epoch: 9500 ; discA_realA: 0.075 ; discA_fakeA: 0.101 ; discB_realB: 0.133 ; discB_fakeB: 0.143 ; gen_loss_A2B: 0.397 ;gen_loss_B2A: 0.307
# Epoch: 9600 ; discA_realA: 0.07 ; discA_fakeA: 0.098 ; discB_realB: 0.127 ; discB_fakeB: 0.171 ; gen_loss_A2B: 0.42 ;gen_loss_B2A: 0.332
# Epoch: 9700 ; discA_realA: 0.092 ; discA_fakeA: 0.097 ; discB_realB: 0.1 ; discB_fakeB: 0.095 ; gen_loss_A2B: 0.436 ;gen_loss_B2A: 0.451
# Epoch: 9800 ; discA_realA: 0.137 ; discA_fakeA: 0.12 ; discB_realB: 0.127 ; discB_fakeB: 0.117 ; gen_loss_A2B: 0.852 ;gen_loss_B2A: 1.177
# Epoch: 9900 ; discA_realA: 0.153 ; discA_fakeA: 0.126 ; discB_realB: 0.135 ; discB_fakeB: 0.14 ; gen_loss_A2B: 0.32 ;gen_loss_B2A: 0.369
# Epoch: 10000 ; discA_realA: 0.07 ; discA_fakeA: 0.118 ; discB_realB: 0.17 ; discB_fakeB: 0.083 ; gen_loss_A2B: 0.431 ;gen_loss_B2A: 0.231
# Epoch: 10100 ; discA_realA: 0.09 ; discA_fakeA: 0.155 ; discB_realB: 0.151 ; discB_fakeB: 0.082 ; gen_loss_A2B: 0.437 ;gen_loss_B2A: 0.329
# Epoch: 10200 ; discA_realA: 0.142 ; discA_fakeA: 0.095 ; discB_realB: 0.102 ; discB_fakeB: 0.119 ; gen_loss_A2B: 0.796 ;gen_loss_B2A: 1.169
# Epoch: 10300 ; discA_realA: 0.143 ; discA_fakeA: 0.096 ; discB_realB: 0.1 ; discB_fakeB: 0.142 ; gen_loss_A2B: 0.848 ;gen_loss_B2A: 1.242
# Epoch: 10400 ; discA_realA: 0.154 ; discA_fakeA: 0.11 ; discB_realB: 0.117 ; discB_fakeB: 0.143 ; gen_loss_A2B: 0.287 ;gen_loss_B2A: 0.367
# Epoch: 10500 ; discA_realA: 0.178 ; discA_fakeA: 0.122 ; discB_realB: 0.13 ; discB_fakeB: 0.087 ; gen_loss_A2B: 0.194 ;gen_loss_B2A: 0.286
# Epoch: 10600 ; discA_realA: 0.175 ; discA_fakeA: 0.092 ; discB_realB: 0.091 ; discB_fakeB: 0.169 ; gen_loss_A2B: 0.2 ;gen_loss_B2A: 0.357
# Epoch: 10700 ; discA_realA: 0.174 ; discA_fakeA: 0.093 ; discB_realB: 0.156 ; discB_fakeB: 0.167 ; gen_loss_A2B: 0.201 ;gen_loss_B2A: 0.211
# Epoch: 10800 ; discA_realA: 0.172 ; discA_fakeA: 0.098 ; discB_realB: 0.098 ; discB_fakeB: 0.14 ; gen_loss_A2B: 0.208 ;gen_loss_B2A: 0.34
# Epoch: 10900 ; discA_realA: 0.148 ; discA_fakeA: 0.113 ; discB_realB: 0.12 ; discB_fakeB: 0.1 ; gen_loss_A2B: 0.305 ;gen_loss_B2A: 0.373
# Epoch: 11000 ; discA_realA: 0.174 ; discA_fakeA: 0.181 ; discB_realB: 0.165 ; discB_fakeB: 0.171 ; gen_loss_A2B: 0.206 ;gen_loss_B2A: 0.19
# Epoch: 11100 ; discA_realA: 0.096 ; discA_fakeA: 0.134 ; discB_realB: 0.155 ; discB_fakeB: 0.1 ; gen_loss_A2B: 0.394 ;gen_loss_B2A: 0.277
# Epoch: 11200 ; discA_realA: 0.091 ; discA_fakeA: 0.108 ; discB_realB: 0.112 ; discB_fakeB: 0.085 ; gen_loss_A2B: 0.433 ;gen_loss_B2A: 0.42
# Epoch: 11300 ; discA_realA: 0.147 ; discA_fakeA: 0.096 ; discB_realB: 0.146 ; discB_fakeB: 0.166 ; gen_loss_A2B: 0.742 ;gen_loss_B2A: 0.984
# Epoch: 11400 ; discA_realA: 0.073 ; discA_fakeA: 0.11 ; discB_realB: 0.146 ; discB_fakeB: 0.087 ; gen_loss_A2B: 0.367 ;gen_loss_B2A: 0.243
# Epoch: 11500 ; discA_realA: 0.173 ; discA_fakeA: 0.113 ; discB_realB: 0.117 ; discB_fakeB: 0.171 ; gen_loss_A2B: 0.189 ;gen_loss_B2A: 0.299
# Epoch: 11600 ; discA_realA: 0.068 ; discA_fakeA: 0.169 ; discB_realB: 0.159 ; discB_fakeB: 0.083 ; gen_loss_A2B: 0.395 ;gen_loss_B2A: 0.222
# Epoch: 11700 ; discA_realA: 0.151 ; discA_fakeA: 0.116 ; discB_realB: 0.124 ; discB_fakeB: 0.142 ; gen_loss_A2B: 0.354 ;gen_loss_B2A: 0.436
# Epoch: 11800 ; discA_realA: 0.177 ; discA_fakeA: 0.163 ; discB_realB: 0.13 ; discB_fakeB: 0.173 ; gen_loss_A2B: 0.191 ;gen_loss_B2A: 0.279
# Epoch: 11900 ; discA_realA: 0.18 ; discA_fakeA: 0.136 ; discB_realB: 0.103 ; discB_fakeB: 0.097 ; gen_loss_A2B: 0.188 ;gen_loss_B2A: 0.341
# Epoch: 12000 ; discA_realA: 0.096 ; discA_fakeA: 0.111 ; discB_realB: 0.092 ; discB_fakeB: 0.1 ; gen_loss_A2B: 0.47 ;gen_loss_B2A: 0.497
# Epoch: 12100 ; discA_realA: 0.088 ; discA_fakeA: 0.089 ; discB_realB: 0.147 ; discB_fakeB: 0.178 ; gen_loss_A2B: 0.435 ;gen_loss_B2A: 0.325
# Epoch: 12200 ; discA_realA: 0.178 ; discA_fakeA: 0.092 ; discB_realB: 0.139 ; discB_fakeB: 0.173 ; gen_loss_A2B: 0.193 ;gen_loss_B2A: 0.257
# Epoch: 12300 ; discA_realA: 0.065 ; discA_fakeA: 0.11 ; discB_realB: 0.16 ; discB_fakeB: 0.081 ; gen_loss_A2B: 0.406 ;gen_loss_B2A: 0.228
# Epoch: 12400 ; discA_realA: 0.139 ; discA_fakeA: 0.174 ; discB_realB: 0.162 ; discB_fakeB: 0.122 ; gen_loss_A2B: 0.574 ;gen_loss_B2A: 0.684
# Epoch: 12500 ; discA_realA: 0.181 ; discA_fakeA: 0.088 ; discB_realB: 0.091 ; discB_fakeB: 0.078 ; gen_loss_A2B: 0.199 ;gen_loss_B2A: 0.359
# Epoch: 12600 ; discA_realA: 0.148 ; discA_fakeA: 0.105 ; discB_realB: 0.112 ; discB_fakeB: 0.143 ; gen_loss_A2B: 0.32 ;gen_loss_B2A: 0.417
# Epoch: 12700 ; discA_realA: 0.146 ; discA_fakeA: 0.11 ; discB_realB: 0.153 ; discB_fakeB: 0.122 ; gen_loss_A2B: 0.642 ;gen_loss_B2A: 0.828
# Epoch: 12800 ; discA_realA: 0.154 ; discA_fakeA: 0.085 ; discB_realB: 0.082 ; discB_fakeB: 0.094 ; gen_loss_A2B: 0.306 ;gen_loss_B2A: 0.46
# Epoch: 12900 ; discA_realA: 0.185 ; discA_fakeA: 0.087 ; discB_realB: 0.091 ; discB_fakeB: 0.095 ; gen_loss_A2B: 0.206 ;gen_loss_B2A: 0.378
# Epoch: 13000 ; discA_realA: 0.066 ; discA_fakeA: 0.153 ; discB_realB: 0.102 ; discB_fakeB: 0.079 ; gen_loss_A2B: 0.373 ;gen_loss_B2A: 0.361
# Epoch: 13100 ; discA_realA: 0.15 ; discA_fakeA: 0.105 ; discB_realB: 0.139 ; discB_fakeB: 0.152 ; gen_loss_A2B: 0.535 ;gen_loss_B2A: 0.713
# Epoch: 13200 ; discA_realA: 0.186 ; discA_fakeA: 0.114 ; discB_realB: 0.122 ; discB_fakeB: 0.076 ; gen_loss_A2B: 0.182 ;gen_loss_B2A: 0.309
# Epoch: 13300 ; discA_realA: 0.081 ; discA_fakeA: 0.093 ; discB_realB: 0.143 ; discB_fakeB: 0.093 ; gen_loss_A2B: 0.433 ;gen_loss_B2A: 0.32
# Epoch: 13400 ; discA_realA: 0.189 ; discA_fakeA: 0.097 ; discB_realB: 0.107 ; discB_fakeB: 0.182 ; gen_loss_A2B: 0.181 ;gen_loss_B2A: 0.347
# Epoch: 13500 ; discA_realA: 0.153 ; discA_fakeA: 0.098 ; discB_realB: 0.177 ; discB_fakeB: 0.126 ; gen_loss_A2B: 0.556 ;gen_loss_B2A: 0.657
# Epoch: 13600 ; discA_realA: 0.184 ; discA_fakeA: 0.086 ; discB_realB: 0.084 ; discB_fakeB: 0.177 ; gen_loss_A2B: 0.189 ;gen_loss_B2A: 0.377
# Epoch: 13700 ; discA_realA: 0.15 ; discA_fakeA: 0.171 ; discB_realB: 0.096 ; discB_fakeB: 0.095 ; gen_loss_A2B: 0.311 ;gen_loss_B2A: 0.444
# Epoch: 13800 ; discA_realA: 0.152 ; discA_fakeA: 0.1 ; discB_realB: 0.093 ; discB_fakeB: 0.151 ; gen_loss_A2B: 0.322 ;gen_loss_B2A: 0.474
# Epoch: 13900 ; discA_realA: 0.151 ; discA_fakeA: 0.089 ; discB_realB: 0.089 ; discB_fakeB: 0.148 ; gen_loss_A2B: 0.311 ;gen_loss_B2A: 0.44
# Epoch: 14000 ; discA_realA: 0.09 ; discA_fakeA: 0.11 ; discB_realB: 0.112 ; discB_fakeB: 0.123 ; gen_loss_A2B: 0.414 ;gen_loss_B2A: 0.408
# Epoch: 14100 ; discA_realA: 0.148 ; discA_fakeA: 0.103 ; discB_realB: 0.112 ; discB_fakeB: 0.078 ; gen_loss_A2B: 0.285 ;gen_loss_B2A: 0.382
# Epoch: 14200 ; discA_realA: 0.092 ; discA_fakeA: 0.094 ; discB_realB: 0.099 ; discB_fakeB: 0.098 ; gen_loss_A2B: 0.437 ;gen_loss_B2A: 0.453
# Epoch: 14300 ; discA_realA: 0.162 ; discA_fakeA: 0.142 ; discB_realB: 0.121 ; discB_fakeB: 0.127 ; gen_loss_A2B: 0.543 ;gen_loss_B2A: 0.788
# Epoch: 14400 ; discA_realA: 0.16 ; discA_fakeA: 0.092 ; discB_realB: 0.089 ; discB_fakeB: 0.127 ; gen_loss_A2B: 0.506 ;gen_loss_B2A: 0.771
# Epoch: 14500 ; discA_realA: 0.155 ; discA_fakeA: 0.135 ; discB_realB: 0.139 ; discB_fakeB: 0.124 ; gen_loss_A2B: 0.523 ;gen_loss_B2A: 0.689
# Epoch: 14600 ; discA_realA: 0.154 ; discA_fakeA: 0.139 ; discB_realB: 0.14 ; discB_fakeB: 0.125 ; gen_loss_A2B: 0.553 ;gen_loss_B2A: 0.736
# Epoch: 14700 ; discA_realA: 0.144 ; discA_fakeA: 0.105 ; discB_realB: 0.11 ; discB_fakeB: 0.146 ; gen_loss_A2B: 0.308 ;gen_loss_B2A: 0.411
# Epoch: 14800 ; discA_realA: 0.173 ; discA_fakeA: 0.184 ; discB_realB: 0.176 ; discB_fakeB: 0.125 ; gen_loss_A2B: 0.211 ;gen_loss_B2A: 0.204
# Epoch: 14900 ; discA_realA: 0.145 ; discA_fakeA: 0.097 ; discB_realB: 0.1 ; discB_fakeB: 0.17 ; gen_loss_A2B: 0.302 ;gen_loss_B2A: 0.419
# Epoch: 15000 ; discA_realA: 0.09 ; discA_fakeA: 0.133 ; discB_realB: 0.139 ; discB_fakeB: 0.095 ; gen_loss_A2B: 0.43 ;gen_loss_B2A: 0.351
# Epoch: 15100 ; discA_realA: 0.093 ; discA_fakeA: 0.1 ; discB_realB: 0.17 ; discB_fakeB: 0.083 ; gen_loss_A2B: 0.469 ;gen_loss_B2A: 0.337
# Epoch: 15200 ; discA_realA: 0.09 ; discA_fakeA: 0.104 ; discB_realB: 0.092 ; discB_fakeB: 0.081 ; gen_loss_A2B: 0.441 ;gen_loss_B2A: 0.454
# Epoch: 15300 ; discA_realA: 0.169 ; discA_fakeA: 0.099 ; discB_realB: 0.111 ; discB_fakeB: 0.125 ; gen_loss_A2B: 0.203 ;gen_loss_B2A: 0.337
# Epoch: 15400 ; discA_realA: 0.095 ; discA_fakeA: 0.106 ; discB_realB: 0.114 ; discB_fakeB: 0.1 ; gen_loss_A2B: 0.453 ;gen_loss_B2A: 0.45
# Epoch: 15500 ; discA_realA: 0.088 ; discA_fakeA: 0.107 ; discB_realB: 0.11 ; discB_fakeB: 0.097 ; gen_loss_A2B: 0.424 ;gen_loss_B2A: 0.404
# Epoch: 15600 ; discA_realA: 0.156 ; discA_fakeA: 0.122 ; discB_realB: 0.128 ; discB_fakeB: 0.128 ; gen_loss_A2B: 0.476 ;gen_loss_B2A: 0.646
# Epoch: 15700 ; discA_realA: 0.084 ; discA_fakeA: 0.169 ; discB_realB: 0.092 ; discB_fakeB: 0.094 ; gen_loss_A2B: 0.435 ;gen_loss_B2A: 0.418
# Epoch: 15800 ; discA_realA: 0.138 ; discA_fakeA: 0.136 ; discB_realB: 0.138 ; discB_fakeB: 0.144 ; gen_loss_A2B: 0.302 ;gen_loss_B2A: 0.331
# Epoch: 15900 ; discA_realA: 0.073 ; discA_fakeA: 0.104 ; discB_realB: 0.125 ; discB_fakeB: 0.079 ; gen_loss_A2B: 0.381 ;gen_loss_B2A: 0.32
# Epoch: 16000 ; discA_realA: 0.162 ; discA_fakeA: 0.121 ; discB_realB: 0.13 ; discB_fakeB: 0.125 ; gen_loss_A2B: 0.522 ;gen_loss_B2A: 0.714
# Epoch: 16100 ; discA_realA: 0.068 ; discA_fakeA: 0.109 ; discB_realB: 0.114 ; discB_fakeB: 0.173 ; gen_loss_A2B: 0.377 ;gen_loss_B2A: 0.329
# Epoch: 16200 ; discA_realA: 0.143 ; discA_fakeA: 0.1 ; discB_realB: 0.098 ; discB_fakeB: 0.147 ; gen_loss_A2B: 0.293 ;gen_loss_B2A: 0.409
# Epoch: 16300 ; discA_realA: 0.141 ; discA_fakeA: 0.159 ; discB_realB: 0.145 ; discB_fakeB: 0.144 ; gen_loss_A2B: 0.272 ;gen_loss_B2A: 0.278
# Epoch: 16400 ; discA_realA: 0.138 ; discA_fakeA: 0.131 ; discB_realB: 0.129 ; discB_fakeB: 0.164 ; gen_loss_A2B: 0.283 ;gen_loss_B2A: 0.341
# Epoch: 16500 ; discA_realA: 0.161 ; discA_fakeA: 0.142 ; discB_realB: 0.103 ; discB_fakeB: 0.163 ; gen_loss_A2B: 0.207 ;gen_loss_B2A: 0.335
# Epoch: 16600 ; discA_realA: 0.089 ; discA_fakeA: 0.103 ; discB_realB: 0.146 ; discB_fakeB: 0.126 ; gen_loss_A2B: 0.455 ;gen_loss_B2A: 0.38
# Epoch: 16700 ; discA_realA: 0.091 ; discA_fakeA: 0.102 ; discB_realB: 0.111 ; discB_fakeB: 0.099 ; gen_loss_A2B: 0.426 ;gen_loss_B2A: 0.417
# Epoch: 16800 ; discA_realA: 0.07 ; discA_fakeA: 0.146 ; discB_realB: 0.1 ; discB_fakeB: 0.095 ; gen_loss_A2B: 0.376 ;gen_loss_B2A: 0.353
# Epoch: 16900 ; discA_realA: 0.139 ; discA_fakeA: 0.111 ; discB_realB: 0.166 ; discB_fakeB: 0.151 ; gen_loss_A2B: 0.29 ;gen_loss_B2A: 0.272
# Epoch: 17000 ; discA_realA: 0.088 ; discA_fakeA: 0.093 ; discB_realB: 0.145 ; discB_fakeB: 0.099 ; gen_loss_A2B: 0.413 ;gen_loss_B2A: 0.322
# Epoch: 17100 ; discA_realA: 0.146 ; discA_fakeA: 0.102 ; discB_realB: 0.107 ; discB_fakeB: 0.15 ; gen_loss_A2B: 0.252 ;gen_loss_B2A: 0.355
# Epoch: 17200 ; discA_realA: 0.146 ; discA_fakeA: 0.166 ; discB_realB: 0.163 ; discB_fakeB: 0.15 ; gen_loss_A2B: 0.274 ;gen_loss_B2A: 0.259
# Epoch: 17300 ; discA_realA: 0.068 ; discA_fakeA: 0.107 ; discB_realB: 0.118 ; discB_fakeB: 0.15 ; gen_loss_A2B: 0.383 ;gen_loss_B2A: 0.336
# Epoch: 17400 ; discA_realA: 0.142 ; discA_fakeA: 0.182 ; discB_realB: 0.179 ; discB_fakeB: 0.145 ; gen_loss_A2B: 0.296 ;gen_loss_B2A: 0.251
# Epoch: 17500 ; discA_realA: 0.144 ; discA_fakeA: 0.129 ; discB_realB: 0.125 ; discB_fakeB: 0.098 ; gen_loss_A2B: 0.276 ;gen_loss_B2A: 0.351
# Epoch: 17600 ; discA_realA: 0.085 ; discA_fakeA: 0.107 ; discB_realB: 0.15 ; discB_fakeB: 0.15 ; gen_loss_A2B: 0.452 ;gen_loss_B2A: 0.357
# Epoch: 17700 ; discA_realA: 0.065 ; discA_fakeA: 0.135 ; discB_realB: 0.189 ; discB_fakeB: 0.173 ; gen_loss_A2B: 0.412 ;gen_loss_B2A: 0.197
# Epoch: 17800 ; discA_realA: 0.167 ; discA_fakeA: 0.107 ; discB_realB: 0.121 ; discB_fakeB: 0.128 ; gen_loss_A2B: 0.438 ;gen_loss_B2A: 0.619
# Epoch: 17900 ; discA_realA: 0.089 ; discA_fakeA: 0.101 ; discB_realB: 0.106 ; discB_fakeB: 0.075 ; gen_loss_A2B: 0.44 ;gen_loss_B2A: 0.452
# Epoch: 18000 ; discA_realA: 0.14 ; discA_fakeA: 0.098 ; discB_realB: 0.097 ; discB_fakeB: 0.171 ; gen_loss_A2B: 0.276 ;gen_loss_B2A: 0.386
# Epoch: 18100 ; discA_realA: 0.171 ; discA_fakeA: 0.098 ; discB_realB: 0.15 ; discB_fakeB: 0.073 ; gen_loss_A2B: 0.421 ;gen_loss_B2A: 0.524
# Epoch: 18200 ; discA_realA: 0.071 ; discA_fakeA: 0.145 ; discB_realB: 0.145 ; discB_fakeB: 0.1 ; gen_loss_A2B: 0.376 ;gen_loss_B2A: 0.241
# Epoch: 18300 ; discA_realA: 0.141 ; discA_fakeA: 0.098 ; discB_realB: 0.127 ; discB_fakeB: 0.146 ; gen_loss_A2B: 0.284 ;gen_loss_B2A: 0.35
# Epoch: 18400 ; discA_realA: 0.141 ; discA_fakeA: 0.097 ; discB_realB: 0.084 ; discB_fakeB: 0.152 ; gen_loss_A2B: 0.263 ;gen_loss_B2A: 0.384
# Epoch: 18500 ; discA_realA: 0.142 ; discA_fakeA: 0.116 ; discB_realB: 0.123 ; discB_fakeB: 0.151 ; gen_loss_A2B: 0.263 ;gen_loss_B2A: 0.335
# Epoch: 18600 ; discA_realA: 0.169 ; discA_fakeA: 0.115 ; discB_realB: 0.146 ; discB_fakeB: 0.076 ; gen_loss_A2B: 0.421 ;gen_loss_B2A: 0.514
# Epoch: 18700 ; discA_realA: 0.088 ; discA_fakeA: 0.115 ; discB_realB: 0.185 ; discB_fakeB: 0.099 ; gen_loss_A2B: 0.452 ;gen_loss_B2A: 0.313
# Epoch: 18800 ; discA_realA: 0.167 ; discA_fakeA: 0.149 ; discB_realB: 0.168 ; discB_fakeB: 0.131 ; gen_loss_A2B: 0.401 ;gen_loss_B2A: 0.461
# Epoch: 18900 ; discA_realA: 0.138 ; discA_fakeA: 0.153 ; discB_realB: 0.124 ; discB_fakeB: 0.15 ; gen_loss_A2B: 0.276 ;gen_loss_B2A: 0.342
# Epoch: 19000 ; discA_realA: 0.066 ; discA_fakeA: 0.171 ; discB_realB: 0.193 ; discB_fakeB: 0.07 ; gen_loss_A2B: 0.42 ;gen_loss_B2A: 0.197
# Epoch: 19100 ; discA_realA: 0.088 ; discA_fakeA: 0.099 ; discB_realB: 0.112 ; discB_fakeB: 0.101 ; gen_loss_A2B: 0.41 ;gen_loss_B2A: 0.41
# Epoch: 19200 ; discA_realA: 0.168 ; discA_fakeA: 0.144 ; discB_realB: 0.144 ; discB_fakeB: 0.102 ; gen_loss_A2B: 0.205 ;gen_loss_B2A: 0.254
# Epoch: 19300 ; discA_realA: 0.094 ; discA_fakeA: 0.112 ; discB_realB: 0.131 ; discB_fakeB: 0.143 ; gen_loss_A2B: 0.426 ;gen_loss_B2A: 0.404
# Epoch: 19400 ; discA_realA: 0.139 ; discA_fakeA: 0.142 ; discB_realB: 0.146 ; discB_fakeB: 0.143 ; gen_loss_A2B: 0.276 ;gen_loss_B2A: 0.288
# Epoch: 19500 ; discA_realA: 0.175 ; discA_fakeA: 0.124 ; discB_realB: 0.165 ; discB_fakeB: 0.131 ; gen_loss_A2B: 0.41 ;gen_loss_B2A: 0.49
# Epoch: 19600 ; discA_realA: 0.137 ; discA_fakeA: 0.106 ; discB_realB: 0.12 ; discB_fakeB: 0.077 ; gen_loss_A2B: 0.277 ;gen_loss_B2A: 0.367
# Epoch: 19700 ; discA_realA: 0.079 ; discA_fakeA: 0.179 ; discB_realB: 0.181 ; discB_fakeB: 0.102 ; gen_loss_A2B: 0.393 ;gen_loss_B2A: 0.231
# Epoch: 19800 ; discA_realA: 0.096 ; discA_fakeA: 0.108 ; discB_realB: 0.108 ; discB_fakeB: 0.13 ; gen_loss_A2B: 0.415 ;gen_loss_B2A: 0.424
# Epoch: 19900 ; discA_realA: 0.134 ; discA_fakeA: 0.108 ; discB_realB: 0.146 ; discB_fakeB: 0.141 ; gen_loss_A2B: 0.266 ;gen_loss_B2A: 0.27
# Epoch: 20000 ; discA_realA: 0.135 ; discA_fakeA: 0.109 ; discB_realB: 0.105 ; discB_fakeB: 0.145 ; gen_loss_A2B: 0.256 ;gen_loss_B2A: 0.333

# %%
# Create a line plots of loss for the CycleGAN - Generators and Discriminators and save to file
def plot_history(discA_loss_realA_hist, discA_loss_fakeA_hist, discB_loss_realB_hist, discB_loss_fakeB_hist, gen_loss_A2B_hist, gen_loss_B2A_hist):
    ### plot Training Loss Performance of DiscA, DiscB, Gen ###
    fig = plt.figure(figsize=(15,12))
    ax1 = plt.subplot(2, 1, 1)
    ax1.plot(discA_loss_realA_hist, label='discA-realA')
    ax1.plot(discA_loss_fakeA_hist, label='discA-fakeA')
    ax1.plot(discB_loss_realB_hist, label='discB-realB')
    ax1.plot(discB_loss_fakeB_hist, label='discB-fakeB')
    ax1.plot(gen_loss_A2B_hist, label='Gen-A2B')
    ax1.plot(gen_loss_B2A_hist, label='Gen-B2A')
    ax1.legend()
  # save plot to file
#   plt.savefig('plots/GAN_Training_loss.png')
#   plt.close()

# %%
plot_history(discA_loss_realA_hist, discA_loss_fakeA_hist, discB_loss_realB_hist, discB_loss_fakeB_hist, gen_loss_A2B_hist, gen_loss_B2A_hist)

# %% [markdown]
# ### Synthesise Artificial data with trained CycleGAN

# %%
X_syn_scaled1,_ = generate_fake_samples(g_model_AtoB,  Sim_df)
X_synthesised1 = scaler.inverse_transform(X_syn_scaled1)
df_syn1 = pd.DataFrame(data = X_synthesised1, columns = colnames_all)
array_of_hovs = ['CGAN_ASD{}'.format(i) for i in range(len(df_syn1))] # Use List Comprehension to create unique HoV Label for the artificial data point
df_syn1.insert(0, "HoV",array_of_hovs)
df_syn1
# Out:
#            HoV           D         Z         c         V
# 0    CGAN_ASD0  120.209045  0.310074  0.978707  0.231356
# 1    CGAN_ASD1  122.036682  0.292309  1.005169  0.240656
# 2    CGAN_ASD2  124.084549  0.274646  1.013683  0.247953
# 3    CGAN_ASD3  126.123466  0.257118  1.022313  0.255207
# 4    CGAN_ASD4  127.969574  0.242487  1.005182  0.262926
# 5    CGAN_ASD5  129.822174  0.227803  0.987982  0.270673
# 6    CGAN_ASD6  131.682327  0.213058  0.970701  0.278452
# 7    CGAN_ASD7  133.716156  0.198190  0.969618  0.288391
# 8    CGAN_ASD8  135.901581  0.183204  0.982352  0.300191
# 9    CGAN_ASD9  138.101776  0.168115  0.995171  0.312072
# 10  CGAN_ASD10  140.238098  0.156037  1.002465  0.324398
# 11  CGAN_ASD11  142.295166  0.147388  1.005871  0.337243

# %% [markdown]
# ### Data Visualization of Model Output
# Create plots of `Diameter` vs `Correction_Factor` for all three datasets

# %%
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file,output_notebook
from bokeh.models import HoverTool
from bokeh.io import show,export_svgs
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2e266b9f-b313-4e61-981d-4c48143a5d88">Loading BokehJS ...</span>
#     </div>

# %%
p1 = figure(plot_width=1100)
hover = HoverTool(names = ['ActualPoints'],tooltips = [('Diameter (mm)', '@x'), ('Correction Factor','@y')])
hover.point_policy='snap_to_data'

## Add a line renderer - line_dash = 'dashed'
p1.line(dataset_sim['D'],dataset_sim['c'], line_width=2, color="black",line_dash = 'dashed', legend = 'Simulation')
p1.line(df_syn1['D'],df_syn1['c'], line_width=2, color="green", legend = 'CycleGAN_ASD')
p1.line(dataset_LTR['D'],dataset_LTR['c'], line_width=2, color="blue", legend = 'LTR')

## Add a circle renderer with a size, color, and alpha
p1.circle(dataset_sim['D'],dataset_sim['c'], size=12, color="black", alpha=0.85, name = 'ActualPoints',legend = 'Simulation')
p1.circle(dataset_LTR['D'],dataset_LTR['c'], size=12, color="blue", alpha=0.85, name = 'ActualPoints',legend = 'LTR')
p1.circle(df_syn1['D'],df_syn1['c'], size=12, color="green", alpha=0.85, name = 'ActualPoints',legend = 'CycleGAN_ASD')

p1.yaxis.axis_label = "Correction Factor"
p1.xaxis.axis_label = "Diameter (mm)"
p1.legend.location = "top_left" # "bottom_right"
p1.add_tools(hover)

# output_file('plots/CycleGAN_ToyProblem_Dia_Cf.html', mode='inline')
# show the results
show(p1)
# Out:
#   <div class="bk-root" id="a29732cf-68c7-4021-9ffa-6e73a95eb72a"></div>

# %% [markdown]
# ### Resources:
# 1. https://machinelearningmastery.com/how-to-develop-cyclegan-models-from-scratch-with-keras/
# 2. https://machinelearningmastery.com/how-to-develop-a-generative-adversarial-network-for-a-1-dimensional-function-from-scratch-in-keras/
