# %% [markdown]
# ## Version Description
# In this version, we deploy a Hybrid PINN to predict only one correction factor for the MTR ( MTR-600 ) by the neural network. We implement line search ([Secant Method](https://nickcdryan.com/2017/09/13/root-finding-algorithms-in-python-line-search-bisection-secant-newton-raphson-boydens-inverse-quadratic-interpolation-brents/)) to adaptively find the learning rate.
# * SingleHoV is looped till it attains convergence, so `batch size = 1` is used.
# * Two extra features `x1` and `x2` are engineered and the input features used are `['x1','x2']` only. `TZ6_flow` is used as a seperate input not part of `X` (set of all features in train dataset).
# * **Linear** (Identity) Activation function is used in the **hidden and output layers**.

# %%
from IPython.core.display import display, HTML,display_html
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# import required libraries
import random
import pandas as pd
import numpy as np

from functools import reduce
import sys

#Set some numpy print options for displaying numpy arrays to fit maximum width of cell
np.set_printoptions(precision=3, edgeitems=30, linewidth=1000,formatter=dict(float=lambda x: "%.3g" % x))

# Disable Warnings for chained assignments Eg:Setting with Copy Warning
pd.options.mode.chained_assignment = None

from bokeh.models import ColumnDataSource
from bokeh.plotting import figure, show, output_file,output_notebook
output_notebook() # Set to output the plot in the notebook
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="07292744-7303-4ba2-94af-39cf29b491e7">Loading BokehJS ...</span>
#     </div>

# %%
np.random.seed(42)

# import LTR and corresponding Restrictor dataframe
Restrictor_data = pd.read_csv('D:/OneDrive/Documents/Airbus/GitHub/ML_A350_Restrictors/TZ6/data/Zone6_RestrictorData_LTR.csv')
LTR_data = pd.read_csv('D:/OneDrive/Documents/Airbus/GitHub/ML_A350_Restrictors/TZ6/data/Zone6_LTRData.csv')
obs_HOVs = pd.read_csv('../data/LTR_dataset.csv', usecols = ['HoV'])[['HoV']]
LTR_data[['AMBP','MIXP']] *= 100 # Convert hPa to Pa
zero_MIXT_hoV_idx = LTR_data.index[LTR_data['MIXT'] == 20].tolist() # Points where originally, MIXT == 0 and substituted with 20° C
LTR_data[['MIXT','AMBT']] += 273.15 # Convert Celcius to Kelvin
LTR_data[['TZ6_Flow']] /= 1000 # Convert l/s to cu.m/s
print('Total LTR points:',len(LTR_data))

## Calculate Density = (0.5* Pmix + Pamb) / (R * Tmix) where R = 287 is the Gas constant in Ideal Gas Law
idx = LTR_data.columns.get_loc("AMBT")
LTR_data.insert(loc=(idx+1), column='Density(kg/m³)', value=np.round((0.5 * LTR_data['MIXP'] + LTR_data['AMBP'] ) / (LTR_data['MIXT']*287),4))
target_df = reduce(lambda left,right: pd.merge(left,right,left_on='HoV',right_on='HoV'), [LTR_data,Restrictor_data])
target_df['HoV'] = obs_HOVs.values
target_df.head()
# Out:
# Total LTR points: 34
#   HoV  CAOLH_C66-C68  CAOLH_C68-C70  CAOLH_C70-C72  CAOLH_C72-C74  \
# 0  A1      36.071000      38.802000      36.796000      36.794000
# 1  A2      36.061000      38.697000      37.156000      36.738000
# 2  A3      37.504234      40.911735      38.412733      37.859887
# 3  A4      36.383413      39.101836      38.110486      37.597728
# 4  A5      36.897000      39.925000      38.704000      38.175000
#
#    CAOLH_C74-C76  CAOLH_C76-C78  CAORH_C66-C68  CAORH_C68-C70  CAORH_C70-C72  \
# 0      39.100000      38.318000      37.055000      39.596000      38.333000
# 1      38.957000      38.326000      36.501000      40.797000      39.284000
# 2      36.585486      38.504564      36.161971      37.068225      37.893405
# 3      36.190671      37.706898      36.668551      37.759174      38.497755
# 4      40.591000      39.913000      37.641000      38.309000      38.600000
#
#      ...     R632_HS1  R633_HS1  R634_HS1  R635_HS1  R636_HS1  R637_HS1  \
# 0    ...           41        41        41        41        41        41
# 1    ...           41        41        41        41        41        41
# 2    ...           41        41        41        41        41        41
# 3    ...           41        41        41        41        41        41
# 4    ...           41        41        41        41        41        41
#
#    R638_HS1  R639_HS1  R640_HS1  R641_HS1
# 0        41        41        41        41
# 1        41        41        41        41
# 2        41        41        41        41
# 3        41        41        41        41
# 4        41        41        41        41
#
# [5 rows x 58 columns]

# %%
V_max_org = target_df['TZ6_Flow'].max()
print('Maximum TZ6 Flow:',V_max_org)
# Out:
# Maximum TZ6 Flow: 0.7640123719999998

# %%
MIXP = [1800, 2600, 3400]
# Define Restrictor Labels
MTR = 'R600_HD'
CLRS = ['R610_HS1','R611_HS1','R612_HS1','R613_HS1']
CAORS = ['R620_HS1','R620_HS2','R620_HS3','R621_HS1','R621_HS2','R621_HS3']
MHRS = CLRS + CAORS
LAORS = ['R630_HS1','R631_HS1','R632_HS1','R633_HS1','R634_HS1','R635_HS1','R636_HS1','R637_HS1','R638_HS1','R639_HS1','R640_HS1','R641_HS1']

# %%
# Duct Areas
MTR_DuctArea = 0.03464 # in sq.m
MHR_Duct_Areas = {'R610_HS1':0.01767,'R611_HS1':0.01767,'R612_HS1':0.02461,'R613_HS1':0.02461,
                 'R620_HS1':0.01090,'R620_HS2':0.00470,'R620_HS3':0.01085,'R621_HS1':0.01085,'R621_HS2':0.00470,'R621_HS3':0.01090}

## Define Initial Correction factor values from CFD
# Correction Factor for Duct Part `TZ6_zmix:
TZ6_zmix_cf = 1 # Start with initial c_f =1 

#3D Correction Factor for MTR
MTR_cf = 1.1664876228437


#3D Correction Factors for MultiHole Restrictors
MHR_cf = {'R610_HS1':0.740773983383846,'R611_HS1':0.740205245723713,'R612_HS1':0.83879652680329,'R613_HS1':0.81775586281569,
          'R620_HS1':0.757121843184036,'R620_HS2':0.773919779037984,'R620_HS3':0.789028593182055,
          'R621_HS1':0.714811824527744,'R621_HS2':0.866271631648556,'R621_HS3':0.822447592395462}

# %% [markdown]
# ### Calculate Loss-Coefficient $\zeta$
# **For Single Hole Restrictor:**<br>
#
#     f0_f1 = A_Circular(Hole_Diameter) / Area_Overall
#     l_cross = Thickness / Hole_Diameter
#     Zeta_dash = 0.13 + 0.34 * 10 ^ -(3.4 * l_cross + 88.4 * l_cross ^ 2.3)
#     Zeta_Single_Hole_Thick_Chamfered = ((1 - f0_f1 + (Zeta_dash ^ 0.5) * (1 - f0_f1) ^ 0.375) ^ 2) * f0_f1 ^ -2

# %%
def SHR_Zeta_3D(n_holes,hole_dia,MTR_DuctArea,cf):
    '''
    Computes the Zeta with 3D Correction Factor (cf) for Single Hole Retrictors
    '''
    MTR_New_Area = n_holes * (np.pi/4) * (hole_dia / 1000)**2 # Divide dia by 1000 to convert mm to m
    f0_f1 = MTR_New_Area/MTR_DuctArea
    l_cross = 1/hole_dia
    zeta_dash = 0.13 + 0.34 * 10**(-(3.4 * l_cross + 88.4 * l_cross**2.3))
    zeta_SHR_1D = ((1 - f0_f1 + (zeta_dash**0.5) * (1 - f0_f1)**0.375)**2) * f0_f1**(-2) # 1D Zeta
    zeta_SHR_3D = zeta_SHR_1D * cf # Zeta with 3D Correction Factor    
    return MTR_New_Area,zeta_SHR_3D

# %%
target_df[MTR+'_Area'],target_df[MTR+'_Zeta3D'] = zip(*[SHR_Zeta_3D(1,dia,MTR_DuctArea,MTR_cf) for dia in target_df[MTR]])
target_df[[MTR,'R600_HD_Area','R600_HD_Zeta3D']].head()
# Out:
#    R600_HD  R600_HD_Area  R600_HD_Zeta3D
# 0      148      0.017203        4.949375
# 1      149      0.017437        4.730821
# 2      152      0.018146        4.127180
# 3      154      0.018627        3.764504
# 4      148      0.017203        4.949375

# %% [markdown]
# **For Multi Hole Restrictors:**<br>
#
#     Area_Free = Number_of_Holes * A_Circular(Hole_Diameter)
#     f0_f1 = Area_Free / Area_Overall
#     l_cross = Thickness / Hole_Diameter
#     phi = 0.25 + (0.535 * l_cross ^ 8) / (0.05 + l_cross ^ 7)
#     tau = (2.4 - l_cross) * 10 ^ (-phi)
#     Zeta_Multi_Hole = (0.5 * (1 - f0_f1) ^ 0.75 + tau * (1 - f0_f1) ^ 1.375 + (1 - f0_f1) ^ 2 + 0.02 * l_cross) / f0_f1 ^ 2

# %%
def MHR_Zeta_3D(nr_holes,hole_dia,MHR_DuctArea,cf):
    '''
    Computes the Zeta with 3D Correction Factor (cf) for Multi Hole Restrictors
    '''
    MHR_New_Area = nr_holes * (np.pi/4) * (hole_dia / 1000)**2 # Divide dia by 1000 to convert mm to m
    f0_f1 = MHR_New_Area/MHR_DuctArea
    l_cross = (0.00144*1000)/hole_dia
    phi = 0.25 + (0.535 * l_cross**8) / (0.05 + l_cross**7)
    tau = (2.4 - l_cross) * 10**(-phi)
    zeta_MHR_1D = (0.5 * (1 - f0_f1)**0.75 + tau * (1 - f0_f1)**1.375 + (1 - f0_f1)**2 + 0.02 * l_cross) / f0_f1**2 # 1D Zeta     
    zeta_MHR_3D = zeta_MHR_1D * cf # Zeta with 3D Correction Factor    
    return MHR_New_Area,zeta_MHR_3D

# %%
# Calculate Zeta for Multi-Hole Restrictors
for clr in CLRS:
    if (clr == 'R610_HS1') | (clr == 'R611_HS1'):
        hole_dia = 8
    else:
        hole_dia = 10
    MHR_nr_holes = target_df[clr].values
    target_df[clr+'_Area'], target_df[clr+'_Zeta3D'] = zip(*[MHR_Zeta_3D(ele,hole_dia,MHR_Duct_Areas[clr],MHR_cf[clr]) for ele in MHR_nr_holes])
    
for caor in CAORS:
    CAOR_nr_holes = target_df[caor].values
    target_df[caor+'_Area'],target_df[caor+'_Zeta3D'] = zip(*[MHR_Zeta_3D(ele,8,MHR_Duct_Areas[caor],MHR_cf[caor]) for ele in CAOR_nr_holes])

# %% [markdown]
# **Store Loss Coefficient ($\zeta$) Values and Names for all Restrictors:**

# %%
# Gather col_names and their corresponding column indices
zeta_col_names = [col for col in target_df.columns if 'Zeta3D' in col]
zeta_col_names_idx = [target_df.columns.get_loc(col) for col in zeta_col_names if col in target_df]
area_col_names = [col for col in target_df.columns if 'Area' in col]
area_col_names_idx = [target_df.columns.get_loc(col) for col in area_col_names if col in target_df]
pt_var_idx = [target_df.columns.get_loc(col) for col in ['MIXP','AMBP','AMBT'] if col in target_df]
req_flow_rates_idx = [target_df.columns.get_loc(col) for col in ['TZ6_Flow'] if col in target_df]
# print(zeta_col_names_idx)
print(zeta_col_names)
# Out:
# ['R600_HD_Zeta3D', 'R610_HS1_Zeta3D', 'R611_HS1_Zeta3D', 'R612_HS1_Zeta3D', 'R613_HS1_Zeta3D', 'R620_HS1_Zeta3D', 'R620_HS2_Zeta3D', 'R620_HS3_Zeta3D', 'R621_HS1_Zeta3D', 'R621_HS2_Zeta3D', 'R621_HS3_Zeta3D']

# %%
LTR_zeta_df_col_idx = sorted([0] + req_flow_rates_idx + pt_var_idx + zeta_col_names_idx)
target_df.iloc[:,LTR_zeta_df_col_idx].to_csv('data_output/LTR_Zeta_df.csv', index=False)

# %%
LTR_zeta_df = target_df[['HoV','MIXP','AMBP','AMBT','TZ6_Flow']+zeta_col_names]
final_df = target_df[['HoV','MIXP','Density(kg/m³)','R600_HD','R600_HD_Area','R600_HD_Zeta3D','TZ6_Flow']]
final_df.reset_index(drop=True,inplace = True)
final_df.head()
# Out:
#   HoV       MIXP  Density(kg/m³)  R600_HD  R600_HD_Area  R600_HD_Zeta3D  \
# 0  A1  2600.0000          1.2207      148      0.017203        4.949375
# 1  A2  2600.0000          1.2228      149      0.017437        4.730821
# 2  A3  2606.1928          1.2090      152      0.018146        4.127180
# 3  A4  2599.8998          1.2368      154      0.018627        3.764504
# 4  A5  2600.0000          1.2380      148      0.017203        4.949375
#
#    TZ6_Flow
# 0  0.738083
# 1  0.737775
# 2  0.740980
# 3  0.732112
# 4  0.741828

# %% [markdown]
# ### Feature Engineering

# %%
final_df['xf1'] = ( final_df['MIXP']/final_df['R600_HD_Zeta3D'] ) * (2/final_df['Density(kg/m³)']) * (MTR_DuctArea/ final_df['TZ6_Flow'])**2
final_df['xf2'] = ( 1 /final_df['R600_HD_Zeta3D'] )
final_df.drop(columns = ['MIXP','Density(kg/m³)','R600_HD','R600_HD_Zeta3D','R600_HD_Area','TZ6_Flow'], inplace = True)

# %% [markdown]
# ### Train Data Preperation

# %%
input_features = ['xf1','xf2']
## Using un-scaled values
train_data = final_df[input_features]
print("Number of training samples:", len(train_data))
train_data
# Out:
# Number of training samples: 34
#          xf1       xf2
# 0   1.895786  0.202046
# 1   1.981615  0.211380
# 2   2.282967  0.242296
# 3   2.500234  0.265639
# 4   1.850468  0.202046
# 5   1.869475  0.202046
# 6   1.899464  0.202046
# 7   2.398352  0.253672
# 8   2.319517  0.242296
# 9   2.044012  0.221181
# 10  2.354210  0.242296
# 11  2.416669  0.265639
# 12  2.072221  0.231476
# 13  1.891574  0.202046
# 14  1.910352  0.202046
# 15  2.326366  0.202046
# 16  1.791030  0.184676
# 17  1.815110  0.184676
# 18  1.852599  0.202046
# 19  1.891568  0.202046
# 20  2.387054  0.242296
# 21  2.081111  0.202046
# 22  2.397488  0.265639
# 23  2.421323  0.265639
# 24  2.432481  0.265639
# 25  1.964356  0.202046
# 26  1.873024  0.202046
# 27  2.608462  0.278234
# 28  1.884554  0.202046
# 29  1.997970  0.221181
# 30  2.092031  0.221181
# 31  3.126511  0.352142
# 32  2.003086  0.202046
# 33  1.885288  0.202046

# %%
# Store indices of train, test and validation data
train_data_idx = train_data.index.values.tolist()
train_R600HD_series = target_df['R600_HD'].iloc[train_data_idx]
X_train = train_data.values

# %% [markdown]
# ### Predict $c_f$ with Physics Informed Neural Network

# %%
# Define custom MSE function
MSE = lambda y_hat,y_true: np.mean((np.asarray(y_hat)-np.asarray(y_true))**2)

# %% [markdown]
# **Train the Neural Network**

# %%
### Set the hyperparameters here ###
iterations = 100
lr0, lr1 = 0, 1
hidden_nodes = 1 ### Important Parameter
output_nodes = 1
batch_sample_size = 2
MTR_epsi = np.float64(MTR_cf * 0.01)

# %%
from Hybrid_PINN_v2_1 import PINN

# %%
# %%time
N_i = X_train.shape[1] # no. of features
network = PINN(N_i, hidden_nodes, output_nodes, MTR_epsi)

MSE_flowloss_hist = []
err_loss_hist = []
losses_hist = {'HoV':[],'MSE_flowloss':[],'Error_loss':[]}
c_f_hist = {'HoV':[],'c_f_hat':[],'FlowRate_Diff_(LTR-FDDN)':[],'f1':[],'f2':[]}

# Set Initial Weights and Gradient Updates
w_ih, w_ho, dw_i_h, dw_h_o = None, None, None, None

for idx in train_data_idx:    
     # Go through one record at a time from the training data set        
    print('Old_Zeta:',target_df[MTR+'_Zeta3D'].loc[idx])    
    X_train = train_data[input_features].loc[[idx]].values
    dia_train = np.atleast_1d(train_R600HD_series.loc[idx])
    HoV = target_df[['HoV']].loc[idx].values.tolist()
    for ii in range(iterations):                
        ## Initialize with default weights    
        w0_i_h, w0_h_o = network.calc_new_weights(lr0, delta_weights_i_h = dw_i_h, delta_weights_h_o = dw_h_o, w_ih = w_ih, w_ho = w_ho)
        print('\nTRAINING ITERATION {} - w_0:'.format(ii), list(w0_i_h) + list(w0_h_o))                                                                        
        V_LTR_true, V_hat_FDDN, V_hat_epsi_FDDN, cf_array, hidden_outputs, _ = network.train(X_train, dia_train,[idx], w0_i_h, w0_h_o, MTR_DuctArea, target_df, zeta_col_names)
        _, dE_dw_ih0, dE_dw_ho0 = network.gradient_update(V_LTR_true, V_hat_FDDN , V_hat_epsi_FDDN, cf_array, X_train, hidden_outputs, dw_i_h, dw_h_o, w0_h_o, V_max_org)    
        f0 = network.cust_f_alpha(dE_dw_ih0, dE_dw_ho0, dE_dw_ih0, dE_dw_ho0 )        
        print('f0:', f0)
        w1_i_h, w1_h_o = network.calc_new_weights(lr1, dE_dw_ih0, dE_dw_ho0, w_ih = w0_i_h, w_ho = w0_h_o)
        V_LTR_true, V_hat_FDDN, V_hat_epsi_FDDN, cf_array, hidden_outputs, _ = network.train(X_train, dia_train, [idx], w1_i_h, w1_h_o, MTR_DuctArea, target_df, zeta_col_names)
        _,dE_dw_ih1, dE_dw_ho1 = network.gradient_update(V_LTR_true, V_hat_FDDN, V_hat_epsi_FDDN, cf_array, X_train, hidden_outputs, dw_i_h, dw_h_o, w1_h_o, V_max_org )
        f1 = network.cust_f_alpha(dE_dw_ih0, dE_dw_ho0, dE_dw_ih1, dE_dw_ho1)        
        print('f1:', f1)
        lr2 = network.calc_lr2( f0, f1, lr0, lr1)    
        w2_i_h, w2_h_o = network.calc_new_weights(lr2, dE_dw_ih0, dE_dw_ho0, w_ih = w0_i_h, w_ho = w0_h_o)    
        V_LTR_true, V_hat_FDDN, V_hat_epsi_FDDN, cf_array, hidden_outputs, break_flag_arr = network.train(X_train, dia_train, [idx], w2_i_h, w2_h_o, MTR_DuctArea, target_df, zeta_col_names)
        error, dE_dw_ih2, dE_dw_ho2 = network.gradient_update(V_LTR_true, V_hat_FDDN, V_hat_epsi_FDDN, cf_array, X_train, hidden_outputs, dw_i_h, dw_h_o, w2_h_o, V_max_org)
        f2 = network.cust_f_alpha(dE_dw_ih0, dE_dw_ho0, dE_dw_ih2, dE_dw_ho2)        
        print('f2:', f2)
        w_ih, w_ho = w2_i_h, w2_h_o
        dw_i_h, dw_h_o = dE_dw_ih2, dE_dw_ho2

        # Print out the training progress        
        MSE_flowloss = MSE(V_hat_FDDN, V_LTR_true) # MSE between FDDN predicted flow rate and true flow rate on UN-scaled original values in cu.m/s
        sys.stdout.write("\rProgress: {:2.1f}".format(100 * ii/float(iterations))+ "% ... MSE FLowloss: " + str(round(MSE_flowloss,4))[:5] + " ... Error Function loss: " + str(round(error,4))) # For truncated version of the error
        print('... Training Iteration:',ii)    
        sys.stdout.flush()
        MSE_flowloss_hist.append(MSE_flowloss)
        err_loss_hist.append(error) # For truncated version of the error            
        if (1 in break_flag_arr) or (ii == (iterations - 1)): # To remove converged HoV
            print('EARLY STOPPING ACTIVATED - Terminating Neural Network Training')
            print('MSE FlowLoss History for {}:'.format(HoV[0]),MSE_flowloss_hist)
            print('Error Loss History for {}:'.format(HoV[0]),err_loss_hist)
            losses_hist['HoV'].append(HoV[0])            
            losses_hist['MSE_flowloss'].append(MSE_flowloss_hist)
            losses_hist['Error_loss'].append(err_loss_hist)
            c_f_hist['HoV'].append(HoV[0])
            c_f_hist['FlowRate_Diff_(LTR-FDDN)'].append( V_LTR_true[0][0] - V_hat_FDDN[0][0])
            c_f_hist['c_f_hat'].append(cf_array[0])
            c_f_hist['f1'].append(f1)
            c_f_hist['f2'].append(f2)
            err_loss_hist = []
            MSE_flowloss_hist = []
            break
# Out:
# Initial Weights_i_h: [array([1]), array([0.1])]
# Initial Weights_h_o: [array([1])]
# Old_Zeta: 4.949375283472444
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0]), array([0]), array([0])]
# CALC NEW WEIGHTS - new_weights_i_h: [array([1]), array([0.1])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([1]), array([0.1]), array([1])]
#
# NN output (C_f): 1.9159908486948936
# New_Zeta: 8.129497102397062
# FDDN Solver Output: [[64.2 30.7 96.9 63.4 33.5 103 10.1 21.9 21.9 21.9 21.4 21.2 9.9 21.6 21.7 21.4 21.1 21.1]]
# New_Zeta_epsi: 8.178990855231786
# FDDN Solver Output: [[64.1 30.6 96.7 63.2 33.4 103 10.1 21.9 21.8 21.9 21.4 21.1 9.89 21.5 21.7 21.3 21.1 21.1]]
# Row ID: 0
# HoV: ['A1']
# Flow Rate Difference (LTR - FDDN): 0.11101802247714976 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.0356]), array([0.0038])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 0.0012835642461738986
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.0356]), array([0.0038]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([1]), array([0.1])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.964]), array([0.0962])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.8476861243801213
# New_Zeta: 7.839682013366125
# FDDN Solver Output: [[64.9 31 97.9 64 33.8 104 10.3 22.1 22.1 22.1 21.7 21.4 10 21.8 22 21.6 21.3 21.4]]
# New_Zeta_epsi: 7.88917576620085
# FDDN Solver Output: [[64.8 30.9 97.7 63.9 33.8 104 10.2 22.1 22.1 22.1 21.6 21.3 10 21.8 21.9 21.6 21.3 21.3]]
# Row ID: 0
# HoV: ['A1']
# Flow Rate Difference (LTR - FDDN): 0.10423845803342346 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.0342]), array([0.00364])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 0.0012313137604576846
# Learning Rate 2: 24.565594531412984
#
# CALC NEW WEIGHTS - Learning Rate Used: 10
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.0356]), array([0.0038]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([1]), array([0.1])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.644]), array([0.062])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.2329436055471703
# New_Zeta: 5.231346212087689
# FDDN Solver Output: [[72.4 34.6 109 71.4 37.7 116 11.4 24.7 24.6 24.7 24.2 23.8 11.2 24.3 24.5 24.1 23.8 23.8]]
# New_Zeta_epsi: 5.280839964922413
# FDDN Solver Output: [[72.3 34.5 109 71.3 37.6 116 11.4 24.6 24.6 24.6 24.1 23.8 11.1 24.2 24.4 24 23.7 23.8]]
# Row ID: 0
# HoV: ['A1']
# Flow Rate Difference (LTR - FDDN): 0.03124797180000105 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.0142]), array([0.00151])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: 0.0005105556881488386
# Progress: 0.0% ... MSE FLowloss: 0.001 ... Error Function loss: 0.0008... Training Iteration: 0
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.0142]), array([0.00151]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.644]), array([0.062])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.644]), array([0.062])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 1 - w_0: [array([0.644]), array([0.062]), array([1])]
#
# NN output (C_f): 1.2329436055471703
# New_Zeta: 5.231346212087689
# FDDN Solver Output: [[72.4 34.6 109 71.4 37.7 116 11.4 24.7 24.6 24.7 24.2 23.8 11.2 24.3 24.5 24.1 23.8 23.8]]
# New_Zeta_epsi: 5.280839964922413
# FDDN Solver Output: [[72.3 34.5 109 71.3 37.6 116 11.4 24.6 24.6 24.6 24.1 23.8 11.1 24.2 24.4 24 23.7 23.8]]
# Row ID: 0
# HoV: ['A1']
# Flow Rate Difference (LTR - FDDN): 0.03124797180000105 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.0142]), array([0.00151])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 0.00020308068838637523
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.0142]), array([0.00151]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.644]), array([0.062])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.63]), array([0.0605])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.2057744430916897
# New_Zeta: 5.116068194133253
# FDDN Solver Output: [[72.8 34.7 110 71.8 37.9 117 11.5 24.8 24.8 24.8 24.3 24 11.2 24.4 24.6 24.2 23.9 23.9]]
# New_Zeta_epsi: 5.165561946967978
# FDDN Solver Output: [[72.7 34.7 110 71.7 37.9 117 11.5 24.8 24.7 24.8 24.2 23.9 11.2 24.4 24.6 24.2 23.9 23.9]]
# Row ID: 0
# HoV: ['A1']
# Flow Rate Difference (LTR - FDDN): 0.027386105599004673 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.0128]), array([0.00136])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 0.00018348489844572876
# Learning Rate 2: 10.363485677356447
#
# CALC NEW WEIGHTS - Learning Rate Used: 10
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.0142]), array([0.00151]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.644]), array([0.062])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.502]), array([0.0469])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 0.9612519809923631
# New_Zeta: 4.078566032543326
# FDDN Solver Output: [[76.7 36.6 116 75.6 40 123 12.1 26.1 26.1 26.1 25.6 25.2 11.8 25.7 25.9 25.5 25.2 25.2]]
# New_Zeta_epsi: 4.128059785378051
# FDDN Solver Output: [[76.5 36.5 115 75.4 39.8 123 12.1 26.1 26 26.1 25.5 25.2 11.8 25.7 25.9 25.4 25.1 25.1]]
# Row ID: 0
# HoV: ['A1']
# Flow Rate Difference (LTR - FDDN): -0.01016889512143282 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00544]), array([-0.000579])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: -7.792140858928559e-05
# Progress: 1.0% ... MSE FLowloss: 0.000 ... Error Function loss: 0.0001... Training Iteration: 1
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00544]), array([-0.000579]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.502]), array([0.0469])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.502]), array([0.0469])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 2 - w_0: [array([0.502]), array([0.0469]), array([1])]
#
# NN output (C_f): 0.9612519809923631
# New_Zeta: 4.078566032543326
# FDDN Solver Output: [[76.7 36.6 116 75.6 40 123 12.1 26.1 26.1 26.1 25.6 25.2 11.8 25.7 25.9 25.5 25.2 25.2]]
# New_Zeta_epsi: 4.128059785378051
# FDDN Solver Output: [[76.5 36.5 115 75.4 39.8 123 12.1 26.1 26 26.1 25.5 25.2 11.8 25.7 25.9 25.4 25.1 25.1]]
# Row ID: 0
# HoV: ['A1']
# Flow Rate Difference (LTR - FDDN): -0.01016889512143282 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00544]), array([-0.000579])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 2.9898194480149037e-05
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00544]), array([-0.000579]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.502]), array([0.0469])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.507]), array([0.0475])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 0.9716767014596008
# New_Zeta: 4.1227978381855275
# FDDN Solver Output: [[76.5 36.5 115 75.4 39.9 123 12.1 26.1 26 26.1 25.5 25.2 11.8 25.7 25.9 25.4 25.1 25.1]]
# New_Zeta_epsi: 4.172291591020252
# FDDN Solver Output: [[76.3 36.4 115 75.2 39.8 123 12 26 25.9 26 25.4 25.1 11.8 25.6 25.8 25.4 25.1 25.1]]
# Row ID: 0
# HoV: ['A1']
# Flow Rate Difference (LTR - FDDN): -0.008449767337550096 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00454]), array([-0.000484])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 2.4955161297186525e-05
# Learning Rate 2: 6.048552249902181
#
# CALC NEW WEIGHTS - Learning Rate Used: 6.048552249902181
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00544]), array([-0.000579]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.502]), array([0.0469])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.535]), array([0.0504])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.0243064474290757
# New_Zeta: 4.3461044200777
# FDDN Solver Output: [[75.6 36.1 114 74.6 39.4 122 11.9 25.8 25.7 25.8 25.2 24.9 11.7 25.4 25.6 25.2 24.8 24.9]]
# New_Zeta_epsi: 4.3955981729124245
# FDDN Solver Output: [[75.4 36 114 74.4 39.3 121 11.9 25.7 25.7 25.7 25.2 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# Row ID: 0
# HoV: ['A1']
# Flow Rate Difference (LTR - FDDN): 7.179836316406618e-05 cu.m/s
# % Diff between flowrates 0.009728154623796939 %
# GRADIENT_UPDATE - dw_ih: [array([3.69e-05]), array([3.93e-06])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: -2.028589700587739e-07
# Progress: 2.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 2
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for A1: [0.0009764357416136609, 0.00010340642799070019, 5.155004953039136e-09]
# Error Loss History for A1: [0.0008363978150725182, 8.857614152155417e-05, 4.415687275318825e-09]
# Old_Zeta: 4.7308206417914045
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([3.69e-05]), array([3.93e-06]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.535]), array([0.0504])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.535]), array([0.0504])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.535]), array([0.0504]), array([1])]
#
# NN output (C_f): 1.0706898354609684
# New_Zeta: 4.342302031638182
# FDDN Solver Output: [[75.5 36 114 74.4 39.3 121 11.9 25.7 25.7 25.7 25.2 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# New_Zeta_epsi: 4.389610238056096
# FDDN Solver Output: [[75.3 35.9 113 74.2 39.2 121 11.9 25.6 25.6 25.7 25.1 24.8 11.6 25.2 25.5 25 24.7 24.7]]
# Row ID: 1
# HoV: ['A2']
# Flow Rate Difference (LTR - FDDN): 0.0013882299222692795 cu.m/s
# % Diff between flowrates 0.1883415986559033 %
# GRADIENT_UPDATE - dw_ih: [array([0.000735]), array([7.84e-05])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 5.469586477259245e-07
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.000735]), array([7.84e-05]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.535]), array([0.0504])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.534]), array([0.0504])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.069215984897879
# New_Zeta: 4.336324666314939
# FDDN Solver Output: [[75.5 36 114 74.4 39.3 121 11.9 25.7 25.7 25.7 25.2 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# New_Zeta_epsi: 4.383632872732853
# FDDN Solver Output: [[75.3 35.9 114 74.3 39.2 121 11.9 25.6 25.6 25.7 25.1 24.8 11.6 25.3 25.5 25.1 24.7 24.7]]
# Row ID: 1
# HoV: ['A2']
# Flow Rate Difference (LTR - FDDN): 0.0011964533397499366 cu.m/s
# % Diff between flowrates 0.16230209402082407 %
# GRADIENT_UPDATE - dw_ih: [array([0.000616]), array([6.57e-05])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 4.583339822766361e-07
# Learning Rate 2: 6.171630041739311
#
# CALC NEW WEIGHTS - Learning Rate Used: 6.171630041739311
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.000735]), array([7.84e-05]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.535]), array([0.0504])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.53]), array([0.05])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.061593775048772
# New_Zeta: 4.305411944238801
# FDDN Solver Output: [[75.6 36.1 114 74.6 39.4 121 11.9 25.8 25.7 25.8 25.2 24.9 11.6 25.4 25.6 25.2 24.8 24.8]]
# New_Zeta_epsi: 4.352720150656715
# FDDN Solver Output: [[75.4 36 114 74.4 39.3 121 11.9 25.7 25.6 25.7 25.1 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# Row ID: 1
# HoV: ['A2']
# Flow Rate Difference (LTR - FDDN): 4.453240282686899e-05 cu.m/s
# % Diff between flowrates 0.006036223355971562 %
# GRADIENT_UPDATE - dw_ih: [array([2.27e-05]), array([2.42e-06])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: 1.689663289476468e-08
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for A2: [1.983134901534529e-09]
# Error Loss History for A2: [1.6987187460962641e-09]
# Old_Zeta: 4.127180457922134
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([2.27e-05]), array([2.42e-06]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.53]), array([0.05])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.53]), array([0.05])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.53]), array([0.05]), array([1])]
#
# NN output (C_f): 1.2229732053550058
# New_Zeta: 4.3270335791465895
# FDDN Solver Output: [[75.5 36 114 72.6 38.4 118 11.9 25.7 25.7 25.7 25.2 24.9 11.6 25.3 25.5 25.1 24.8 24.8]]
# New_Zeta_epsi: 4.3683053837258115
# FDDN Solver Output: [[75.4 36 114 72.5 38.3 118 11.9 25.7 25.6 25.7 25.1 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# Row ID: 2
# HoV: ['A3']
# Flow Rate Difference (LTR - FDDN): 0.009748881548349075 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.00503]), array([0.000533])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 2.5538727828786838e-05
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.00503]), array([0.000533]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.53]), array([0.05])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.525]), array([0.0494])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.2113712386275892
# New_Zeta: 4.285984356323183
# FDDN Solver Output: [[75.7 36.1 114 72.8 38.4 119 11.9 25.8 25.7 25.8 25.2 24.9 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi: 4.327256160902405
# FDDN Solver Output: [[75.5 36 114 72.6 38.4 118 11.9 25.7 25.7 25.7 25.2 24.9 11.6 25.3 25.5 25.1 24.8 24.8]]
# Row ID: 2
# HoV: ['A3']
# Flow Rate Difference (LTR - FDDN): 0.008219841931618066 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.00421]), array([0.000447])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 2.141495533854651e-05
# Learning Rate 2: 6.193049662470219
#
# CALC NEW WEIGHTS - Learning Rate Used: 6.193049662470219
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.00503]), array([0.000533]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.53]), array([0.05])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.499]), array([0.0466])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.1511216492297864
# New_Zeta: 4.072813703595424
# FDDN Solver Output: [[76.5 36.5 115 73.6 38.9 120 12.1 26.1 26 26.1 25.5 25.2 11.8 25.7 25.9 25.5 25.1 25.2]]
# New_Zeta_epsi: 4.114085508174646
# FDDN Solver Output: [[76.4 36.4 115 73.4 38.8 120 12.1 26 26 26 25.5 25.1 11.8 25.6 25.8 25.4 25.1 25.1]]
# Row ID: 2
# HoV: ['A3']
# Flow Rate Difference (LTR - FDDN): 0.0001627391051567395 cu.m/s
# % Diff between flowrates 0.021965100720773192 %
# GRADIENT_UPDATE - dw_ih: [array([8.57e-05]), array([9.09e-06])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: 4.3531690588896e-07
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for A3: [2.6484016347216317e-08]
# Error Loss History for A3: [2.2685746192114478e-08]
# Old_Zeta: 3.7645035449506787
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([8.57e-05]), array([9.09e-06]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.499]), array([0.0466])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.499]), array([0.0466])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.499]), array([0.0466]), array([1])]
#
# NN output (C_f): 1.2606853796021422
# New_Zeta: 4.068499731707537
# FDDN Solver Output: [[75.5 36 114 74.5 39.3 121 11.9 25.7 25.7 25.7 25.2 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# New_Zeta_epsi: 4.106144767157044
# FDDN Solver Output: [[75.4 35.9 114 74.3 39.3 121 11.9 25.7 25.6 25.7 25.1 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# Row ID: 3
# HoV: ['A4']
# Flow Rate Difference (LTR - FDDN): -0.004585961451015197 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00242]), array([-0.000257])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 5.92695189660272e-06
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00242]), array([-0.000257]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.499]), array([0.0466])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.502]), array([0.0469])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.26680654053849
# New_Zeta: 4.088254019359488
# FDDN Solver Output: [[75.4 36 114 74.4 39.3 121 11.9 25.7 25.6 25.7 25.1 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# New_Zeta_epsi: 4.125899054808995
# FDDN Solver Output: [[75.3 35.9 113 74.2 39.2 121 11.9 25.6 25.6 25.6 25.1 24.8 11.6 25.2 25.5 25 24.7 24.7]]
# Row ID: 3
# HoV: ['A4']
# Flow Rate Difference (LTR - FDDN): -0.003838785762290242 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00205]), array([-0.000218])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 5.018004735224629e-06
# Learning Rate 2: 6.520678152090416
#
# CALC NEW WEIGHTS - Learning Rate Used: 6.520678152090416
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00242]), array([-0.000257]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.499]), array([0.0466])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.515]), array([0.0483])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.3005994999852148
# New_Zeta: 4.1973110836097245
# FDDN Solver Output: [[75 35.8 113 74 39.1 121 11.8 25.5 25.5 25.6 25 24.7 11.6 25.2 25.4 24.9 24.6 24.6]]
# New_Zeta_epsi: 4.234956119059231
# FDDN Solver Output: [[74.8 35.7 113 73.8 39 120 11.8 25.5 25.4 25.5 25 24.6 11.5 25.1 25.3 24.9 24.6 24.6]]
# Row ID: 3
# HoV: ['A4']
# Flow Rate Difference (LTR - FDDN): 0.00031209364167228415 cu.m/s
# % Diff between flowrates 0.04263833360793449 %
# GRADIENT_UPDATE - dw_ih: [array([0.000164]), array([1.74e-05])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: -4.011775805795794e-07
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for A4: [9.74024411722681e-08]
# Error Loss History for A4: [8.343323119715137e-08]
# Old_Zeta: 4.949375283472444
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.000164]), array([1.74e-05]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.515]), array([0.0483])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.515]), array([0.0483])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.515]), array([0.0483]), array([1])]
#
# NN output (C_f): 0.9628601291628652
# New_Zeta: 4.085389361528027
# FDDN Solver Output: [[76.7 36.6 116 76 40.1 124 12.1 26.1 26 26.1 25.5 25.2 11.8 25.6 25.8 25.4 25.1 25.1]]
# New_Zeta_epsi: 4.134883114362752
# FDDN Solver Output: [[76.5 36.5 115 75.8 40 123 12 26 25.9 26 25.4 25.1 11.7 25.5 25.8 25.3 25 25]]
# Row ID: 4
# HoV: ['A5']
# Flow Rate Difference (LTR - FDDN): -0.006755269844909928 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00366]), array([-0.0004])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 1.3560642204066526e-05
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00366]), array([-0.0004]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.515]), array([0.0483])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.519]), array([0.0487])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 0.9697149357815381
# New_Zeta: 4.114474119726091
# FDDN Solver Output: [[76.6 36.6 115 75.8 40.1 124 12.1 26 26 26 25.5 25.1 11.8 25.6 25.8 25.4 25 25.1]]
# New_Zeta_epsi: 4.163967872560815
# FDDN Solver Output: [[76.4 36.5 115 75.6 40 123 12 25.9 25.9 26 25.4 25.1 11.7 25.5 25.7 25.3 25 25]]
# Row ID: 4
# HoV: ['A5']
# Flow Rate Difference (LTR - FDDN): -0.005566943415195813 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00298]), array([-0.000325])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 1.103820655803644e-05
# Learning Rate 2: 5.376011168177403
#
# CALC NEW WEIGHTS - Learning Rate Used: 5.376011168177403
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00366]), array([-0.0004]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.515]), array([0.0483])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.535]), array([0.0505])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 0.9997116461005467
# New_Zeta: 4.241749346424554
# FDDN Solver Output: [[76.1 36.3 115 75.3 39.8 123 12 25.8 25.8 25.9 25.3 25 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi: 4.291243099259279
# FDDN Solver Output: [[75.9 36.2 114 75.1 39.7 122 11.9 25.8 25.7 25.8 25.2 24.9 11.6 25.3 25.5 25.1 24.8 24.8]]
# Row ID: 4
# HoV: ['A5']
# Flow Rate Difference (LTR - FDDN): -0.000520732746028707 cu.m/s
# % Diff between flowrates 0.07017125852192085 %
# GRADIENT_UPDATE - dw_ih: [array([-0.000275]), array([-3.01e-05])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: 1.0198961844319092e-06
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for A5: [2.7116259278659787e-07]
# Error Loss History for A5: [2.322731445300224e-07]
# Old_Zeta: 4.949375283472444
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.000275]), array([-3.01e-05]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.535]), array([0.0505])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.535]), array([0.0505])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.535]), array([0.0505]), array([1])]
#
# NN output (C_f): 1.0098751142891365
# New_Zeta: 4.284872665748196
# FDDN Solver Output: [[75.1 35.8 113 74.1 39.1 121 11.9 25.6 25.5 25.6 25 24.7 11.6 25.2 25.4 25 24.7 24.7]]
# New_Zeta_epsi: 4.3343664185829205
# FDDN Solver Output: [[74.9 35.7 113 73.9 39 120 11.8 25.5 25.5 25.5 25 24.6 11.5 25.1 25.3 24.9 24.6 24.6]]
# Row ID: 5
# HoV: ['A6']
# Flow Rate Difference (LTR - FDDN): 0.010676203682665641 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.0054]), array([0.000583])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 2.946596550762601e-05
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.0054]), array([0.000583]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.535]), array([0.0505])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.529]), array([0.0499])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 0.9996680319364818
# New_Zeta: 4.2415642927116775
# FDDN Solver Output: [[75.3 35.9 113 74.2 39.2 121 11.9 25.6 25.6 25.7 25.1 24.8 11.6 25.2 25.5 25 24.7 24.7]]
# New_Zeta_epsi: 4.291058045546402
# FDDN Solver Output: [[75.1 35.8 113 74 39.1 121 11.8 25.6 25.5 25.6 25 24.7 11.6 25.2 25.4 25 24.7 24.7]]
# Row ID: 5
# HoV: ['A6']
# Flow Rate Difference (LTR - FDDN): 0.009048876925660476 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.00468]), array([0.000505])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 2.5532735201392725e-05
# Learning Rate 2: 7.491543391427925
#
# CALC NEW WEIGHTS - Learning Rate Used: 7.491543391427925
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.0054]), array([0.000583]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.535]), array([0.0505])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.494]), array([0.0461])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 0.9334083139443455
# New_Zeta: 3.960426109932969
# FDDN Solver Output: [[76.4 36.4 115 75.3 39.8 123 12.1 26 26 26 25.5 25.1 11.8 25.6 25.8 25.4 25.1 25.1]]
# New_Zeta_epsi: 4.009919862767694
# FDDN Solver Output: [[76.2 36.3 115 75.1 39.7 122 12 25.9 25.9 26 25.4 25.1 11.7 25.5 25.8 25.3 25 25]]
# Row ID: 5
# HoV: ['A6']
# Flow Rate Difference (LTR - FDDN): -0.0018149228720238941 cu.m/s
# % Diff between flowrates 0.24379691406387843 %
# GRADIENT_UPDATE - dw_ih: [array([-0.000979]), array([-0.000106])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: -5.3431777482010154e-06
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for A6: [3.2939450313954605e-06]
# Error Loss History for A6: [2.8215358264898605e-06]
# Old_Zeta: 4.949375283472444
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.000979]), array([-0.000106]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.494]), array([0.0461])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.494]), array([0.0461])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.494]), array([0.0461]), array([1])]
#
# NN output (C_f): 0.9482320636358232
# New_Zeta: 4.02332287702641
# FDDN Solver Output: [[76.5 36.5 115 75.5 39.9 123 12.1 26.1 26 26.1 25.5 25.2 11.8 25.7 25.9 25.5 25.1 25.1]]
# New_Zeta_epsi: 4.072816629861134
# FDDN Solver Output: [[76.3 36.4 115 75.3 39.8 123 12 26 25.9 26 25.5 25.1 11.8 25.6 25.8 25.4 25.1 25.1]]
# Row ID: 6
# HoV: ['C1']
# Flow Rate Difference (LTR - FDDN): -0.006563645539109375 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00359]), array([-0.000382])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 1.3010417921183546e-05
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00359]), array([-0.000382]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.494]), array([0.0461])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.498]), array([0.0465])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 0.9551220720926139
# New_Zeta: 4.0525569956669685
# FDDN Solver Output: [[76.4 36.5 115 75.3 39.8 123 12.1 26 26 26 25.5 25.1 11.8 25.6 25.8 25.4 25.1 25.1]]
# New_Zeta_epsi: 4.102050748501693
# FDDN Solver Output: [[76.2 36.4 115 75.1 39.7 122 12 26 25.9 26 25.4 25.1 11.7 25.6 25.8 25.3 25 25]]
# Row ID: 6
# HoV: ['C1']
# Flow Rate Difference (LTR - FDDN): -0.00544336880597085 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00297]), array([-0.000316])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 1.0790611542415134e-05
# Learning Rate 2: 5.861059795855688
#
# CALC NEW WEIGHTS - Learning Rate Used: 5.861059795855688
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00359]), array([-0.000382]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.494]), array([0.0461])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.515]), array([0.0483])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 0.9886148151950247
# New_Zeta: 4.194665794457863
# FDDN Solver Output: [[75.8 36.2 114 74.8 39.5 122 12 25.8 25.8 25.8 25.3 24.9 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi: 4.244159547292588
# FDDN Solver Output: [[75.6 36.1 114 74.6 39.4 122 11.9 25.8 25.7 25.8 25.2 24.9 11.7 25.4 25.6 25.2 24.8 24.9]]
# Row ID: 6
# HoV: ['C1']
# Flow Rate Difference (LTR - FDDN): 9.330782875127674e-05 cu.m/s
# % Diff between flowrates 0.012608751218095812 %
# GRADIENT_UPDATE - dw_ih: [array([4.91e-05]), array([5.22e-06])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: -1.77922479124772e-07
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for C1: [8.706350906277588e-09]
# Error Loss History for C1: [7.457708239183257e-09]
# Old_Zeta: 3.9420929651694854
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([4.91e-05]), array([5.22e-06]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.515]), array([0.0483])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.515]), array([0.0483])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.515]), array([0.0483]), array([1])]
#
# NN output (C_f): 1.2482019279025884
# New_Zeta: 4.218242819499761
# FDDN Solver Output: [[77.1 36.8 116 74.7 39.5 122 12.1 26 26 26 25.5 25.1 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi: 4.257663749151456
# FDDN Solver Output: [[76.9 36.7 116 74.6 39.4 122 12 26 25.9 26 25.4 25.1 11.7 25.4 25.6 25.2 24.8 24.9]]
# Row ID: 7
# HoV: ['C2']
# Flow Rate Difference (LTR - FDDN): -0.0019216636318912794 cu.m/s
# % Diff between flowrates 0.25843842611128515 %
# GRADIENT_UPDATE - dw_ih: [array([-0.00103]), array([-0.000109])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 1.0731577120978434e-06
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00103]), array([-0.000109]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.515]), array([0.0483])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.516]), array([0.0484])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.2507003194955808
# New_Zeta: 4.22668602260805
# FDDN Solver Output: [[77.1 36.8 116 74.7 39.5 122 12 26 26 26 25.5 25.1 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi: 4.266106952259745
# FDDN Solver Output: [[76.9 36.7 116 74.5 39.4 121 12 26 25.9 26 25.4 25.1 11.6 25.4 25.6 25.1 24.8 24.8]]
# Row ID: 7
# HoV: ['C2']
# Flow Rate Difference (LTR - FDDN): -0.001595541715215698 cu.m/s
# % Diff between flowrates 0.2146263940295855 %
# GRADIENT_UPDATE - dw_ih: [array([-0.000841]), array([-8.9e-05])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 8.762826411299394e-07
# Learning Rate 2: 5.450957842564016
#
# CALC NEW WEIGHTS - Learning Rate Used: 5.450957842564016
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00103]), array([-0.000109]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.515]), array([0.0483])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.521]), array([0.0489])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.2618205551502069
# New_Zeta: 4.264266363699249
# FDDN Solver Output: [[76.9 36.7 116 74.6 39.4 121 12 26 25.9 26 25.4 25.1 11.7 25.4 25.6 25.1 24.8 24.8]]
# New_Zeta_epsi: 4.303687293350944
# FDDN Solver Output: [[76.8 36.6 116 74.4 39.3 121 12 25.9 25.9 25.9 25.4 25 11.6 25.3 25.5 25.1 24.8 24.8]]
# Row ID: 7
# HoV: ['C2']
# Flow Rate Difference (LTR - FDDN): -0.0001572318348930235 cu.m/s
# % Diff between flowrates 0.021170727388283742 %
# GRADIENT_UPDATE - dw_ih: [array([-8.24e-05]), array([-8.72e-06])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: 8.58735556255798e-08
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for C2: [2.4721849903827002e-08]
# Error Loss History for C2: [2.1176305170824938e-08]
# Old_Zeta: 4.127180457922134
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-8.24e-05]), array([-8.72e-06]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.521]), array([0.0489])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.521]), array([0.0489])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.521]), array([0.0489]), array([1])]
#
# NN output (C_f): 1.220195399507544
# New_Zeta: 4.317205351409722
# FDDN Solver Output: [[77 36.7 116 74.6 39.4 122 11.9 25.8 25.7 25.8 25.2 24.9 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi: 4.358477155988943
# FDDN Solver Output: [[76.8 36.7 116 74.5 39.3 121 11.9 25.7 25.7 25.7 25.2 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# Row ID: 8
# HoV: ['C3']
# Flow Rate Difference (LTR - FDDN): -0.002661390601208846 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00142]), array([-0.000149])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 2.0449589142908696e-06
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00142]), array([-0.000149]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.521]), array([0.0489])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.522]), array([0.0491])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.2235304052379805
# New_Zeta: 4.329005022669123
# FDDN Solver Output: [[76.9 36.7 116 74.6 39.4 122 11.9 25.8 25.7 25.8 25.2 24.9 11.7 25.4 25.6 25.2 24.8 24.9]]
# New_Zeta_epsi: 4.370276827248344
# FDDN Solver Output: [[76.8 36.6 116 74.4 39.3 121 11.9 25.7 25.7 25.7 25.2 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# Row ID: 8
# HoV: ['C3']
# Flow Rate Difference (LTR - FDDN): -0.0022059067323181303 cu.m/s
# % Diff between flowrates 0.29775583924636206 %
# GRADIENT_UPDATE - dw_ih: [array([-0.00117]), array([-0.000122])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 1.6858152347020963e-06
# Learning Rate 2: 5.6939855286674925
#
# CALC NEW WEIGHTS - Learning Rate Used: 5.6939855286674925
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00142]), array([-0.000149]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.521]), array([0.0489])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.529]), array([0.0498])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.2391848738746727
# New_Zeta: 4.384392508803785
# FDDN Solver Output: [[76.7 36.6 116 74.4 39.3 121 11.9 25.7 25.6 25.7 25.1 24.8 11.6 25.3 25.5 25.1 24.8 24.8]]
# New_Zeta_epsi: 4.425664313383007
# FDDN Solver Output: [[76.6 36.5 115 74.2 39.2 121 11.9 25.6 25.6 25.6 25.1 24.8 11.6 25.2 25.4 25 24.7 24.7]]
# Row ID: 8
# HoV: ['C3']
# Flow Rate Difference (LTR - FDDN): -0.00011423582776659558 cu.m/s
# % Diff between flowrates 0.015441482454284734 %
# GRADIENT_UPDATE - dw_ih: [array([-6.04e-05]), array([-6.31e-06])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: 8.68379297117394e-08
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for C3: [1.3049824345519289e-08]
# Error Loss History for C3: [1.1178251782994527e-08]
# Old_Zeta: 4.521188627716888
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-6.04e-05]), array([-6.31e-06]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.529]), array([0.0498])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.529]), array([0.0498])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.529]), array([0.0498]), array([1])]
#
# NN output (C_f): 1.0923798058134482
# New_Zeta: 4.233954187315978
# FDDN Solver Output: [[75.2 35.9 113 74.1 39.2 121 11.9 25.6 25.6 25.6 25.1 24.7 11.6 25.2 25.4 25 24.7 24.7]]
# New_Zeta_epsi: 4.279166073593147
# FDDN Solver Output: [[75 35.8 113 74 39.1 121 11.8 25.5 25.5 25.6 25 24.7 11.6 25.2 25.4 24.9 24.6 24.6]]
# Row ID: 9
# HoV: ['C4']
# Flow Rate Difference (LTR - FDDN): 0.006297922526577127 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.00322]), array([0.000349])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 1.0500504415799573e-05
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.00322]), array([0.000349]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.529]), array([0.0498])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.526]), array([0.0494])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.0857176245704643
# New_Zeta: 4.20813224331786
# FDDN Solver Output: [[75.3 35.9 113 74.2 39.2 121 11.9 25.6 25.6 25.7 25.1 24.8 11.6 25.2 25.5 25 24.7 24.7]]
# New_Zeta_epsi: 4.253344129595029
# FDDN Solver Output: [[75.1 35.8 113 74.1 39.1 121 11.8 25.6 25.5 25.6 25 24.7 11.6 25.2 25.4 25 24.7 24.7]]
# Row ID: 9
# HoV: ['C4']
# Flow Rate Difference (LTR - FDDN): 0.005323085715676523 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.00274]), array([0.000296])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 8.91757791660406e-06
# Learning Rate 2: 6.6336020157197595
#
# CALC NEW WEIGHTS - Learning Rate Used: 6.6336020157197595
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.00322]), array([0.000349]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.529]), array([0.0498])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.508]), array([0.0475])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.0481855468908998
# New_Zeta: 4.062661687560261
# FDDN Solver Output: [[75.8 36.2 114 74.8 39.5 122 12 25.8 25.8 25.8 25.3 24.9 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi: 4.10787357383743
# FDDN Solver Output: [[75.7 36.1 114 74.6 39.4 122 11.9 25.8 25.7 25.8 25.2 24.9 11.7 25.4 25.6 25.2 24.9 24.9]]
# Row ID: 9
# HoV: ['C4']
# Flow Rate Difference (LTR - FDDN): -0.0002799170616659685 cu.m/s
# % Diff between flowrates 0.0378288302365231 %
# GRADIENT_UPDATE - dw_ih: [array([-0.00015]), array([-1.62e-05])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: -4.891082769304032e-07
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for C4: [7.835356141170963e-08]
# Error Loss History for C4: [6.711629324383534e-08]
# Old_Zeta: 4.127180457922134
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00015]), array([-1.62e-05]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.508]), array([0.0475])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.508]), array([0.0475])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.508]), array([0.0475]), array([1])]
#
# NN output (C_f): 1.2066662614021713
# New_Zeta: 4.26933755298002
# FDDN Solver Output: [[75.2 35.9 113 74.2 39.2 121 12 25.9 25.9 25.9 25.4 25 11.6 25.2 25.4 25 24.7 24.7]]
# New_Zeta_epsi: 4.310609357559241
# FDDN Solver Output: [[75.1 35.8 113 74 39.1 121 12 25.9 25.8 25.9 25.3 25 11.6 25.2 25.4 25 24.7 24.7]]
# Row ID: 10
# HoV: ['C5']
# Flow Rate Difference (LTR - FDDN): -0.008422195213711126 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00447]), array([-0.00046])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 2.017249243499839e-05
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00447]), array([-0.00046]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.508]), array([0.0475])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.512]), array([0.0479])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.2172957656691634
# New_Zeta: 4.3069460808623665
# FDDN Solver Output: [[75.1 35.8 113 74 39.1 121 12 25.9 25.8 25.9 25.3 25 11.6 25.2 25.4 25 24.7 24.7]]
# New_Zeta_epsi: 4.3482178854415885
# FDDN Solver Output: [[74.9 35.7 113 73.9 39 120 12 25.8 25.8 25.8 25.3 24.9 11.5 25.1 25.3 24.9 24.6 24.6]]
# Row ID: 10
# HoV: ['C5']
# Flow Rate Difference (LTR - FDDN): -0.007011567203240587 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00376]), array([-0.000387])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 1.697666755066649e-05
# Learning Rate 2: 6.312139483579848
#
# CALC NEW WEIGHTS - Learning Rate Used: 6.312139483579848
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00447]), array([-0.00046]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.508]), array([0.0475])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.536]), array([0.0504])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.2737611749767335
# New_Zeta: 4.5067278267454975
# FDDN Solver Output: [[74.3 35.5 112 73.3 38.7 119 11.9 25.6 25.6 25.6 25.1 24.7 11.5 24.9 25.1 24.7 24.4 24.4]]
# New_Zeta_epsi: 4.5479996313247195
# FDDN Solver Output: [[74.2 35.4 112 73.1 38.6 119 11.8 25.6 25.5 25.6 25 24.7 11.4 24.9 25.1 24.7 24.4 24.4]]
# Row ID: 10
# HoV: ['C5']
# Flow Rate Difference (LTR - FDDN): 0.00037246575264326953 cu.m/s
# % Diff between flowrates 0.05123630719006971 %
# GRADIENT_UPDATE - dw_ih: [array([0.000199]), array([2.05e-05])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: -8.973322142924849e-07
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for C5: [1.3873073689211725e-07]
# Error Loss History for C5: [1.1883432803085327e-07]
# Old_Zeta: 3.7645035449506787
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.000199]), array([2.05e-05]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.536]), array([0.0504])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.536]), array([0.0504])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.536]), array([0.0504]), array([1])]
#
# NN output (C_f): 1.3084069115470607
# New_Zeta: 4.222507260513691
# FDDN Solver Output: [[76.6 36.5 115 74.3 39.2 121 12.1 26.1 26 26.1 25.5 25.2 11.7 25.5 25.7 25.3 25 25]]
# New_Zeta_epsi: 4.260152295963198
# FDDN Solver Output: [[76.4 36.5 115 74.1 39.2 121 12.1 26 26 26 25.5 25.1 11.7 25.4 25.6 25.2 24.9 24.9]]
# Row ID: 11
# HoV: ['C6']
# Flow Rate Difference (LTR - FDDN): 0.011524543380538654 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.00594]), array([0.000653])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 3.57099111225232e-05
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.00594]), array([0.000653]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.536]), array([0.0504])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.53]), array([0.0497])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.2938784574497924
# New_Zeta: 4.17562085050748
# FDDN Solver Output: [[76.8 36.6 116 74.4 39.3 121 12.1 26.1 26.1 26.2 25.6 25.3 11.7 25.5 25.7 25.3 25 25]]
# New_Zeta_epsi: 4.213265885956988
# FDDN Solver Output: [[76.6 36.6 116 74.3 39.2 121 12.1 26.1 26.1 26.1 25.6 25.2 11.7 25.5 25.7 25.3 25 25]]
# Row ID: 11
# HoV: ['C6']
# Flow Rate Difference (LTR - FDDN): 0.009698941065097388 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.00503]), array([0.000553])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 3.022406057293275e-05
# Learning Rate 2: 6.50945752162154
#
# CALC NEW WEIGHTS - Learning Rate Used: 6.50945752162154
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.00594]), array([0.000653]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.536]), array([0.0504])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.497]), array([0.0461])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.2138345567460638
# New_Zeta: 3.9173021662369303
# ...
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.503]), array([0.0444])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.0620508290859585
# New_Zeta: 4.11640212590933
# FDDN Solver Output: [[76.6 36.5 115 74.3 39.2 121 11.9 25.6 25.6 25.7 25.1 24.8 11.6 25.3 25.5 25 24.7 24.8]]
# New_Zeta_epsi: 4.161614012186499
# FDDN Solver Output: [[76.4 36.5 115 74.1 39.1 121 11.9 25.6 25.5 25.6 25.1 24.7 11.6 25.2 25.4 25 24.7 24.7]]
# Row ID: 30
# HoV: ['S4']
# Flow Rate Difference (LTR - FDDN): -0.004224868011919014 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00227]), array([-0.00024])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 6.2285609568721485e-06
# Learning Rate 2: 6.117033206984494
#
# CALC NEW WEIGHTS - Learning Rate Used: 6.117033206984494
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00271]), array([-0.000287]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.5]), array([0.0441])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.517]), array([0.0458])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.0914242998673036
# New_Zeta: 4.2302507424333875
# FDDN Solver Output: [[76.1 36.3 115 73.8 39 120 11.8 25.5 25.5 25.5 25 24.6 11.5 25.1 25.3 24.9 24.6 24.6]]
# New_Zeta_epsi: 4.275462628710557
# FDDN Solver Output: [[76 36.2 115 73.6 38.9 120 11.8 25.4 25.4 25.5 24.9 24.6 11.5 25 25.3 24.8 24.5 24.6]]
# Row ID: 30
# HoV: ['S4']
# Flow Rate Difference (LTR - FDDN): 0.00014706568834377265 cu.m/s
# % Diff between flowrates 0.020025455107103234 %
# GRADIENT_UPDATE - dw_ih: [array([7.72e-05]), array([8.16e-06])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: -2.1177042275555777e-07
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for S4: [2.1628316688027666e-08]
# Error Loss History for S4: [1.852643860789798e-08]
# Old_Zeta: 2.8397674398682766
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([7.72e-05]), array([8.16e-06]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.517]), array([0.0458])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.517]), array([0.0458])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.517]), array([0.0458]), array([1])]
#
# NN output (C_f): 1.6321076838202357
# New_Zeta: 3.9733008461527075
# FDDN Solver Output: [[77.2 36.8 116 74.8 39.5 122 12.2 26.3 26.2 26.3 25.7 25.4 11.7 25.4 25.6 25.2 24.9 24.9]]
# New_Zeta_epsi: 4.001698520551391
# FDDN Solver Output: [[77 36.8 116 74.7 39.5 122 12.2 26.2 26.2 26.3 25.7 25.3 11.7 25.4 25.6 25.2 24.9 24.9]]
# Row ID: 31
# HoV: ['S5']
# Flow Rate Difference (LTR - FDDN): 0.011518334078553516 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.00597]), array([0.000672])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 3.605234750832586e-05
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.00597]), array([0.000672]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.517]), array([0.0458])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.511]), array([0.0452])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.6132162888835901
# New_Zeta: 3.927310501133876
# FDDN Solver Output: [[77.3 36.9 117 75 39.6 122 12.2 26.3 26.3 26.4 25.8 25.4 11.7 25.5 25.7 25.3 25 25]]
# New_Zeta_epsi: 3.9557081755325587
# FDDN Solver Output: [[77.2 36.9 116 74.9 39.6 122 12.2 26.3 26.3 26.3 25.7 25.4 11.7 25.5 25.7 25.3 24.9 24.9]]
# Row ID: 31
# HoV: ['S5']
# Flow Rate Difference (LTR - FDDN): 0.009695485483182886 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.00488]), array([0.000549])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 2.945814355592754e-05
# Learning Rate 2: 5.467278198942205
#
# CALC NEW WEIGHTS - Learning Rate Used: 5.467278198942205
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.00597]), array([0.000672]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.517]), array([0.0458])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.484]), array([0.0422])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.528823172135507
# New_Zeta: 3.721858835469421
# FDDN Solver Output: [[78.2 37.3 118 75.8 40.1 124 12.3 26.6 26.6 26.6 26.1 25.7 11.8 25.8 26 25.6 25.3 25.3]]
# New_Zeta_epsi: 3.750256509868104
# FDDN Solver Output: [[78.1 37.3 118 75.7 40 123 12.3 26.6 26.5 26.6 26 25.7 11.8 25.7 26 25.5 25.2 25.2]]
# Row ID: 31
# HoV: ['S5']
# Flow Rate Difference (LTR - FDDN): 0.0013011635926903908 cu.m/s
# % Diff between flowrates 0.17182080956868573 %
# GRADIENT_UPDATE - dw_ih: [array([0.000703]), array([7.92e-05])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: 4.248540732386746e-06
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for S5: [1.6930266949429653e-06]
# Error Loss History for S5: [1.4502171194282426e-06]
# Old_Zeta: 4.949375283472444
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.000703]), array([7.92e-05]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.484]), array([0.0422])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.484]), array([0.0422])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.484]), array([0.0422]), array([1])]
#
# NN output (C_f): 0.978489871436521
# New_Zeta: 4.151705933244144
# FDDN Solver Output: [[76.6 36.5 115 75.5 39.9 123 12.1 26.1 26 26.1 25.5 25.2 11.8 25.7 25.9 25.5 25.2 25.2]]
# New_Zeta_epsi: 4.201199686078868
# FDDN Solver Output: [[76.4 36.5 115 75.3 39.8 123 12.1 26 26 26 25.5 25.1 11.8 25.6 25.8 25.4 25.1 25.1]]
# Row ID: 32
# HoV: ['T1']
# Flow Rate Difference (LTR - FDDN): -0.02482994726647081 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.0141]), array([-0.00142])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 0.00020088934982447784
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.0141]), array([-0.00142]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.484]), array([0.0422])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.498]), array([0.0436])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.007024764230853
# New_Zeta: 4.272778707911489
# FDDN Solver Output: [[76.1 36.3 115 75.1 39.7 122 12 25.9 25.9 25.9 25.4 25 11.7 25.5 25.7 25.3 25 25]]
# New_Zeta_epsi: 4.3222724607462135
# FDDN Solver Output: [[75.9 36.2 114 74.9 39.6 122 12 25.9 25.8 25.9 25.3 25 11.7 25.5 25.7 25.3 24.9 25]]
# Row ID: 32
# HoV: ['T1']
# Flow Rate Difference (LTR - FDDN): -0.02014257771339245 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.011]), array([-0.00111])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 0.00015655944066450138
# Learning Rate 2: 4.53168873185628
#
# CALC NEW WEIGHTS - Learning Rate Used: 4.53168873185628
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.0141]), array([-0.00142]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.484]), array([0.0422])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.548]), array([0.0486])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.1078011235773226
# New_Zeta: 4.700370061938729
# FDDN Solver Output: [[74.5 35.5 112 73.5 38.8 120 11.8 25.4 25.3 25.4 24.8 24.5 11.5 25 25.2 24.8 24.5 24.5]]
# New_Zeta_epsi: 4.7498638147734535
# FDDN Solver Output: [[74.3 35.5 112 73.3 38.7 119 11.7 25.3 25.3 25.3 24.8 24.4 11.5 24.9 25.1 24.7 24.4 24.4]]
# Row ID: 32
# HoV: ['T1']
# Flow Rate Difference (LTR - FDDN): -0.004365194550516538 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00223]), array([-0.000225])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: 3.178320334893947e-05
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00223]), array([-0.000225]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.548]), array([0.0486])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.548]), array([0.0486])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 1 - w_0: [array([0.548]), array([0.0486]), array([1])]
#
# NN output (C_f): 1.1078011235773226
# New_Zeta: 4.700370061938729
# FDDN Solver Output: [[74.5 35.5 112 73.5 38.8 120 11.8 25.4 25.3 25.4 24.8 24.5 11.5 25 25.2 24.8 24.5 24.5]]
# New_Zeta_epsi: 4.7498638147734535
# FDDN Solver Output: [[74.3 35.5 112 73.3 38.7 119 11.7 25.3 25.3 25.3 24.8 24.4 11.5 24.9 25.1 24.7 24.4 24.4]]
# Row ID: 32
# HoV: ['T1']
# Flow Rate Difference (LTR - FDDN): -0.004365194550516538 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.00223]), array([-0.000225])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 5.028499599419533e-06
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00223]), array([-0.000225]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.548]), array([0.0486])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.55]), array([0.0488])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.1123156998901775
# New_Zeta: 4.719525286546876
# FDDN Solver Output: [[74.4 35.5 112 73.4 38.8 120 11.7 25.3 25.3 25.4 24.8 24.5 11.5 25 25.2 24.8 24.5 24.5]]
# New_Zeta_epsi: 4.7690190393816
# FDDN Solver Output: [[74.2 35.4 112 73.2 38.7 119 11.7 25.3 25.2 25.3 24.8 24.4 11.4 24.9 25.1 24.7 24.4 24.4]]
# Row ID: 32
# HoV: ['T1']
# Flow Rate Difference (LTR - FDDN): -0.00369049322210957 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([-0.0019]), array([-0.000192])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 4.292928186279162e-06
# Learning Rate 2: 6.836181381698057
#
# CALC NEW WEIGHTS - Learning Rate Used: 6.836181381698057
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([-0.00223]), array([-0.000225]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.548]), array([0.0486])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.563]), array([0.0501])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.1386635861135175
# New_Zeta: 4.831318651767191
# FDDN Solver Output: [[74 35.3 112 73 38.6 119 11.7 25.2 25.2 25.2 24.7 24.4 11.4 24.8 25 24.6 24.3 24.3]]
# New_Zeta_epsi: 4.880812404601915
# FDDN Solver Output: [[73.8 35.2 111 72.8 38.5 119 11.7 25.2 25.1 25.2 24.6 24.3 11.4 24.8 25 24.6 24.3 24.3]]
# Row ID: 32
# HoV: ['T1']
# Flow Rate Difference (LTR - FDDN): 0.00025707251529927255 cu.m/s
# % Diff between flowrates 0.03558311513577271 %
# GRADIENT_UPDATE - dw_ih: [array([0.000131]), array([1.32e-05])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: -2.947619989454056e-07
# Progress: 1.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 1
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for T1: [1.905492346385928e-05, 6.608627812229473e-08]
# Error Loss History for T1: [1.6322114884086077e-05, 5.660835247224296e-08]
# Old_Zeta: 4.949375283472444
#
# CALC NEW WEIGHTS - Learning Rate Used: 0
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.000131]), array([1.32e-05]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.563]), array([0.0501])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.563]), array([0.0501])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# TRAINING ITERATION 0 - w_0: [array([0.563]), array([0.0501]), array([1])]
#
# NN output (C_f): 1.0722962737801256
# New_Zeta: 4.549723949122498
# FDDN Solver Output: [[74.6 35.6 112 73.5 38.9 120 11.8 25.4 25.4 25.4 24.9 24.5 11.5 25 25.2 24.8 24.5 24.5]]
# New_Zeta_epsi: 4.599217701957223
# FDDN Solver Output: [[74.4 35.5 112 73.4 38.8 120 11.7 25.3 25.3 25.4 24.8 24.5 11.5 25 25.2 24.7 24.4 24.5]]
# Row ID: 33
# HoV: ['T2']
# Flow Rate Difference (LTR - FDDN): 0.013453255647144613 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.00673]), array([0.000721])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f0: 4.583993226787247e-05
#
# CALC NEW WEIGHTS - Learning Rate Used: 1
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.00673]), array([0.000721]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.563]), array([0.0501])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.557]), array([0.0494])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 1.0594588038835413
# New_Zeta: 4.495254913220015
# FDDN Solver Output: [[74.8 35.7 113 73.7 39 120 11.8 25.5 25.4 25.5 24.9 24.6 11.5 25.1 25.3 24.9 24.6 24.6]]
# New_Zeta_epsi: 4.54474866605474
# FDDN Solver Output: [[74.6 35.6 112 73.6 38.9 120 11.8 25.4 25.4 25.4 24.9 24.5 11.5 25 25.2 24.8 24.5 24.5]]
# Row ID: 33
# HoV: ['T2']
# Flow Rate Difference (LTR - FDDN): 0.011471340771161964 cu.m/s
# GRADIENT_UPDATE - dw_ih: [array([0.00574]), array([0.000615])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f1: 3.908271014782618e-05
# Learning Rate 2: 6.783842746841426
#
# CALC NEW WEIGHTS - Learning Rate Used: 6.783842746841426
# CALC NEW WEIGHTS - delta_weights_input_i_h_o: [array([0.00673]), array([0.000721]), array([0])]
# CALC NEW WEIGHTS - Inputs Passed Weights_i_h: [array([0.563]), array([0.0501])] Shape: (2, 1)
# CALC NEW WEIGHTS - Inputs Passed Weights_h_o: [array([1])] Shape: (1, 1)
# CALC NEW WEIGHTS - new_weights_i_h: [array([0.518]), array([0.0452])]
# CALC NEW WEIGHTS - new_weights_h_o: [array([1])]
#
# NN output (C_f): 0.9852088967343875
# New_Zeta: 4.1802145749879935
# FDDN Solver Output: [[76 36.3 115 74.9 39.6 122 12 25.9 25.8 25.9 25.3 25 11.7 25.5 25.7 25.3 25 25]]
# New_Zeta_epsi: 4.229708327822719
# FDDN Solver Output: [[75.8 36.2 114 74.8 39.5 122 12 25.8 25.8 25.8 25.3 24.9 11.7 25.4 25.6 25.2 24.9 24.9]]
# Row ID: 33
# HoV: ['T2']
# Flow Rate Difference (LTR - FDDN): -0.0003179327905837859 cu.m/s
# % Diff between flowrates 0.042883457109455035 %
# GRADIENT_UPDATE - dw_ih: [array([-0.000166]), array([-1.77e-05])] <class 'numpy.ndarray'> (2, 1)
# GRADIENT_UPDATE - dw_ho [array([0])] <class 'numpy.ndarray'> (1, 1)
# f2: -1.1277073082182034e-06
# Progress: 0.0% ... MSE FLowloss: 0.0 ... Error Function loss: 0.0... Training Iteration: 0
# EARLY STOPPING ACTIVATED - Terminating Neural Network Training
# MSE FlowLoss History for T2: [1.0108125932839345e-07]
# Error Loss History for T2: [8.658444262530677e-08]
# Wall time: 8min 28s

# %%
cf_df = pd.DataFrame(data=c_f_hist)
losses = pd.DataFrame(data=losses_hist)

# %%
mseflow_last_loss = []
error_last_loss = []
for i in range(len(losses)):
    loss1 = losses.MSE_flowloss[i][-1]
    loss2 = losses.Error_loss[i][-1]
    mseflow_last_loss.append(loss1)
    error_last_loss.append(loss2)

cf_df['Final_MSELoss'] = mseflow_last_loss
cf_df['Final_ErrorLoss'] = error_last_loss

# %%
cf_df['MaxEpochs'] = None # Initialize Empty Column for storing epochs trained

for i in range(len(losses['HoV'])):
    nr_epochs_trained = len(losses['MSE_flowloss'][i])
    cf_df['MaxEpochs'].loc[i] = nr_epochs_trained

cf_df
# Out:
#    HoV   c_f_hat  FlowRate_Diff_(LTR-FDDN)            f1            f2  \
# 0   A1  1.024306                  0.000072  2.495516e-05 -2.028590e-07
# 1   A2  1.061594                  0.000045  4.583340e-07  1.689663e-08
# 2   A3  1.151122                  0.000163  2.141496e-05  4.353169e-07
# 3   A4  1.300599                  0.000312  5.018005e-06 -4.011776e-07
# 4   A5  0.999712                 -0.000521  1.103821e-05  1.019896e-06
# 5   A6  0.933408                 -0.001815  2.553274e-05 -5.343178e-06
# 6   C1  0.988615                  0.000093  1.079061e-05 -1.779225e-07
# 7   C2  1.261821                 -0.000157  8.762826e-07  8.587356e-08
# 8   C3  1.239185                 -0.000114  1.685815e-06  8.683793e-08
# 9   C4  1.048186                 -0.000280  8.917578e-06 -4.891083e-07
# 10  C5  1.273761                  0.000372  1.697667e-05 -8.973322e-07
# 11  C6  1.213835                 -0.000572  3.022406e-05 -1.863609e-06
# 12  D1  1.056349                  0.000361  9.083946e-07 -1.965821e-07
# 13  D2  0.989649                 -0.000563  5.500543e-06  7.652689e-07
# 14  E1  1.016303                 -0.000349  2.191156e-06  3.004056e-07
# 15  E2  1.484870                  0.000222  5.685028e-06 -2.750603e-07
# 16  F1  0.992343                 -0.001084  9.929540e-05 -5.828872e-06
# 17  F2  0.990798                  0.000099  1.435502e-06  6.778132e-08
# 18  F3  1.010118                  0.000003  2.511696e-08  2.994290e-10
# 19  H1  1.044310                 -0.000142  1.212763e-06  9.099457e-08
# 20  I1  1.323380                 -0.000152  1.908619e-07  3.846422e-08
# 21  J1  1.195861                 -0.000430  9.701316e-06  7.568048e-07
# 22  M1  1.155841                 -0.000260  7.470384e-06  4.267301e-07
# 23  M2  1.220221                 -0.000460  1.460153e-05  1.086095e-06
# 24  P1  1.210761                 -0.000059  8.532882e-07 -3.245798e-08
# 25  Q1  1.001545                 -0.000117  3.347861e-06  1.204167e-07
# 26  Q2  0.981755                  0.000254  4.053703e-06 -2.941499e-07
# 27  S1  1.302545                 -0.000963  1.016794e-05 -1.762399e-06
# 28  S2  0.987867                 -0.000520  1.716354e-05  1.269154e-06
# 29  S3  1.009256                 -0.000032  7.906878e-06 -5.214378e-08
# 30  S4  1.091424                  0.000147  6.228561e-06 -2.117704e-07
# 31  S5  1.528823                  0.001301  2.945814e-05  4.248541e-06
# 32  T1  1.138664                  0.000257  4.292928e-06 -2.947620e-07
# 33  T2  0.985209                 -0.000318  3.908271e-05 -1.127707e-06
#
#     Final_MSELoss  Final_ErrorLoss  MaxEpochs
# 0    5.155005e-09     4.415687e-09          3
# 1    1.983135e-09     1.698719e-09          1
# 2    2.648402e-08     2.268575e-08          1
# 3    9.740244e-08     8.343323e-08          1
# 4    2.711626e-07     2.322731e-07          1
# 5    3.293945e-06     2.821536e-06          1
# 6    8.706351e-09     7.457708e-09          1
# 7    2.472185e-08     2.117631e-08          1
# 8    1.304982e-08     1.117825e-08          1
# 9    7.835356e-08     6.711629e-08          1
# 10   1.387307e-07     1.188343e-07          1
# 11   3.274195e-07     2.804618e-07          1
# 12   1.303271e-07     1.116359e-07          1
# 13   3.170431e-07     2.715736e-07          1
# 14   1.214735e-07     1.040521e-07          1
# 15   4.941282e-08     4.232616e-08          2
# 16   1.175975e-06     1.007320e-06          1
# 17   9.756465e-09     8.357218e-09          1
# 18   1.032156e-11     8.841268e-12          1
# 19   2.017796e-08     1.728409e-08          1
# 20   2.307845e-08     1.976860e-08          1
# 21   1.849558e-07     1.584299e-07          1
# 22   6.769963e-08     5.799032e-08          2
# 23   2.111600e-07     1.808760e-07          1
# 24   3.528647e-09     3.022578e-09          1
# 25   1.380268e-08     1.182314e-08          1
# 26   6.473321e-08     5.544934e-08          1
# 27   9.266087e-07     7.937169e-07          1
# 28   2.702305e-07     2.314747e-07          1
# 29   9.991997e-10     8.558970e-10          1
# 30   2.162832e-08     1.852644e-08          1
# 31   1.693027e-06     1.450217e-06          1
# 32   6.608628e-08     5.660835e-08          2
# 33   1.010813e-07     8.658444e-08          1

# %%
print('Max no. of epochs for:',cf_df['HoV'].iloc[[cf_df.MaxEpochs.idxmax()]].values)
cf_df.to_csv('data_output/NN_1CF_Output_FE_LS_SingleHoVLoop.csv',index=False)
cf_df.iloc[[cf_df.MaxEpochs.idxmax()]]
# Out:
# Max no. of epochs for: ['A1']
#   HoV   c_f_hat  FlowRate_Diff_(LTR-FDDN)        f1            f2  \
# 0  A1  1.024306                  0.000072  0.000025 -2.028590e-07
#
#    Final_MSELoss  Final_ErrorLoss  MaxEpochs
# 0   5.155005e-09     4.415687e-09          3

# %% [markdown]
# ### Plot Training Loss

# %%
from bokeh.palettes import Category20,Colorblind,Spectral,Set2,YlGnBu,RdPu
temp_list = []
bokeh_palettes = [Colorblind,YlGnBu,RdPu,Set2]
for palette in bokeh_palettes:
    for key in palette.keys():
        temp_list.append(palette[key])
    
color_palette = [y for x in temp_list for y in x]
print(color_palette)
# Out:
# ['#0072B2', '#E69F00', '#F0E442', '#0072B2', '#E69F00', '#F0E442', '#009E73', '#0072B2', '#E69F00', '#F0E442', '#009E73', '#56B4E9', '#0072B2', '#E69F00', '#F0E442', '#009E73', '#56B4E9', '#D55E00', '#0072B2', '#E69F00', '#F0E442', '#009E73', '#56B4E9', '#D55E00', '#CC79A7', '#0072B2', '#E69F00', '#F0E442', '#009E73', '#56B4E9', '#D55E00', '#CC79A7', '#000000', '#2c7fb8', '#7fcdbb', '#edf8b1', '#225ea8', '#41b6c4', '#a1dab4', '#ffffcc', '#253494', '#2c7fb8', '#41b6c4', '#a1dab4', '#ffffcc', '#253494', '#2c7fb8', '#41b6c4', '#7fcdbb', '#c7e9b4', '#ffffcc', '#0c2c84', '#225ea8', '#1d91c0', '#41b6c4', '#7fcdbb', '#c7e9b4', '#ffffcc', '#0c2c84', '#225ea8', '#1d91c0', '#41b6c4', '#7fcdbb', '#c7e9b4', '#edf8b1', '#ffffd9', '#081d58', '#253494', '#225ea8', '#1d91c0', '#41b6c4', '#7fcdbb', '#c7e9b4', '#edf8b1', '#ffffd9', '#c51b8a', '#fa9fb5', '#fde0dd', '#ae017e', '#f768a1', '#fbb4b9', '#feebe2', '#7a0177', '#c51b8a', '#f768a1', '#fbb4b9', '#feebe2', '#7a0177', '#c51b8a', '#f768a1', '#fa9fb5', '#fcc5c0', '#feebe2', '#7a0177', '#ae017e', '#dd3497', '#f768a1', '#fa9fb5', '#fcc5c0', '#feebe2', '#7a0177', '#ae017e', '#dd3497', '#f768a1', '#fa9fb5', '#fcc5c0', '#fde0dd', '#fff7f3', '#49006a', '#7a0177', '#ae017e', '#dd3497', '#f768a1', '#fa9fb5', '#fcc5c0', '#fde0dd', '#fff7f3', '#66c2a5', '#fc8d62', '#8da0cb', '#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f', '#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f', '#e5c494', '#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f', '#e5c494', '#b3b3b3']

# %%
num_lines = len(losses.HoV) # no. of lines to draw
colors = color_palette[0:num_lines]
labels = losses.HoV.values.tolist()

p1 = figure(width=1600)
for i in range(num_lines):
    x = list(range(1,len(losses['MSE_flowloss'][i])+1))
    y1 = losses['MSE_flowloss'][i]    
    p1.line(x, y1, line_width=2, color=colors[i], alpha=0.8, legend='MSE Flow Loss for {}'.format(labels[i]))    
p1.yaxis.axis_label = "MSE FlowRate Loss"
p1.xaxis.axis_label = "Epochs"
p1.legend.click_policy="hide"
show(p1)
# Out:
#   <div class="bk-root" id="61575a4f-4f9e-43f8-bb2a-de4809c67da1"></div>

# %%
p2 = figure(width=1600)
for i in range(num_lines):
    x = list(range(1,len(losses['MSE_flowloss'][i])+1))     
    y2 = losses['Error_loss'][i]    
    err_loss_lineplot = p2.line(x, y2, line_width=2, color= colors[i], alpha=0.5, legend='Error Loss for {}'.format(labels[i]))
p2.yaxis.axis_label = "Error Loss"
p2.xaxis.axis_label = "Epochs"
p2.legend.click_policy="hide"
show(p2)
# Out:
#   <div class="bk-root" id="a4261108-4b83-4f57-9026-ce6bc10cb2e8"></div>
